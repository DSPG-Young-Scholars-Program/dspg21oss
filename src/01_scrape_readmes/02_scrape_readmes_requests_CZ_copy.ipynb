# %% [markdown]
# <div style="font-size:30px" align="center"> <b> Scaping GitHub READMEs </b> </div>
#
# <div style="font-size:18px" align="center"> <b> Brandon Kramer, UVA Biocomplexity Institute, OSS DSPG 2021 </b> </div>
#
# <br>
#
# ### Overview
#
# In this notebook, we have developed a function for scraping GitHub READMEs in order to classify repositories into different types of software projects.
#
# The pipeline is setup with the following steps:
#
# 1. Loading all of the packages
#
# 2. Calling a function that scrapes the READMEs
#
# 3. Loading the repositories from PostgreSQL as a DataFrame
#
# 4. Cross-referencing the repos against the scraped data
#
# 5. Scraping the repos using multiprocessing
#
# 6. Checking the data that was scraped
#
# ### Load Packages

# %%
# for pulling/manipulating data 
import os 
import glob
import itertools
import pandas as pd
from datetime import datetime
import psycopg2 as pg
from sqlalchemy import create_engine

# for web scraping 
import json 
import lxml
import requests 
from requests.auth import HTTPBasicAuth
from bs4 import BeautifulSoup
from ratelimit import limits, sleep_and_retry
import multiprocessing
from multiprocessing.pool import ThreadPool as Pool
print("ready")
# Out:
# ready

# %% [markdown]
# ### Call Functions
#
# To use the `scrape_readmes()` function, you first need to set the username and personal acccess token (PAT) that you create on GitHub. While you can run it without this information but having no PAT means you can only make 50 calls an hour compared to about 5,000. It helps if you have several PATs to help in this process, especially since this function takes only a few moments to make 5,000 calls after the multiprocessing is incorporated. In this pipeline, we are calling the usernames and PATs from a table in PostgreSQL that looks like this:
#
# |    login    |   token  |
# |    :---:    |  :----:  |
# |  username1  |   PAT1   |
# |  username2  |   PAT2   |
# |  etc.  |   etc.   |
#
# Once the username and PAT are passed into the authetication fields, `requests` will connect to the GitHub repository of all the slugs you feed it. We have designed the function to throw errors for all issues it encounters unless it gets a 404 error (i.e. no README available), as this usually means that the repo or README has been deleted, never existed, and/or is no longer available for some reason. Unfortunately, the way that GitHub's API is setup seems to require two calls to get the README: one to get the JSON with the README location and another to decode the content. We have a `@sleep_and_retry` decorator to deal with this if we setup a `slurm` for each PAT, but using it here in the notebook means that you will just want to wait for the threshold to be hit and then move onto the next PAT. While we plan to continue working on this function to minimize the number of calls, this process will allow us to get some preliminary data for classification in the short-term.
#
# At the end of this chunk, you will also see the `filter_scraped_readmes()` function that filters scraped READMEs. Basically, you just feed this function your original data and then it filters out slugs that have already been scraped based on the local CSV that has that information.
#
# **NOTE: Before running this cell, you need to set the** `github_pat_index`. **Changing this parameter provides access to 36 different PATs.**

# %%
#os.environ['db_user'] = ''
#os.environ['db_pwd'] = ''

# set this parameter to a number between 0 and 35 
# pats #7, #14. #19, #25 seem to be setup wrong or have been removed 
github_pat_index = 20

# set the environment variables with your username and github personal access token here 
# connect to the database, download data 
connection = pg.connect(host = 'postgis1', database = 'sdad', 
                        user = os.environ.get('db_user'), 
                        password = os.environ.get('db_pwd'))
github_pats = '''SELECT * FROM gh_2007_2020.pats'''
github_pats = pd.read_sql_query(github_pats, con=connection)
github_username = github_pats.login[github_pat_index]
github_token = github_pats.token[github_pat_index]

# %%
# os.environ['GITHUB_USERNAME'] = ''
# os.environ['GITHUB_TOKEN'] = ''
# github_username = os.environ.get("GITHUB_USERNAME")
# github_token = os.environ.get("GITHUB_TOKEN")

# can only make 2500 calls per hour 
# because the function calls twice each time 
@sleep_and_retry
@limits(calls=2500, period=3600)
def scrape_readmes(slug):
    
    while True:
        try: 
            # define url based on the slug 
            url = f'https://api.github.com/repos/{slug}/readme'
            response = requests.get(url, auth=(github_username, github_token))
            response_code = response.status_code
            
            if response_code == 404: 
                print(f"404 error on {slug}")
                readme_string = "404 ERROR - NO README"
                now = datetime.now()
                current_time = now.strftime("%Y-%m-%d %H:%M:%S")
                return slug, readme_string, current_time, "Done"
            
            # can i build in a response_code == 403 continue onto the next PAT in the PAT for loop 
            
        except KeyError:
            print("Key error for: " + slug, flush=True)
            break
        
        except requests.exceptions.HTTPError as http_error:
            print ("HTTP Error:", http_error)
            raise SystemExit(http_error)
            break
            
        except requests.exceptions.ConnectionError as connection_error:
            print ("Error Connecting:", connection_error)
            raise SystemExit(connection_error)
            break 
        
        except requests.exceptions.TooManyRedirects as toomany_requests:
            print ("Too Many Requests:", toomany_requests)
            raise SystemExit(toomany_requests)
            break
                
        except requests.exceptions.Timeout as timeout_error:
            print ("Timeout Error:", timeout_error)
            raise SystemExit(timeout_error)
            break
        
        except requests.exceptions.RequestException as request_exception_error:
            print ("Oops, Some Other Error:", request_exception_error)
            raise SystemExit(request_exception_error)
            break 
            
        html_content = response.content
        soup = BeautifulSoup(html_content, 'html.parser')
        site_json=json.loads(soup.text)
        readme_link = site_json['download_url']
        
        while True:
            try: 
                readme_response = requests.get(readme_link, auth=(github_username, github_token))
                readme_response_code = readme_response.status_code
                
            except requests.exceptions.HTTPError as http_error:
                print ("HTTP Error:", http_error)
                raise SystemExit(http_error)
                break
            
            except requests.exceptions.ConnectionError as connection_error:
                print ("Error Connecting:", connection_error)
                raise SystemExit(connection_error)
                break
            
            except requests.exceptions.TooManyRedirects as toomany_requests:
                print ("Too Many Requests:", toomany_requests)
                raise SystemExit(toomany_requests)
                break 
        
            except requests.exceptions.Timeout as timeout_error:
                print ("Timeout Error:", timeout_error)
                raise SystemExit(timeout_error)
                break
        
            except requests.exceptions.RequestException as request_exception_error:
                print ("Oops, Some Other Error:", request_exception_error)
                raise SystemExit(request_exception_error)
                break  
    
            # pull the content out of the readme 
            readme_content = readme_response.content
            readme_soup = BeautifulSoup(readme_content, 'html.parser')
            readme_string = str(readme_soup)
    
            #give us the the timing and status 
            now = datetime.now()
            current_time = now.strftime("%Y-%m-%d %H:%M:%S")
            #print(readme_string)
            return slug, readme_string, current_time, "Done"
        
def filter_scraped_readmes(original_data): 
    ''' 
    Function ingests repos data and filters out already scraped data from local csv 
    '''
    
    # ingests local csv data and converts it to a list 
    os.chdir('/project/class/bii_sdad_dspg/ncses_oss_2021/requests_scrape/')
    all_filenames = [i for i in glob.glob('*.csv')]
    combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
    combined_csv = combined_csv[combined_csv['status'] == 'Done']
    scraped_slugs_list = combined_csv['slug'].tolist()
    
    # filters out all of the scraped slugs from the original_data 
    filtered_slugs = ~raw_slug_data.slug.isin(scraped_slugs_list)
    filtered_slugs = raw_slug_data[filtered_slugs]
    
    # provides the output of current slug count and number of slugs filtered 
    new_slug_count = filtered_slugs['slug'].count()
    slug_count_diff = raw_slug_data['slug'].count() - filtered_slugs['slug'].count()
    print("Current data has", new_slug_count, "entries (filtered", slug_count_diff, "from input data)")
    return filtered_slugs
    
if __name__ == "__main__":
    print("Started scraping")
    scrape_readmes(slug = 'cjbd/src')
    print("Finished scraping")
# Out:
# Started scraping
# 404 error on cjbd/src
# Finished scraping

# %% [markdown]
# ### Ingesting the Repo Slugs from the Database
#
# Here, we ingested the repository data from PostgreSQL. To pull from different subsets of the data, you can change the range of the commits clause in the `SQL` code. Even if you pull from the same range as someone else already has, the next step of the pipeline is cross-referencing which READMEs have already been scraped and then removing from slugs from the dataset. I have also added a clause to remove all of the repos with an 'Init' status, as their commits data have not yet been scraped and they seem to missing in some systematic way. For now, we are just ignoring them to deal with the majority of valid repos.

# %%
# connect to the database, download data 
connection = pg.connect(host = 'postgis1', database = 'sdad', 
                        user = os.environ.get('db_user'), 
                        password = os.environ.get('db_pwd'))

raw_slug_data = '''SELECT * FROM gh_2007_2020.repos_ranked where commits < 106 AND commits > 100 AND status != 'Init' '''

# convert to a dataframe, show how many missing we have (none)
raw_slug_data = pd.read_sql_query(raw_slug_data, con=connection)
raw_slug_data.head()
# Out:
#                                  id     spdx                        slug  \
# 0  MDEwOlJlcG9zaXRvcnkyNTMzODA2OA==      MIT          yanhaijing/data.js
# 1  MDEwOlJlcG9zaXRvcnkxMDY4NDkwMTE=  GPL-3.0              btrd/gustoland
# 2      MDEwOlJlcG9zaXRvcnkyOTk2Njc=      MIT             emonti/dnet-ffi
# 3  MDEwOlJlcG9zaXRvcnk4NDA3NzYxOA==      MIT      EvidentSolutions/cissa
# 4  MDEwOlJlcG9zaXRvcnkyMTc0NDkzNTU=      MIT  jlkravitz/joshuakravitz.me
#
#             createdat                                        description  \
# 0 2014-10-17 04:23:00  data.js 是带有消息通知的数据中心，我称其为会说话的数据。旨在让编程变得简单，世界变得美好。
# 1 2017-10-13 16:36:51                                               None
# 2 2009-09-07 05:46:03  Ruby FFI bindings for the libdnet network and ...
# 3 2017-03-06 13:41:44                                  CSS preprocessor.
# 4 2019-10-25 04:15:47                                               None
#
#   primarylanguage                                            branch  commits  \
# 0      JavaScript      MDM6UmVmMjUzMzgwNjg6cmVmcy9oZWFkcy9tYXN0ZXI=      105
# 1            Ruby  MDM6UmVmMTA2ODQ5MDExOnJlZnMvaGVhZHMvZGV2ZWxvcA==      105
# 2            Ruby          MDM6UmVmMjk5NjY3OnJlZnMvaGVhZHMvbWFzdGVy      105
# 3            Java      MDM6UmVmODQwNzc2MTg6cmVmcy9oZWFkcy9tYXN0ZXI=      105
# 4           Shell      MDM6UmVmMjE3NDQ5MzU1OnJlZnMvaGVhZHMvbWFzdGVy      105
#
#                  asof status
# 0 2021-01-03 14:18:29   Done
# 1 2021-01-03 18:30:22   Done
# 2 2021-01-03 14:06:25   Done
# 3 2021-01-03 16:26:07   Done
# 4 2021-01-03 16:17:12   Done

# %% [markdown]
# ### Checking the Counts
#
# Before running the function, you want to compare the original table that you just pulled from the database and the local CSV files that are keeping track of the already downloaded data. The first cell below gives you the count for the original table and the next cell pulls in all of the CSVs, concatenates them, and then gives the count of how many more slugs need to be scraped.

# %%
raw_slug_data['slug'].count()
# Out:
# 27976

# %%
new_slugs = filter_scraped_readmes(original_data=raw_slug_data)
# Out:
# Current data has 22832 entries (filtered 5144 from input data)

# %% [markdown]
# ### Scraping the READMEs
#
# This chunk of code does a few things. First, it sets the `batch_name` to both keep track of which batch of data we are collecting and to name the output files with the appropriate name. This MUST be done before you run the code chunk. Second, the code sets up multiprocessing to draw from multiple cores. Third, the code converts the DataFrame into a list to feed the slugs into the for loop. Lastly, we feed all the slugs to the function as a for loop and it downloads the data into our project folder.
#
# **NOTE: Before running this cell, set the** `batch_name` **variable. Changing this variable will tell us which download batch the data was collected during and then save the CSV with that batch name.**

# %%
# need to change this for each batch or you will save over what you had  
batch_name = 'oss_readme_batch1_56' 

# sets the number of cores so that it can draw from multiprocessors 
# there must be 1 core subtracted so that the notebook can run too 
cores_available = multiprocessing.cpu_count() - 1
pool = Pool(cores_available)

# convert the dataframe into a list for the subsequent for loop 
raw_slugs = new_slugs["slug"].tolist()
slugs = []
for s in raw_slugs:
    slugs.append(s.strip())
    
# now we will feed in all of the remaining slugs 
slug_log = []
readme_log = []
asof_log = []
status_log = []
for result in pool.imap_unordered(scrape_readmes, slugs):
    slug_log.append(result[0])
    readme_log.append(result[1])
    asof_log.append(result[2])
    status_log.append(result[3])
    final_log = pd.DataFrame({'slug': slug_log, "readme_text": readme_log, 'batch': batch_name, 'as_of': asof_log, 'status': status_log}, 
                              columns=["slug", "readme_text", "batch", "as_of", "status"])
    final_log.to_csv('/project/class/bii_sdad_dspg/ncses_oss_2021/requests_scrape/'+batch_name+'.csv', sep=',', encoding='utf-8', index=False)
print("Finished scraping", len(final_log), "of", len(slugs), "records")
# Out:
# 404 error on nikolakn/TeamMatchStats
# 404 error on terranpro/async-task
# 404 error on hoodiecrow/Modules
# 404 error on MessageOnTap/GoogleDocsPlugin
# 404 error on hatofmonkeys/cloudfocker
# 404 error on pkdone/k8smongodb
# 404 error on VlinderSoftware/securitylayer
# 404 error on GreatOrator/TolkienCraftII-Map
# 404 error on rullzer/dropit
# 404 error on hesyifei/Sleep-Android
# 404 error on fenexomega/webgl
# 404 error on ale-d/csgo_dashboard
# 404 error on hacklabmikkeli/membertrack
# 404 error on dbtdsilva/dbtdsilva.github.io
# 404 error on zhuhaow/dandelion
# 404 error on palasthotel/wp-firebase-notifications
# 404 error on citizen010/empty-site-template
# 404 error on deathbeam/raxe-book
# 404 error on optoro-devops/chef-ci404 error on surgefm/v2land-url-trimmer
# 404 error on veragodman/verafimost
#
# 404 error on hugodelahousse/psychic-guacamole
# 404 error on Festiva-Team/festiva_documents
# 404 error on wikimedia/mediawiki-extensions-BlueSpiceAbout
# 404 error on tdd-php/lib-simple-string
# 404 error on skabashnyuk/eclipse-che-plugins
# 404 error on megacoder/restfs
# 404 error on darkreapyre/aws-modernization-workshop
# 404 error on TheHive-Project/ova_builder
# 404 error on yzylovepmn/YDrawing2D
# 404 error on kallangerard/rmshelper
# 404 error on tehshin/bestoftheworst
# 404 error on aniabrown/QuEST_Performance
# 404 error on wahern/luapath
# 404 error on KoTiX/movieplayer_film404 error on latex-projects/ProjectTemplate
#
# 404 error on veragodman/-
# 404 error on ravenblu/ravenblu.github.io
# 404 error on andrzejgorski/social_network_graph_analysis
# 404 error on FLS-Wiesbaden/vplanUploader
# 404 error on alexpear/commander
# 404 error on jammaloo/tamarafreeman.ca
# 404 error on koryagin2006/GB_Course_Database
# 404 error on mtomai/RevisionControlForImages
# 404 error on bruun-rasmussen/mail-util
# 404 error on kakaLQY/config
# 404 error on mikewubox/V2Ray_ws-tls_bash_onekey
# 404 error on JohnOliver23/activities-of-the-second-period
# 404 error on discferret/magpie
# 404 error on ecrampton1/MspPeripheralmm
# 404 error on gamma-omg/libnes404 error on Quabynah-Codelabs/ug-congregation404 error on RussbellGutierrez/KTransporte
#
#
# 404 error on MyMiniFactory/3DPrintingMeshRepair
# 404 error on maciejken/node-express-postgres
# 404 error on hychul/zerone-android-example
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-a379aae48959> in <module>
#      18 asof_log = []
#      19 status_log = []
# ---> 20 for result in pool.imap_unordered(scrape_readmes, slugs):
#      21     slug_log.append(result[0])
#      22     readme_log.append(result[1])
#
# ~/.conda/envs/brandon_env/lib/python3.9/multiprocessing/pool.py in next(self, timeout)
#     868         if success:
#     869             return value
# --> 870         raise value
#     871
#     872     __next__ = next                    # XXX
#
# ~/.conda/envs/brandon_env/lib/python3.9/multiprocessing/pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     123         job, i, func, args, kwds = task
#     124         try:
# --> 125             result = (True, func(*args, **kwds))
#     126         except Exception as e:
#     127             if wrap_exception and func is not _helper_reraises_exception:
#
# ~/.conda/envs/brandon_env/lib/python3.9/site-packages/ratelimit/decorators.py in wrapper(*args, **kargs)
#     111         while True:
#     112             try:
# --> 113                 return func(*args, **kargs)
#     114             except RateLimitException as exception:
#     115                 time.sleep(exception.period_remaining)
#
# ~/.conda/envs/brandon_env/lib/python3.9/site-packages/ratelimit/decorators.py in wrapper(*args, **kargs)
#      78                     return
#      79
# ---> 80             return func(*args, **kargs)
#      81         return wrapper
#      82
#
# <ipython-input-13-1e1feeae1113> in scrape_readmes(slug)
#      72         soup = BeautifulSoup(html_content, 'html.parser')
#      73         site_json=json.loads(soup.text)
# ---> 74         readme_link = site_json['download_url']
#      75
#      76         while True:
#
# KeyError: 'download_url'
# 404 error on UMWRG/csv-app
# 404 error on fsproru/alextamoykin.com
# 404 error on pooza/shooby-do-bop404 error on Taleshire/Vision_of_a_Shaman404 error on yulqen/twdft
#
#
# 404 error on pawanrhd/financestocks
# 404 error on christopherjbly/google-docslist-gadget
# 404 error on nikolakn/TeamMatchStats
# 404 error on castorgodinho/ChowguleRedesign
# 404 error on DanielCauser/ReleaseEverywhereBuildOnce
# 404 error on sindanar/PDStrategy
# 404 error on terranpro/async-task
# 404 error on hoodiecrow/Modules
# 404 error on MessageOnTap/GoogleDocsPlugin
# 404 error on hatofmonkeys/cloudfocker
# 404 error on voivoid/CppSip
# 404 error on pkdone/k8smongodb
# 404 error on VlinderSoftware/securitylayer
# 404 error on BastyZ/Subastas_nSystem
# 404 error on serlosan/serlosan.github.io
# 404 error on fdabl/fdabl.github.io
# 404 error on fvendrameto/Databases-Final-Project
# 404 error on GreatOrator/TolkienCraftII-Map
# 404 error on xbib/catalog
# 404 error on DrenfongWong/x509-ada
# 404 error on darrowco/z76-Docs
# 404 error on rullzer/dropit
# 404 error on tronixworkshop/tronixworkshop.github.io
# 404 error on cvast/cvast-arches
# 404 error on hesyifei/Sleep-Android
# 404 error on LaunchCoderGirlSTL/Data-Analysis-Learning-Track
# 404 error on fenexomega/webgl
# 404 error on bmaupin/bmaupin.github.io
# 404 error on ale-d/csgo_dashboard
# 404 error on AshtrayBroom/ashbloom
# 404 error on selfhostedworks/openmappr
# 404 error on hacklabmikkeli/membertrack
# 404 error on zeddee/nsdmdh-src
# 404 error on Jaruso/Maple_Tycoon
# 404 error on SENERGY-Platform/smart-meter-connector
# 404 error on cronfy/experience
# 404 error on Steven-Chavez/CourseWork-AssociatesDegree
# 404 error on Cimsolutions2019/Frontend
# 404 error on BenedictC/BCOObjectStore
# 404 error on dbtdsilva/dbtdsilva.github.io
# 404 error on zhuhaow/dandelion
# 404 error on ecorov/ecorov.github.io404 error on lukevandekieft/appsync_tutorial
#
# 404 error on ieasb/ieasb.github.io
# 404 error on yzylovepmn/YDrawing2D
# 404 error on tehshin/bestoftheworst
# 404 error on kallangerard/rmshelper
# 404 error on aniabrown/QuEST_Performance404 error on palasthotel/wp-firebase-notifications
# 404 error on wahern/luapath
#
# 404 error on KoTiX/movieplayer_film404 error on deathbeam/raxe-book
# 404 error on citizen010/empty-site-template
#
# 404 error on latex-projects/ProjectTemplate
# 404 error on veragodman/-
# 404 error on ravenblu/ravenblu.github.io
# 404 error on andrzejgorski/social_network_graph_analysis
# 404 error on FLS-Wiesbaden/vplanUploader
# 404 error on surgefm/v2land-url-trimmer404 error on alexpear/commander
#
# 404 error on optoro-devops/chef-ci
# 404 error on 4oi/Nest-API
# 404 error on alex-clay/Brutal-Bunnyhop
# 404 error on TrueC-D/Event-Space
# 404 error on theAlidiary/theAlidiary.github.io
# 404 error on felipeguilhermefs/dotfiles
# 404 error on azman/my1ftree
# 404 error on ECNU-Studio/emoc
# 404 error on walterdejong/mpflow
# 404 error on liuzhanjie75/leetcode
# 404 error on PMET-public/magento-scripts
# 404 error on John15321/MUD
# 404 error on jcsmileyjr/v2-Portfolio
# 404 error on XIMDEX/xfind
# 404 error on bmatthias/kolab-android
# 404 error on theSorcerers/octopull
# 404 error on reddress/vertfolia
# 404 error on NoeRamos2/ejemplocss
# 404 error on sonysantos/xgrammar404 error on davidbarratt/davidwbarratt
#
# 404 error on GalphaXie/E-commerce
# 404 error on Xiaoye220/Specs
# 404 error on mh-uq2/Blinkist-Daily-Scraper
# 404 error on drew1horn/cmci2
# 404 error on Miha22/ItemRestrictorAdvanced
# 404 error on eusoupaulolopes/zmplayer
# 404 error on Nana-Muthuswamy/FoodEx
# 404 error on andron/recorder
# 404 error on iisotirisii/iisotirisii.github.io
# 404 error on iswarit/tourism
# 404 error on huimumua/Project_sig_ma
# 404 error on Ryukie/Ryubo
# 404 error on hanhthaoluu/301n5-portfolio
# 404 error on dingbots/castle
# 404 error on Nicholas-Daddona/Kerberos-Chat
# 404 error on accel2k/urpc
# 404 error on ranginui/git-bz
# 404 error on Strafo/Thread-Pool-C
# 404 error on wit543/Sud-Mun
# 404 error on ThiruniAmanda/Water-Kingdom
# 404 error on detroit-labs/nn-ios
# 404 error on promiladahiya/promiladahiya.github.io
# 404 error on ArtificialSoftwareEngineering/EvoCom4SE
# 404 error on Flashkirby/builders-toolkit
# 404 error on whitstot/wnsTest
# 404 error on mubin4all/PowerBI
# 404 error on mh-uq2/Blinkist-Daily-Scraper
# 404 error on Xiaoye220/Specs
# 404 error on GalphaXie/E-commerce
# 404 error on gorczynski-mike/Games
# 404 error on drew1horn/cmci2
# 404 error on Miha22/ItemRestrictorAdvanced
# 404 error on jeffallen/jra-go
# 404 error on ned3144/nedsblog
# 404 error on eusoupaulolopes/zmplayer404 error on shlevy/haskell-options
#
# 404 error on Nana-Muthuswamy/FoodEx
# 404 error on andron/recorder
# 404 error on ilteris/FBTreeMap
# 404 error on ajaidanial/MyWebSite
# 404 error on iisotirisii/iisotirisii.github.io404 error on iswarit/tourism
#
# 404 error on tripph/docs
# 404 error on DIR-Bunny/DIR-Bunny.github.io
# 404 error on KevinOConnor/ptkei
# 404 error on safety-ducks/duck-on-drug
# 404 error on BielStela/climate_challenge
# 404 error on FernandoRoldan93/Qytetet_Ruby
# 404 error on dupuqub/dunp
# 404 error on Nass9696/Portfolio
# 404 error on huimumua/Project_sig_ma
# 404 error on ParanoidAndroid/HALO
# 404 error on yulqen/twdft
# 404 error on Ryukie/Ryubo
# 404 error on Taleshire/Vision_of_a_Shaman404 error on pooza/shooby-do-bop
#
# 404 error on fsproru/alextamoykin.com
# 404 error on UMWRG/csv-app
# 404 error on pawanrhd/financestocks404 error on hanhthaoluu/301n5-portfolio
#
# 404 error on dingbots/castle
# 404 error on christopherjbly/google-docslist-gadget
# 404 error on accel2k/urpc
# 404 error on Nicholas-Daddona/Kerberos-Chat
# 404 error on ranginui/git-bz
# 404 error on castorgodinho/ChowguleRedesign
# 404 error on Strafo/Thread-Pool-C404 error on sindanar/PDStrategy
# 404 error on DanielCauser/ReleaseEverywhereBuildOnce
#
# 404 error on wit543/Sud-Mun
# 404 error on voivoid/CppSip
# 404 error on ThiruniAmanda/Water-Kingdom
# 404 error on detroit-labs/nn-ios
# 404 error on BastyZ/Subastas_nSystem
# 404 error on ArtificialSoftwareEngineering/EvoCom4SE
# 404 error on promiladahiya/promiladahiya.github.io
# 404 error on wicadmin/docks
# 404 error on ccap/json-formlets404 error on shayyah/webrtctest
#
# 404 error on harmattan/uds
# 404 error on zazaluMonster/zazaluMonster.github.io
# 404 error on thiagorb/llama-adventure
# 404 error on dataisfunny/HappyNewYear.AI
# 404 error on AustinRF2918/SimplexCore
# 404 error on AlexStrNik/theme-preview
# 404 error on irawinder/LastMilePixelizer
# 404 error on fuine/katome
# 404 error on CakeQ/SpaceLoop
# 404 error on OtvorenyParlament/nrsr-pipeline
# 404 error on wagnermoschini/LD32
# 404 error on adiyoss/adiyoss.github.io
# 404 error on aviansie-ben/yet-another-static-java-compiler
# 404 error on wakanda-cloud/wakanda-webapp
# 404 error on crasher925/COP
# 404 error on m8mble/personal-config
# 404 error on google-code-export/lolmodelviewer
# 404 error on rremizov/dotfiles
# 404 error on swqsldz/lolmodelviewer
# 404 error on eflan/practice
# 404 error on kaiywen/kaiywen.github.io
# 404 error on skiselkov/libcpdlc
# 404 error on AntonPashkowskiy/Tars
# 404 error on costolo/recipe_project
# 404 error on rbojan/redmine-extended_fields
# 404 error on mojoe-playground/BlobCache
# 404 error on kricker/plugin.video.sagetv
# 404 error on mrbrownt/gitreleased
# 404 error on tdp-libs/tp_maps
# 404 error on granek/crne_cna1crz1_rnaseq
# 404 error on chang4chihkai/v1Kinect2Scratch404 error on excellentingenuity/Configurator
#
# 404 error on flavio/kaveau404 error on kouaw/metro_lime_phpbb3.1.4
#
# 404 error on idle-inklings/idle-inklings.github.io
# 404 error on karloscarweber/ghostwriter
# 404 error on Geor23/todo-grad-project-geo
# 404 error on alexalko/d-kurochkin.github.io
# 404 error on timothycrosley/blog
# 404 error on jzbjyb/rri_match
# 404 error on italianman1/loyaltynetwork_businessnetwork
# 404 error on astrotycoon/semo
# 404 error on dojocon-japan/dojocon2016teaser
# 404 error on borradaniele/rails.js
# 404 error on songqingchu/ff
# 404 error on 17koa/source
# 404 error on EmmaNaty/UPC_Moodle_Mobile
# 404 error on SeparateRecords/lethargy
# 404 error on agiced/PhoneGap
# 404 error on beaudet08/volafox
# 404 error on ikchu/pawswap
# 404 error on marborrego/cs221
# 404 error on rafaqz/knowledge_feature
# 404 error on DrPizza/advent-of-code
# 404 error on samlanh/ministryindust
# 404 error on evelbulgroz/sr-webdev-restaurant-reviewer
# 404 error on moadAlami/dotfiles
# 404 error on andgi/FlightGear-ZLT-NT
# 404 error on ovbm/kulturpunkt
# 404 error on michalvi/heroes3calc
# 404 error on cyranodb/volafox
# 404 error on AsteroidOS/meta-sturgeon-hybris
# 404 error on alex-clay/Brutal-Bunnyhop
# 404 error on TrueC-D/Event-Space
# 404 error on darfink/Muwesome
# 404 error on 4oi/Nest-API
# 404 error on theAlidiary/theAlidiary.github.io
# 404 error on directman66/majordomo-online
# 404 error on Lrss/jynits404 error on azman/my1ftree
#
# 404 error on felipeguilhermefs/dotfiles
# 404 error on ECNU-Studio/emoc
# 404 error on nevraw/Flux
# 404 error on walterdejong/mpflow
# 404 error on liuzhanjie75/leetcode
# 404 error on gngf-programming/edi3-pf-2018404 error on PMET-public/magento-scripts
#
# 404 error on John15321/MUD
# 404 error on ivanodapice/sito
# 404 error on jcsmileyjr/v2-Portfolio404 error on THEGAYUK/film
#
# 404 error on TheHyperDragon/TheHyperDragon.github.io
# 404 error on mnahm5/django-estore
# 404 error on XIMDEX/xfind
# 404 error on bmatthias/kolab-android
# 404 error on pollingerMaxi/ingenieria-en-sistemas
# 404 error on svenhofstede/svenhofstede.github.io404 error on DBL-Portaria/Pontos-Vendas-Client
#
# 404 error on theSorcerers/octopull
# 404 error on reddress/vertfolia
# 404 error on fheeger/gost
# 404 error on metiscus/wasteland
# 404 error on NoeRamos2/ejemplocss
# 404 error on gloddo/worksapp404 error on olegshtch/gtable
#
# 404 error on GraineDeMoutarde/Univers
# 404 error on davidbarratt/davidwbarratt
# 404 error on dotzhang/dotzhang.github.io404 error on sonysantos/xgrammar
#
# 404 error on GalphaXie/E-commerce
# 404 error on Carbonify/4CubedTicTacToeAI
# 404 error on mudler/foobot
# 404 error on Xiaoye220/Specs404 error on magthe/dataenc
# 404 error on mh-uq2/Blinkist-Daily-Scraper
#
# 404 error on lufvape/lufvape.github.io
# 404 error on drew1horn/cmci2
# 404 error on Jacques2/PAG-Manager
# 404 error on clausM2/f_bnb
# 404 error on Miha22/ItemRestrictorAdvanced
# 404 error on Daniel-Francisco/My-Digital-Safe404 error on eusoupaulolopes/zmplayer
#
# 404 error on bgoplen/Traffic-Sign-Classifier
# 404 error on Nana-Muthuswamy/FoodEx
# 404 error on yireo/Yireo_EmailOverride
# 404 error on andron/recorder
# 404 error on beamplayer/gridbeam
# 404 error on hogoww/compil
# 404 error on Bro-Pals/GGJ2016
# 404 error on adamckay/adamckay.github.io
# 404 error on prestodb/presto-hive-apache
# 404 error on lopezdonaque/Common-PHP-Framework
# 404 error on Ameliorate/buildengine5
# 404 error on Shift-Development/LEdit
# 404 error on mpmilano/mutils
# 404 error on a-dhagat/Animesh
# 404 error on the-it/trello_manager
# 404 error on grahamtriggs/acceptance-tests
# 404 error on MagneFire/meta-sawshark-hybris
# 404 error on Product-Foundry/business-elements-angular
# 404 error on rymixif/lolmodelviewer
# 404 error on darkstar62/tribble-backup
# 404 error on chrender/fizmo-sdl2404 error on NickSamNam/ShiftCalCreator
#
# 404 error on nekonungstvo/KMChat
# 404 error on AgtLucas/Lotus
# 404 error on GuillermoRivero/BoguiJS
# 404 error on xianjunzhengbackup/code
# 404 error on spudgy/lolmodelviewer
# 404 error on bwrsandman/bzr4j
# 404 error on Remypoc/Gestion-de-contact
# 404 error on lvsijian8/MrGarden_for_Web
# 404 error on bryansim/Python
# 404 error on tauraamui/berrybun
# 404 error on MrBirdatGit/Decathletes
# 404 error on redBorder/rb-utils
# 404 error on wildfyre-app/web
# 404 error on netfiretec/php-protobuf
# 404 error on rango527/workshop-2019
# 404 error on JanetMatsen/thesis
# 404 error on kodegenix/wetty-lib
# 404 error on UCSolarCarTeam/Epsilon-Embedded-Test-Tool
# 404 error on n1889/lolmodelviewer
# 404 error on Kleiin96/projexMedia
# 404 error on ronalfy/metronet-tag-manager
# 404 error on 1806-jun25-net/SecureX-MVC
# 404 error on cyrus-/webpage
# 404 error on menyp/SG_Android_Appium
# 404 error on mikniller/CalcTest
# 404 error on lpotas2/mshydro
# 404 error on WIZARDISHUNGRY/sfDomFeedPlugin
# 404 error on swup/docs
# 404 error on Oscar1891/volafox
# 404 error on mikulatomas/mikulatomas.github.io
# 404 error on darkangel100/bustamante
# 404 error on michrome/hello-yoga
# 404 error on intel/rsp-sw-toolkit-im-suite-demo-ui
# 404 error on getpop/migrate-api
# 404 error on shutoff/car-alarm
# 404 error on facebook201/higher-order
# 404 error on rremizov/dotfiles404 error on samalws/ordos
#
# 404 error on swqsldz/lolmodelviewer
# 404 error on hbrunk/vault_too
# 404 error on eflan/practice
# 404 error on kaiywen/kaiywen.github.io
# 404 error on escowles/fcrepo-storage-policy404 error on kyasbal-1994/WatchFunction
#
# 404 error on skiselkov/libcpdlc
# 404 error on taramatt93/recipes-with-friends-web
# 404 error on AntonPashkowskiy/Tars
# 404 error on 0zuna/activities
# 404 error on costolo/recipe_project
# 404 error on dimkinv/angular2-evecyclopedia-client
# 404 error on ma-buracchi/Master-thesis
# 404 error on rbojan/redmine-extended_fields
# 404 error on kricker/plugin.video.sagetv
# 404 error on kaneru/kaneru.github.io
# 404 error on mojoe-playground/BlobCache
# 404 error on aben20807/programming_language404 error on yhx5768/ImageBed
#
# 404 error on mrbrownt/gitreleased
# 404 error on granek/crne_cna1crz1_rnaseq404 error on zhuoaprilfu/demo_fork404 error on shauncarland-old-account/Personal
#
#
# 404 error on phosabyss/site404 error on tdp-libs/tp_maps
#
# 404 error on excellentingenuity/Configurator
# 404 error on chang4chihkai/v1Kinect2Scratch
# 404 error on freedraw/osx
# 404 error on sseitov/WD-Content-Swift
# 404 error on FreeGeng/Linebot404 error on flavio/kaveau
#
# 404 error on idle-inklings/idle-inklings.github.io
# 404 error on itmilos/stuka404 error on kouaw/metro_lime_phpbb3.1.4
# 404 error on kylemcco/jengaship
#
# 404 error on Geor23/todo-grad-project-geo
# 404 error on karloscarweber/ghostwriter
# 404 error on alexalko/d-kurochkin.github.io404 error on philippbosch/django-rosetta
#
# 404 error on timothycrosley/blog
# 404 error on NumeeBot/Numee-Bot
# 404 error on italianman1/loyaltynetwork_businessnetwork
# 404 error on jzbjyb/rri_match
# 404 error on darfink/Muwesome
# 404 error on directman66/majordomo-online
# 404 error on astrotycoon/semo
# 404 error on dojocon-japan/dojocon2016teaser
# 404 error on Lrss/jynits
# 404 error on borradaniele/rails.js
# 404 error on 17koa/source
# 404 error on songqingchu/ff
# 404 error on EmmaNaty/UPC_Moodle_Mobile
# 404 error on SeparateRecords/lethargy
# 404 error on nevraw/Flux
# 404 error on agiced/PhoneGap
# 404 error on ikchu/pawswap
# 404 error on gngf-programming/edi3-pf-2018
# 404 error on beaudet08/volafox
# 404 error on ivanodapice/sito404 error on rafaqz/knowledge_feature
#
# 404 error on marborrego/cs221
# 404 error on THEGAYUK/film
# 404 error on DrPizza/advent-of-code
# 404 error on tehDugong/BACTracker
# 404 error on funkey/pipeline
# 404 error on Alejandro2134/Estructura-De-Datos
# 404 error on open-power/romulus-xml
# 404 error on houseofbits/BloodySundayGame
# 404 error on cmusatyalab/kimberley
# /home/kb7hp/.conda/envs/brandon_env/lib/python3.9/site-packages/bs4/__init__.py:417: MarkupResemblesLocatorWarning: "https://wiki.jenkins-ci.org/display/JENKINS/Job+Import+Plugin
# " looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# 404 error on sirinsidiator/ESO-AetheriusBadgeFilter
# 404 error on white-noise-ntua/cansat-fsw2019
# 404 error on astubbs/buildnumber-maven-plugin
# 404 error on k8hansen/authenticgrace
# 404 error on SkyRzn/a62prices
# 404 error on kopzinski/FriendsMoneyAPI
# 404 error on diogogosch/dg
# 404 error on softwareventures/duration404 error on gitpan/NetAddr-IP
#
# 404 error on jeddict/jeddict.github.io
# 404 error on Appiko/website
# 404 error on gobline/application
# 404 error on ngspipes2/main
# 404 error on gsisko/RoboteQ-Support-Documents
# 404 error on monerodocs/md
# 404 error on MattFrancis123/mattfrancis.tk
# 404 error on ButecoOpenSource/exemplos
# 404 error on rbuffat/gdal_builder
# 404 error on EnessenE/erik
# 404 error on electriccitizen/ecdemo
# 404 error on BradLarson/Molecules
# 404 error on irhawks/pydocbuild
# 404 error on Eresus/Articles
# 404 error on MuddHacksTeam/muddhacks
# 404 error on wicadmin/docks
# 404 error on petr-devaikin/commonview
# 404 error on ccap/json-formlets
# 404 error on jokkebk/euler
# 404 error on shayyah/webrtctest
# 404 error on harmattan/uds
# 404 error on zazaluMonster/zazaluMonster.github.io
# 404 error on thiagorb/llama-adventure
# 404 error on MagneFire/meta-sawfish-hybris
# 404 error on dataisfunny/HappyNewYear.AI
# 404 error on AustinRF2918/SimplexCore
# 404 error on AlexStrNik/theme-preview
# 404 error on irawinder/LastMilePixelizer
# 404 error on janEbert/dotfiles
# 404 error on JoeyEremondi/helium-Top
# 404 error on arBalasquide/arBalasquide.github.io
# 404 error on wjbaker101/loughborough.tech
# 404 error on mike4263/dotfiles
# 404 error on fuine/katome
# 404 error on CakeQ/SpaceLoop
# 404 error on OtvorenyParlament/nrsr-pipeline
# 404 error on aprince86/volafox
# 404 error on erindhoxha/happyCentro
# 404 error on ktsanter/instructor-tips
# 404 error on wagnermoschini/LD32
# 404 error on erpcya/Get-Weight
# 404 error on AntoJant/IMFPMO_Application
# 404 error on adiyoss/adiyoss.github.io
# 404 error on ilhamudzakir/rumah_sentul
# 404 error on wengyifeng-HL/wengyifeng-HL.github.io
# 404 error on aviansie-ben/yet-another-static-java-compiler
# 404 error on venuswang/ShowDoc
# 404 error on wakanda-cloud/wakanda-webapp
# 404 error on Scoudem/modsim
# 404 error on crasher925/COP404 error on m8mble/personal-config
#
# 404 error on google-code-export/lolmodelviewer
# 404 error on rremizov/dotfiles404 error on fahsien/checker
#
# 404 error on swqsldz/lolmodelviewer
# 404 error on kuchkovsky/ubts-applications
# 404 error on eflan/practice
# 404 error on fedyafed/diffraction
# 404 error on kaiywen/kaiywen.github.io
# 404 error on skiselkov/libcpdlc404 error on urbanetic/meteor-atlas-util
#
# 404 error on halkeye/gatsby-theme-nodeschool
# 404 error on AntonPashkowskiy/Tars
# 404 error on costolo/recipe_project
# 404 error on sebalaini/Portfolio404 error on ningxiaoixao/lolmodelviewer
#
# 404 error on Alfieri-Jun-teams/koa-teskboom
# 404 error on ronsaldo/wloden-core-assets
# 404 error on rbojan/redmine-extended_fields
# 404 error on mojoe-playground/BlobCache
# 404 error on kberba/karen-berba-website
# 404 error on kricker/plugin.video.sagetv
# 404 error on mrbrownt/gitreleased
# 404 error on granek/crne_cna1crz1_rnaseq
# 404 error on tdp-libs/tp_maps
# 404 error on FiveAourThe/FiveAourThe.github.io
# 404 error on global4netltd/reactstorefront-ms-catalog-magento2-graph-ql
# 404 error on excellentingenuity/Configurator
# 404 error on Sniperkillerut/SkinText
# 404 error on chang4chihkai/v1Kinect2Scratch
# 404 error on flavio/kaveau
# 404 error on n1ywb/webdlmon-backend
# 404 error on karloscarweber/ghostwriter
# 404 error on kouaw/metro_lime_phpbb3.1.4
# 404 error on Geor23/todo-grad-project-geo404 error on idle-inklings/idle-inklings.github.io
#
# 404 error on Daedalustx/Dlvr
# 404 error on alexalko/d-kurochkin.github.io
# 404 error on airwindows/airwindows
# 404 error on italianman1/loyaltynetwork_businessnetwork
# 404 error on timothycrosley/blog
# 404 error on c00w/hydrogen
# 404 error on jzbjyb/rri_match
# 404 error on TWChennai/KanJuice
# 404 error on astrotycoon/semo
# 404 error on Katreque/queroboli-api
# 404 error on dojocon-japan/dojocon2016teaser
# 404 error on borradaniele/rails.js
# 404 error on songqingchu/ff
# 404 error on 17koa/source
# 404 error on EmmaNaty/UPC_Moodle_Mobile
# 404 error on SeparateRecords/lethargy
# 404 error on Davnit/Pro6-Utils
# 404 error on mnm1001/draggable-homepage404 error on beaudet08/volafox
#
# 404 error on agiced/PhoneGap
# 404 error on ikchu/pawswap
# 404 error on marborrego/cs221
# 404 error on rafaqz/knowledge_feature
# 404 error on DrPizza/advent-of-code
# 404 error on liche501/p2-customer-service
# 404 error on samlanh/ministryindust
# 404 error on Confalone/data-structures-and-algorithms
# 404 error on evelbulgroz/sr-webdev-restaurant-reviewer404 error on moadAlami/dotfiles
#
# 404 error on andgi/FlightGear-ZLT-NT
# 404 error on ovbm/kulturpunkt
# 404 error on AsteroidOS/meta-sturgeon-hybris
# 404 error on michalvi/heroes3calc
# 404 error on adamckay/adamckay.github.io
# 404 error on cyranodb/volafox
# 404 error on Bro-Pals/GGJ2016
# 404 error on prestodb/presto-hive-apache
# 404 error on lopezdonaque/Common-PHP-Framework
# 404 error on jenkinsci/maven-info-plugin404 error on Ameliorate/buildengine5404 error on nooroel/srp-project
#
#
# 404 error on nhsconnect/ccri-fhir-explorer
# 404 error on Shift-Development/LEdit
# 404 error on daviesjoe15/Portfolio
# 404 error on mpmilano/mutils
# 404 error on a-dhagat/Animesh
# 404 error on khmDEV/Proyecto-Cerdo-Volador
# 404 error on Floliroy/SpeedRun
# 404 error on nthu-ee/CAAC-Toolkit
# 404 error on the-it/trello_manager
# 404 error on grahamtriggs/acceptance-tests
# 404 error on MagneFire/meta-sawshark-hybris
# 404 error on watsy0007/devops
# 404 error on wikimedia/mediawiki-extensions-BlueSpiceUEModulePDF
# 404 error on bundestag/ConferenceWeekDetails
# 404 error on LaurieHarding-Russell/Roomba9000
# 404 error on leonLang/Winf
# 404 error on wu-xian/go-learning
# 404 error on MichalFoksa/environment-jx-e1-staging
# 404 error on ktarrant/btscreener
# 404 error on hyperf/framework
# /home/kb7hp/.conda/envs/brandon_env/lib/python3.9/site-packages/bs4/__init__.py:417: MarkupResemblesLocatorWarning: "http://snapbit.org
# " looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# 404 error on PieterBollen87/androidMovieApp
# 404 error on petergarnaes/hopscotch-rust
# 404 error on sportngin-cookbooks/opsworks-puma
# 404 error on Dolphindalt/MLSite
# 404 error on ahmedhosna95/ahmedhosna95.github.io
# 404 error on lucaslrc/Air-BOT-0.1
# 404 error on nasa9084/ident
# 404 error on enjoy-the-science/brain-texts
# 404 error on EMBL-EBI-GCA/faang_dcc
# 404 error on adhocteam/jenkins-library
# 404 error on sQcrm/sqcrm-node-api
# 404 error on dinhnhobao/NUSBuy
# 404 error on VijayalakshmiKumar02/starterkit
# 404 error on hyunkim9123/should
# 404 error on bigminions/bigminions.github.io
# 404 error on sdediego/quantitative-finance
# 404 error on psychelzh/dataprocr
# 404 error on SergeyKarasyov/readings
# 404 error on phantasien/bastian
# 404 error on yb123speed/YBlog
# 404 error on fransiscaandriani/auction-truffle-box404 error on prasannadeep27/prasannadeep27.github.io
#
# 404 error on elevenbuckets/OptractContract
# 404 error on threecast/threecast.github.io
# 404 error on CloudVE/cloudman-helm
# 404 error on mjshorty/asteroids
# 404 error on greenpeace-cee/at.greenpeace.uimods
# 404 error on simplegeo/clusto-sgext404 error on mindcrackx/solorob
#
# 404 error on etomazel/ie421dogsite
# 404 error on nikgoodley-ibboost/forklabs-javaxpcom
# 404 error on frankwang95/frankwang95.github.io
# 404 error on MichaelMiracle/DBLottery
# 404 error on reiser4/spli-g2
# 404 error on pdewan/tools-changedistiller-updated
# 404 error on maniak-dobrii/maniak-dobrii.github.io
# 404 error on What-Up-Games/What-Up-Games.github.io
# 404 error on kdkorthauer/MCC
# 404 error on scola84/node-d3404 error on Y-Innovate/LWZMAKE
#
# 404 error on VALIS-software/valis-typescript-client
# 404 error on venta/routing
# 404 error on gkbrir01/java_qa
# 404 error on init-conference/init-conference.github.io
# 404 error on kernelcase-fiscoflex/erp

# %% [markdown]
# ### Common/Known Errors
#
# Here are some common/known errors that I have identified:
#
# 1. `"MarkupResemblesLocatorWarning: "{slug}" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.`
#
#     Solution: This will just throw a warning and does not seemt to affect subsequent runs of the dataset. You can ignore this.
#
# 2. `KeyError: 'download_url'`
#
#     Solution: It seems like this error can mean one of two things. The first is insignificant and
#
# ### Examining the Dataset
#
# This code just pulls in all of the downloaded data as a DataFrame and sees how many entries we have downloaded already. You can use the commented line to output all the data together.

# %%
os.chdir('/project/class/bii_sdad_dspg/ncses_oss_2021/requests_scrape/')
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
combined_csv = combined_csv[combined_csv['status'] == 'Done']
combined_csv = combined_csv.sort_values("batch")
combined_csv
# 21220 > 53040 now 
# combined_csv.to_csv('/project/class/bii_sdad_dspg/ncses_oss_2021/requests_scrape/oss_readme_aggregated/oss_readme_data_061521.csv', sep=',', encoding='utf-8', index=False)
# Out:
#                                              slug  \
# 172                       h2oota/emacs-win64-msvc
# 240                       Distrotech/mysql-server
# 239            DaichiUeura/Emacs-for-Windows--xj-
# 238                          httpgit12/jb4evea-16
# 237                     Tehsurfer/hugo-contrarian
# ..                                            ...
# 242                       IonPostglacial/treegers
# 243                          TheSavior/PerfectBut
# 244                             kchivorn/angular2
# 224  jeffet/vehicle-manufacture-20180318202618486
# 137                 danielpradilla/version-to-age
#
#                                            readme_text                batch  \
# 172  Copyright (C) 2001-2016 Free Software Foundati...  oss_readme_batch1_1
# 240  MySQL Server 5.6\r\n\r\nThis is a release of M...  oss_readme_batch1_1
# 239  Copyright (C) 2001, 2002, 2003, 2004, 2005, 20...  oss_readme_batch1_1
# 238  <img alt="Swift logo" height="70" src="https:/...  oss_readme_batch1_1
# 237  # Contrarian website\nThis website is the face...  oss_readme_batch1_1
# ..                                                 ...                  ...
# 242            A RTS game using hexagonal grid maps.\n  oss_readme_batch1_9
# 243                                                NaN  oss_readme_batch1_9
# 244  # Angular QuickStart Source\n[![Build Status][...  oss_readme_batch1_9
# 224  # Blockchain - Tutorial\n\nThis is the tutoria...  oss_readme_batch1_9
# 137  # Version To Age (Software Age Gauge)\n\n[![Do...  oss_readme_batch1_9
#
#                    as_of status
# 172        6/11/21 17:21   Done
# 240        6/11/21 17:21   Done
# 239        6/11/21 17:21   Done
# 238        6/11/21 17:21   Done
# 237        6/11/21 17:21   Done
# ..                   ...    ...
# 242  2021-06-14 15:06:23   Done
# 243  2021-06-14 15:06:24   Done
# 244  2021-06-14 15:06:24   Done
# 224  2021-06-14 15:06:23   Done
# 137  2021-06-14 15:06:21   Done
#
# [53040 rows x 5 columns]

# %% [markdown]
# ^ That tells you the number of entries we have downloaded.
#
# ### Development Space
#
# Below, are just some snippets of code that might be useful when tweaking the existing code.

# %%
os.chdir('/project/class/bii_sdad_dspg/ncses_oss_2021/requests_scrape/')
check = pd.read_csv('oss_readme_batch1_8.csv')
check
# Out:
#                                              slug  \
# 0                                 shahabsaf1/copy
# 1                              stephan0992/week-1
# 2     SynapseProject/handlers.ActiveDirectory.net
# 3                               mraggi/discreture
# 4                  karlstroetmann/Lineare-Algebra
# ...                                           ...
# 2174                              pkalro/project8
# 2175                          Tizzio/WifiTransfer
# 2176                      PAPARA-ZZ-I/PAPARA-ZZ-I
# 2177              Capital-T-Industries/docker-elk
# 2178                           volpejoaquin/racer
#
#                                             readme_text                batch  \
# 0     # [InfernalTG](https://telegram.me/TeleInferna...  oss_readme_batch1_8
# 1     # Jekyll Now\n\n**Jekyll** is a static site ge...  oss_readme_batch1_8
# 2     # handlers.ActiveDirectory.net\nActive Directo...  oss_readme_batch1_8
# 3     [![Build Status](https://travis-ci.org/mraggi/...  oss_readme_batch1_8
# 4     Lineare-Algebra\n===============\n\nIn diesem ...  oss_readme_batch1_8
# ...                                                 ...                  ...
# 2174  # angular-seed â€” the seed for AngularJS apps...  oss_readme_batch1_8
# 2175  # WifiTransfer\nDirect wifi file transfer betw...  oss_readme_batch1_8
# 2176  # PAPARA(ZZ)I\nCopyright 2015-2017 Yann Marcon...  oss_readme_batch1_8
# 2177  # The ELK stack (Elasticsearch, Logstash, Kiba...  oss_readme_batch1_8
# 2178  <p align="center">\n<a href="https://github.co...  oss_readme_batch1_8
#
#                     as_of status
# 0     2021-06-14 12:20:52   Done
# 1     2021-06-14 12:20:52   Done
# 2     2021-06-14 12:20:52   Done
# 3     2021-06-14 12:20:52   Done
# 4     2021-06-14 12:20:52   Done
# ...                   ...    ...
# 2174  2021-06-14 12:35:51   Done
# 2175  2021-06-14 12:35:51   Done
# 2176  2021-06-14 12:35:51   Done
# 2177  2021-06-14 12:35:51   Done
# 2178  2021-06-14 12:35:51   Done
#
# [2179 rows x 5 columns]

# %%
# Copy the function from above and make tweaks in this code chunk
combined_csv[combined_csv['readme_text'] == "404 ERROR - NO README"]
# Out:
#                                slug            readme_text  \
# 211      g0v-data/mirror-10minutely  404 ERROR - NO README
# 301  gregorycv/moodle_quiz_extended  404 ERROR - NO README
# 49              sisirkoppaka/fluent  404 ERROR - NO README
# 82           djbender/homebrew-tmux  404 ERROR - NO README
# 43             saidganim/llvm_clone  404 ERROR - NO README
# ..                              ...                    ...
# 278               King19931229/KApp  404 ERROR - NO README
# 281                 tedkulp/phpspec  404 ERROR - NO README
# 221                   Mad9201/T.M.D  404 ERROR - NO README
# 185           davidjhardman/djh-cms  404 ERROR - NO README
# 254             nh4ar/BESI_besilite  404 ERROR - NO README
#
#                    batch                as_of status
# 211  oss_readme_batch1_1        6/11/21 17:21   Done
# 301  oss_readme_batch1_1        6/11/21 17:21   Done
# 49   oss_readme_batch1_1        6/11/21 17:21   Done
# 82   oss_readme_batch1_1        6/11/21 17:21   Done
# 43   oss_readme_batch1_1        6/11/21 17:21   Done
# ..                   ...                  ...    ...
# 278  oss_readme_batch1_9  2021-06-14 15:06:24   Done
# 281  oss_readme_batch1_9  2021-06-14 15:06:24   Done
# 221  oss_readme_batch1_9  2021-06-14 15:06:23   Done
# 185  oss_readme_batch1_9  2021-06-14 15:06:22   Done
# 254  oss_readme_batch1_9  2021-06-14 15:06:24   Done
#
# [2573 rows x 5 columns]

# %%
select_data = combined_csv[combined_csv['readme_text'].notna()]
#select_data['readme_clean'] = select_data['readme_text'].str.lower()
select_data[select_data['readme_text'].str.contains("Blockchain")]
# Out:
#                                                   slug  \
# 449                         flowchain/flowchain-ledger
# 948                               fabiocolacio/Mercury
# 254                     fkbenjamin/pc-firebase-starter
# 1041      peacedudegregoryks/Old-SBC-SocialBenefitCoin
# 758                      mukira/fukoblockchainexplorer
# ...                                                ...
# 1724  agadzinski/vehicle-manufacture-20180607173737101
# 1689  shubhamp1p/vehicle-manufacture-20180606135842485
# 33                 energywebfoundation/ew-did-registry
# 236       jeffet/vehicle-manufacture-20180318192523657
# 224       jeffet/vehicle-manufacture-20180318202618486
#
#                                             readme_text                 batch  \
# 449   # flowchain-ledger\n&gt; Flowchain distributed...  oss_readme_batch1_10
# 948   # Mercury Chat\n\nMercury is my end-to-end enc...  oss_readme_batch1_10
# 254   # PassChain\n\nAuthors: Rob-Jago Flötgen, Flor...  oss_readme_batch1_11
# 1041  # The Social Benefit Coin Smart contract\n \nW...  oss_readme_batch1_11
# 758   # Fuko blockchain Explorer\n\n![GitHub Logo](h...  oss_readme_batch1_11
# ...                                                 ...                   ...
# 1724  # Blockchain - Tutorial\n\nThis is the tutoria...   oss_readme_batch1_8
# 1689  # Blockchain - Tutorial\n\nThis is the tutoria...   oss_readme_batch1_8
# 33    # EW DID Library v0.1\n## Disclaimer\n&gt; The...   oss_readme_batch1_8
# 236   # Blockchain - Tutorial\n\nThis is the tutoria...   oss_readme_batch1_9
# 224   # Blockchain - Tutorial\n\nThis is the tutoria...   oss_readme_batch1_9
#
#                     as_of status
# 449   2021-06-14 15:15:29   Done
# 948   2021-06-14 15:15:38   Done
# 254   2021-06-14 15:19:18   Done
# 1041  2021-06-14 15:19:33   Done
# 758   2021-06-14 15:19:28   Done
# ...                   ...    ...
# 1724  2021-06-14 12:35:40   Done
# 1689  2021-06-14 12:35:40   Done
# 33    2021-06-14 12:20:53   Done
# 236   2021-06-14 15:06:23   Done
# 224   2021-06-14 15:06:23   Done
#
# [124 rows x 5 columns]

# %%
# connect to the database, download data 
connection = pg.connect(host = 'postgis1', database = 'sdad', 
                        user = os.environ.get('db_user'), 
                        password = os.environ.get('db_pwd'))
github_pats = '''SELECT * FROM gh_2007_2020.pats LIMIT 2'''
github_pats = pd.read_sql_query(github_pats, con=connection)
#github_username = github_pats.login[github_pat_index]
#github_token = github_pats.token[github_pat_index]
login_list = github_pats.login.to_list()
token_list = github_pats.token.to_list()

# %%
for github_username, github_token in zip(login_list, token_list):
    print(github_username, github_token)
# Out:
# akindlon977 51f7b11ebd070ebb473d65a5a8f90cdf1c71a3a4
# Azraab c038b80105bebef08d9115cd96243f7a33967352

# %%
@sleep_and_retry
@limits(calls=2500, period=3600)
def scrape_readmes(slug):
    
    while True:
        try: 
            # define url based on the slug 
            url = f'https://api.github.com/repos/{slug}/readme'
            response = requests.get(url, auth=(github_username, github_token))
            response_code = response.status_code
            
            if response_code == 404: 
                print(f"404 error on {slug}")
                readme_string = "404 ERROR - NO README"
                now = datetime.now()
                current_time = now.strftime("%Y-%m-%d %H:%M:%S")
                return slug, readme_string, current_time, "Done"
            
            # can i build in a response_code == 403 continue onto the next PAT in the PAT for loop 
            
        except KeyError:
            print("Key error for: " + slug, flush=True)
            break
        
        except requests.exceptions.HTTPError as http_error:
            print ("HTTP Error:", http_error)
            raise SystemExit(http_error)
            break
            
        except requests.exceptions.ConnectionError as connection_error:
            print ("Error Connecting:", connection_error)
            raise SystemExit(connection_error)
            break 
        
        except requests.exceptions.TooManyRedirects as toomany_requests:
            print ("Too Many Requests:", toomany_requests)
            raise SystemExit(toomany_requests)
            break
                
        except requests.exceptions.Timeout as timeout_error:
            print ("Timeout Error:", timeout_error)
            raise SystemExit(timeout_error)
            break
        
        except requests.exceptions.RequestException as request_exception_error:
                print ("Oops, Some Other Error:", request_exception_error)
                raise SystemExit(request_exception_error)
                break 
            
        html_content = response.content
        soup = BeautifulSoup(html_content, 'html.parser')
        site_json=json.loads(soup.text)
        readme_link = site_json['download_url']
        
        while True:
            try: 
                readme_response = requests.get(readme_link, auth=(github_username, github_token))
                readme_response_code = readme_response.status_code
                
            except requests.exceptions.HTTPError as http_error:
                print ("HTTP Error:", http_error)
                raise SystemExit(http_error)
                break
            
            except requests.exceptions.ConnectionError as connection_error:
                print ("Error Connecting:", connection_error)
                raise SystemExit(connection_error)
                break
            
            except requests.exceptions.TooManyRedirects as toomany_requests:
                print ("Too Many Requests:", toomany_requests)
                raise SystemExit(toomany_requests)
                break 
        
            except requests.exceptions.Timeout as timeout_error:
                print ("Timeout Error:", timeout_error)
                raise SystemExit(timeout_error)
                break
        
            except requests.exceptions.RequestException as request_exception_error:
                print ("Oops, Some Other Error:", request_exception_error)
                raise SystemExit(request_exception_error)
                break  
    
            # pull the content out of the readme 
            readme_content = readme_response.content
            readme_soup = BeautifulSoup(readme_content, 'html.parser')
            readme_string = str(readme_soup)
    
            #give us the the timing and status 
            now = datetime.now()
            current_time = now.strftime("%Y-%m-%d %H:%M:%S")
            #print(readme_string)
            return slug, readme_string, current_time, "Done"
    
if __name__ == "__main__":
    print("Started scraping")
    scrape_readmes(slug = 'cjbd/src')
    print("Finished scraping")
# Out:
# Started scraping
# 404 error on cjbd/src
# Finished scraping

# %%
test_slugs = ["brandonleekramer/diversity", 
              'cjbd/src'
              "uva-bi-sdad/oss-2020", 
              "facebook/react", 
              "RichardLitt/standard-readme",            
]

tmp_username = os.environ['GITHUB_USERNAME'] = 'brandonleekramer'
tmp_token = os.environ['GITHUB_TOKEN'] = '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'

# need to change this for each batch or you will save over what you had  
batch_name_test = "nothing"
cores_available = multiprocessing.cpu_count() - 1
pool = Pool(cores_available)

slug_log = []
readme_log = []
asof_log = []
status_log = []

for github_username, github_token in zip(login_list, token_list): 
    
    test_slugs = filter_scraped_readmes(original_data = test_slugs)
    
    for result in pool.imap_unordered(scrape_readmes, test_slugs):
        slug_log.append(result[0])
        readme_log.append(result[1])
        asof_log.append(result[2])
        status_log.append(result[3])
        final_log = pd.DataFrame({'slug': slug_log, "readme_text": readme_log, 
                                  'batch': batch_name_test, 'as_of': asof_log, 'status': status_log}, 
                                  columns=["slug", "readme_text", "batch", "as_of", "status"])
    print("Finished scraping", len(final_log), "of", len(test_slugs), "records", "using", github_username)
# Out:
# Current data has 24729 entries (filtered 3247 from input data)
# 404 error on id
# 404 error on slug
# 404 error on branch
# 404 error on status
# 404 error on primarylanguage
# 404 error on commits
# 404 error on createdat
# 404 error on description
# 404 error on spdx
# 404 error on asof
# Finished scraping 10 of 24729 records using akindlon977
# Current data has 24729 entries (filtered 3247 from input data)
# 404 error on description
# 404 error on slug
# 404 error on primarylanguage
# 404 error on status
# 404 error on id
# 404 error on createdat
# 404 error on commits
# 404 error on asof
# 404 error on branch
# 404 error on spdx
# Finished scraping 20 of 24729 records using Azraab

# %%
for github_username, github_token in zip(login_list, token_list): 
    check_this = filter_scraped_readmes(original_data = raw_slug_data)
    # now you need to add +=1 to the batch name when sending the output 

print(raw_slug_data['slug'].count(), check_this['slug'].count())
# Out:
# Current data has 24729 entries (filtered 3247 from input data)
# Current data has 24729 entries (filtered 3247 from input data)
# 27976 24729

# %%
check
# Out:
#                                      id        spdx  \
# 1      MDEwOlJlcG9zaXRvcnk4NTk0MjE4NQ==  Apache-2.0
# 2      MDEwOlJlcG9zaXRvcnkxMjM2NDM5MDM=         MIT
# 3      MDEwOlJlcG9zaXRvcnkyNjIzNzk0NQ==  Apache-2.0
# 4      MDEwOlJlcG9zaXRvcnk0Mjg2NDg0Nw==     GPL-2.0
# 5      MDEwOlJlcG9zaXRvcnkyNzQxNDY1Mjc=     GPL-3.0
# ...                                 ...         ...
# 27953  MDEwOlJlcG9zaXRvcnkxNDk3MzI1OTc=         MIT
# 27954  MDEwOlJlcG9zaXRvcnk2NDI4MTg5Mw==         MIT
# 27955  MDEwOlJlcG9zaXRvcnkyNjkxMjc0NA==         MIT
# 27956  MDEwOlJlcG9zaXRvcnkxMzA3Njg4NDg=         MIT
# 27957  MDEwOlJlcG9zaXRvcnkyMjQwNTIyMTQ=         MIT
#
#                               slug           createdat  \
# 1                 crain/accounting 2017-03-23 11:29:26
# 2         knicholson32/MicroServer 2018-03-03 00:08:16
# 3                rranshous/flannel 2014-11-05 20:19:19
# 4                ToqueWillot/M2DAC 2015-09-21 12:27:22
# 5             greenmanish05/morish 2020-06-22 13:35:53
# ...                            ...                 ...
# 27953             sosohime/topfeed 2018-09-21 08:19:40
# 27954    Su-hyun/Su-hyun.github.io 2016-07-27 06:08:40
# 27955  zerodine/angular-restclient 2014-11-20 13:07:35
# 27956            sarcoma/Invoicing 2018-04-23 23:34:23
# 27957                   nabsh/blog 2019-11-25 22:18:59
#
#                                              description   primarylanguage  \
# 1      Microservice for managing accounts, ledgers, a...              Java
# 2       Javascript Websocket server for the Micro Editor        JavaScript
# 3                                                   None                Go
# 4      Set of projects for the first semester of the ...  Jupyter Notebook
# 5                                                   None        JavaScript
# ...                                                  ...               ...
# 27953      Full stack framework built with Koa && React         TypeScript
# 27954                                          myProject               CSS
# 27955  Angular-restclient is a angular module to help...              HTML
# 27956  Console script for creating quotes and invoice...            Python
# 27957                                               None             Shell
#
#                                              branch  commits  \
# 1      MDM6UmVmODU5NDIxODU6cmVmcy9oZWFkcy9kZXZlbG9w      105
# 2      MDM6UmVmMTIzNjQzOTAzOnJlZnMvaGVhZHMvbWFzdGVy      105
# 3      MDM6UmVmMjYyMzc5NDU6cmVmcy9oZWFkcy9tYXN0ZXI=      105
# 4      MDM6UmVmNDI4NjQ4NDc6cmVmcy9oZWFkcy9tYXN0ZXI=      105
# 5      MDM6UmVmMjc0MTQ2NTI3OnJlZnMvaGVhZHMvbWFzdGVy      105
# ...                                             ...      ...
# 27953  MDM6UmVmMTQ5NzMyNTk3OnJlZnMvaGVhZHMvbWFzdGVy      105
# 27954  MDM6UmVmNjQyODE4OTM6cmVmcy9oZWFkcy9tYXN0ZXI=      105
# 27955  MDM6UmVmMjY5MTI3NDQ6cmVmcy9oZWFkcy9tYXN0ZXI=      105
# 27956  MDM6UmVmMTMwNzY4ODQ4OnJlZnMvaGVhZHMvbWFzdGVy      105
# 27957  MDM6UmVmMjI0MDUyMjE0OnJlZnMvaGVhZHMvbWFzdGVy      105
#
#                      asof status
# 1     2021-01-03 13:53:22   Done
# 2     2021-01-03 18:57:20   Done
# 3     2021-01-03 22:58:12   Done
# 4     2021-01-03 17:59:15   Done
# 5     2021-01-03 13:55:07   Done
# ...                   ...    ...
# 27953 2021-01-03 13:56:39   Done
# 27954 2021-01-03 15:24:54   Done
# 27955 2021-01-03 20:41:20   Done
# 27956 2021-01-03 19:21:49   Done
# 27957 2021-01-04 04:41:02   Done
#
# [24729 rows x 10 columns]
