# %%
import os 
import glob
import json 
import lxml
import requests 
from requests.auth import HTTPBasicAuth
from bs4 import BeautifulSoup
from datetime import datetime
import psycopg2 as pg
from sqlalchemy import create_engine
import pandas as pd
from ratelimit import limits, sleep_and_retry
import multiprocessing
from multiprocessing.pool import ThreadPool as Pool
print("ready")
# Out:
# ready

# %%
github_username = os.environ.get("GITHUB_USERNAME")
github_token = os.environ.get("GITHUB_TOKEN")

# can only make 2500 calls per hour 
# because the function calls twice each time 
PER_HOUR = 3600

@sleep_and_retry
@limits(calls=2500, period=PER_HOUR)
def scrape_readmes(slug):
    
    # define url based on the slug 
    url = f'https://api.github.com/repos/{slug}/readme'
    response = requests.get(url, auth=(github_username, github_token))
    
    response_code = response.status_code
    if response_code == 404: 
        print(f"404 error on {slug}")
        readme_string = "404 ERROR - NO README"
        now = datetime.now()
        current_time = now.strftime("%Y-%m-%d %H:%M:%S")
        return slug, readme_string, current_time, "Done"
    
    elif response_code == 403:
        now = datetime.now()
        current_time = now.strftime("%Y-%m-%d %H:%M:%S")
        return print(f"403 error on {slug} at {current_time}")
        
    elif response_code != 200:
        raise Exception(response.status_code, response.text)
        return 
    
    elif response_code == 200:
        html_content = response.content
        soup = BeautifulSoup(html_content, 'html.parser')
        site_json=json.loads(soup.text)
        readme_link = site_json['download_url']
    
        # then scrape the readme 
        readme_response = requests.get(readme_link, auth=(github_username, github_token))
        readme_response_code = readme_response.status_code
        if readme_response_code != 200:
            raise Exception(readme_response_code.status_code, readme_response_code.text)
            return 
    
        # pull the content out of the readme 
        readme_content = readme_response.content
        readme_soup = BeautifulSoup(readme_content, 'html.parser')
        readme_string = str(readme_soup)
    
        #give us the the timing and status 
        now = datetime.now()
        current_time = now.strftime("%Y-%m-%d %H:%M:%S")
        #print(html_content)
        return slug, readme_string, current_time, "Done"
    

if __name__ == "__main__":
    print("Started scraping")
    scrape_readmes(slug = 'brandonleekramer/diversity')
    print("Finished scraping")
# Out:
# Started scraping
# Finished scraping

# %%
# connect to the database, download data 
connection = pg.connect(host = 'postgis1', database = 'sdad', 
                        user = os.environ.get('db_user'), 
                        password = os.environ.get('db_pwd'))

raw_slug_data = '''SELECT * FROM gh_2007_2020.repos_ranked where commits < 500 AND commits > 150 AND status != 'Init' '''

# convert to a dataframe, show how many missing we have (none)
raw_slug_data = pd.read_sql_query(raw_slug_data, con=connection)
raw_slug_data.head()
# Out:
#                                  id        spdx  \
# 0  MDEwOlJlcG9zaXRvcnk0Njc0ODc5Ng==     GPL-2.0
# 1  MDEwOlJlcG9zaXRvcnkyMDU4Mjg0MzE=         MIT
# 2  MDEwOlJlcG9zaXRvcnkxNzI2NDY0MDM=  Apache-2.0
# 3  MDEwOlJlcG9zaXRvcnkxNDE4Mzc4OTA=         MIT
# 4  MDEwOlJlcG9zaXRvcnkzNjE2NTcwNQ==         MIT
#
#                                     slug           createdat  \
# 0                         jfbvm/planigle 2015-11-23 21:22:29
# 1  madscatter/gatsby-starter-netlify-cms 2019-09-02 10:00:38
# 2                   dm1090/friendly-chat 2019-02-26 05:47:44
# 3  Younes-Charfaoui/Daily-Coding-Problem 2018-07-21 18:44:57
# 4                         Rplus/dev-pool 2015-05-24 09:50:47
#
#                                          description primarylanguage  \
# 0  Automatically exported from code.google.com/p/...            Ruby
# 1                                               None      JavaScript
# 2                Google's code lab with enhancements      JavaScript
# 3  Series of the problem 💯 and solution ✅ asked b...          Python
# 4                                               None             CSS
#
#                                          branch  commits                asof  \
# 0  MDM6UmVmNDY3NDg3OTY6cmVmcy9oZWFkcy9tYXN0ZXI=      465 2021-01-03 18:56:55
# 1  MDM6UmVmMjA1ODI4NDMxOnJlZnMvaGVhZHMvbWFzdGVy      465 2021-01-03 14:34:50
# 2  MDM6UmVmMTcyNjQ2NDAzOnJlZnMvaGVhZHMvbWFzdGVy      465 2021-01-03 20:10:09
# 3  MDM6UmVmMTQxODM3ODkwOnJlZnMvaGVhZHMvbWFzdGVy      465 2021-01-03 21:45:05
# 4  MDM6UmVmMzYxNjU3MDU6cmVmcy9oZWFkcy9tYXN0ZXI=      465 2021-01-03 22:22:35
#
#   status
# 0   Done
# 1   Done
# 2   Done
# 3   Done
# 4   Done

# %%
#raw_slug_data = raw_slug_data[raw_slug_data['slug'] != 'cjbd/src']
raw_slug_data['slug'].count()
# Out:
# 4866

# %%
os.chdir('/project/class/bii_sdad_dspg/ncses_oss_2021/requests_scrape/')
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
combined_csv = combined_csv[combined_csv['status'] == 'Done']
already_scraped_slugs = combined_csv['slug'].tolist()
filtered_slugs = ~raw_slug_data.slug.isin(already_scraped_slugs)
filtered_slugs = raw_slug_data[filtered_slugs]
filtered_slugs.head()
filtered_slugs['slug'].count()
# Out:
# 1529

# %%
raw_slugs = filtered_slugs["slug"].tolist()
slugs = []
for s in raw_slugs:
    slugs.append(s.strip())

# %%
# need to change this for each batch or you will save over what you had  
batch_name = 'oss_readme_batch1_8' 
cores_available = multiprocessing.cpu_count() - 1
pool = Pool(cores_available)

slug_log = []
readme_log = []
asof_log = []
status_log = []
for result in pool.imap_unordered(scrape_readmes, slugs):
    slug_log.append(result[0])
    readme_log.append(result[1])
    asof_log.append(result[2])
    status_log.append(result[3])
    final_log = pd.DataFrame({'slug': slug_log, "readme_text": readme_log, 'batch': batch_name, 'as_of': asof_log, 'status': status_log}, 
                              columns=["slug", "readme_text", "batch", "as_of", "status"])
    final_log.to_csv('/project/class/bii_sdad_dspg/ncses_oss_2021/requests_scrape/'+batch_name+'.csv', sep=',', encoding='utf-8', index=False)
print("Finished scraping", len(final_log), "of", len(slugs), "records")
# Out:
# 404 error on crtaylor243/forestry-eval
# 404 error on Mishagta567/Job4j_avasiliev2M
# 404 error on 55011212042/rsc
# 404 error on AxelTidehorn/The-wall
# 404 error on jc00ke/mongoose
# 404 error on mengzhuo/rsc
# 404 error on Timwi/KtaneStuff404 error on ericmbudd/wardogs
#
# 404 error on Meeds-io/gatein-sso
# 404 error on vahidma/TGRoot404 error on thadd3us/quickdic-dictionary.dictionary
#
# 404 error on batandwa/just-the-video
# 404 error on alsfghlasfhgafshg/huahui
# 404 error on idega/com.idega.block.text
# 404 error on Pholenk/siakad
# 404 error on juga0/doctor
# 404 error on amoschov/webstart-maven-plugin
# 404 error on THEGAYUK/news
# 404 error on aliyoussefi/BAST306T-Source
# 404 error on whentze/Power-Defense
# 404 error on codistmonk/TransFile
# 404 error on gonrin/GonrinUI
# 404 error on gustavosr98/UCAB07-BasesII-Proyecto
# 404 error on Gloryofthe80s/gatsby-starter-netlify-cms
# 404 error on Mioze7Ae/android_tools_repo
# 404 error on tudor-berariu/lifelong-learning
# 404 error on usco/web-slicer-ui
# 404 error on Katushe/phase-0
# 404 error on erin-test-things/metacoin
# 404 error on MaxIakovliev/problemSolving
# 404 error on rubima13/jsmpp
# 404 error on a-roy/pacman-mp
# 404 error on davidechiappetta/atalan
# 404 error on Nusantara-ROM/android_external_pulse
# 404 error on mstearnsa/markers-for-android
# 404 error on stardreamer79/markers-for-android
# 404 error on Mathieu-Desrochers/Scheme-Experimentations
# 404 error on lachupe/pandoramapper
# 404 error on UnholyDevs/packages_apps_DUI
# 404 error on BurningFlipside/Registration
# 404 error on alacosta10/one-click-hugo-cms
# 404 error on kamikaz-e/schedule_ystu
# 404 error on PauloBarrantes/Tarea1-Redes
# 404 error on gt-ros-pkg/hrl_autobed_dev
# 404 error on DavidOKeefe/phase-0
# 404 error on jayxtt999/me
# 404 error on agryski/livingwithlessplastic
# 404 error on d-sanderson/dsanderson90.github.io404 error on danzeeeman/makeitdoathing
#
# 404 error on geebee/lemonbar-xft
# 404 error on mpeng/coreui
# 404 error on reduzent/tpf-client
# 404 error on Sage-Bionetworks/Psorcast-iOS
# 404 error on cjbd/openscreen
# 404 error on google-code-export/jcrom
# 404 error on mrmoss/aurora_forecast
# 404 error on asgardphp/core
# 404 error on stevedonovan/gentle-intro
# 404 error on Fraktalis/caterpillapp-android404 error on Selvatico/declaration-is-broken
#
# 404 error on codingbunnys/coolnessbot
# 404 error on ottobehrens/gemstone-scripts
# 404 error on TakuyaNoguchi/yukicoder
# 404 error on snowaver/squirrel-parent
# 404 error on arafsheikh/spm-project-samarpan
# 404 error on MIS-DBMS/mis-dbms
# 404 error on SKhakhulin/test
# 404 error on nghthanhtam/BookStoreManagementWeb
# 404 error on Maroslav/DataStructures404 error on axialmarket/fsq
#
# 404 error on amitmu/utsov
# 404 error on meliorframework/melior
# 404 error on huayun321/aixin
# 404 error on Team-Apple/GenCon
# 404 error on JeffersonLab/PRadAnalyzer
# 404 error on vladfr/wefightwithcards
# 404 error on abhinpai/Google-Training
# 404 error on mimosa-project/emwiki
# 404 error on pgarciaper/boolean
# 404 error on asfdfdfd/fceuxq
# 404 error on JanetMatsen/meta4_bins_janalysis
# 404 error on GyrosGeier/trees
# 404 error on luckywqf/leetcode
# 404 error on sociospatial/sociospatial.github.io
# 404 error on Heintzdm/phase-0
# 404 error on NOAA-EMC/fv3atm
# 404 error on metaborg/spoofax-maven
# 404 error on askworkshop/ask2019
# 404 error on yoo16/project-manager
# 404 error on B3Partners/flamingo-mob
# 404 error on meego-tablet-ux/meego-app-tasks
# 404 error on stefanjauker/libuv-java
# 404 error on Simpreative/WebSockChat
# 404 error on horde/Service_Twitter
# 404 error on linKhehe/Zane
# 404 error on GregHib/interface-editor
# 404 error on lmnleaf/mini_notes
# 404 error on lucasmayoni/angulartest
# 403 error on Opiumtm/Imageboard10 at 2021-06-14 12:35:51
# 403 error on gsemet/pyyaml at 2021-06-14 12:35:51
# 403 error on cornerman/sloth at 2021-06-14 12:35:51403 error on smadha/MlTrio at 2021-06-14 12:35:51
#
# 403 error on cshinaver/Projects-Java at 2021-06-14 12:35:51
# 403 error on nickverma/frontend-developer at 2021-06-14 12:35:51
# 403 error on rubencherbit/samsung-etoile-de-martin at 2021-06-14 12:35:51
# 403 error on obatiuk/dotfiles at 2021-06-14 12:35:51
# 403 error on DMXMax/resume at 2021-06-14 12:35:51
# 403 error on JuliaPackageMirrors/GLFW.jl at 2021-06-14 12:35:51403 error on GroundhogLighting/emp_core at 2021-06-14 12:35:51
#
# 403 error on leonriel/ubuild-jekyll at 2021-06-14 12:35:51
# 403 error on choishingwan/shrek at 2021-06-14 12:35:51403 error on Nikhil1819/autodesk at 2021-06-14 12:35:51403 error on eddiebeazer/gatsby-starter-netlify-cms at 2021-06-14 12:35:52403 error on pemstack/fullstack-template at 2021-06-14 12:35:52403 error on stevenmoks/light7-cn at 2021-06-14 12:35:52
#
#
#
#
# 403 error on mathsq/mathsq.github.io at 2021-06-14 12:35:52403 error on ev3dev/umockdev at 2021-06-14 12:35:52403 error on leejieun51/transformer at 2021-06-14 12:35:52
#
# 403 error on jerrwu/not_Snapchat at 2021-06-14 12:35:52403 error on spillerrec/BooruSurfer2 at 2021-06-14 12:35:52
#
# 403 error on smcllns/css-social-buttons at 2021-06-14 12:35:52403 error on MCMrARM/chatlib at 2021-06-14 12:35:52403 error on FordyceLab/tessellate at 2021-06-14 12:35:52
#
# 403 error on Dr0virus/virusseed at 2021-06-14 12:35:52
# 403 error on rubrikinc/welcome-to-rubrik-build at 2021-06-14 12:35:52
#
# 403 error on perry-mitchell/iocane at 2021-06-14 12:35:52403 error on techascent/tech.netcdf at 2021-06-14 12:35:52403 error on Deprecated-Kode/haxe-formatter at 2021-06-14 12:35:52403 error on mtransitapps/ca-london-transit-bus-android at 2021-06-14 12:35:52403 error on MicheleBertoli/css-in-js at 2021-06-14 12:35:52
#
#
# 403 error on conda-forge/asammdf-feedstock at 2021-06-14 12:35:52
#
#
#
# 403 error on ComputationalRadiationPhysics/pyDive at 2021-06-14 12:35:52403 error on p0nce/dido at 2021-06-14 12:35:52
#
# 403 error on larsaurdal/docker-python1 at 2021-06-14 12:35:52
# 403 error on moscajs/aedes-persistence-redis at 2021-06-14 12:35:52
# 403 error on AGHG46087/clubnode at 2021-06-14 12:35:52
# 403 error on GeoNode/geonode-live at 2021-06-14 12:35:52403 error on hankhank/exys at 2021-06-14 12:35:52
# 403 error on lweckeck/albo at 2021-06-14 12:35:52403 error on cseoighe/StopEvol at 2021-06-14 12:35:52
#
# 403 error on blacknewn/brow at 2021-06-14 12:35:52
# 403 error on eliecerthoms/gatsby-starter-netlify-cms at 2021-06-14 12:35:52403 error on johnhof/fleek-router at 2021-06-14 12:35:52
#
# 403 error on gaofp/plotly_express at 2021-06-14 12:35:52403 error on sharemind-sdk/libexecutable at 2021-06-14 12:35:52
#
# 403 error on thehyve/transmart-core-api at 2021-06-14 12:35:52403 error on mohsenfreeappbot/Mohsen_free_app at 2021-06-14 12:35:52
# 403 error on jordanbtucker/dpapick at 2021-06-14 12:35:52
# 403 error on linchpin/courier-notices at 2021-06-14 12:35:52
#
#
# 403 error on ChristofferFlensburg/superFreq at 2021-06-14 12:35:52403 error on GurifYuanin/three-particle at 2021-06-14 12:35:52403 error on markperez1904/prismic-tutorial at 2021-06-14 12:35:52
# 403 error on ethanlim/ccmf-node at 2021-06-14 12:35:52
#
#
# 403 error on machines-in-motion/dynamic_graph_manager at 2021-06-14 12:35:52403 error on gisce/empowering at 2021-06-14 12:35:52403 error on hpcdev/xylose at 2021-06-14 12:35:52403 error on adamfairholm/PyroSnippets at 2021-06-14 12:35:52
#
#
# 403 error on scottwedge/CTensor at 2021-06-14 12:35:52403 error on ivankayzer/gielda-gier at 2021-06-14 12:35:52
# 403 error on consulo/consulo-maven at 2021-06-14 12:35:52
#
# 403 error on BaptisteBriois/face_emotions at 2021-06-14 12:35:52
# 403 error on gangyou/kitarin-web at 2021-06-14 12:35:52
#
# 403 error on ssisaias/magnolia-core at 2021-06-14 12:35:52
# 403 error on ekszz/OurAcm at 2021-06-14 12:35:52
# 403 error on CHH/pipe at 2021-06-14 12:35:52403 error on jeremy091/SOEN423_Project at 2021-06-14 12:35:52403 error on blairconrad/dicognito at 2021-06-14 12:35:52
#
#
# 403 error on lockys/gae-django-skeleton at 2021-06-14 12:35:52
# 403 error on EcoJulia/Mangal.jl at 2021-06-14 12:35:52403 error on alexdkaminski/one-click-hugo-cms at 2021-06-14 12:35:52
# 403 error on Distrotech/Apache-SizeLimit at 2021-06-14 12:35:52403 error on swelect/onepage-jekyll at 2021-06-14 12:35:52403 error on grishmacontractor/one-click-hugo-cms at 2021-06-14 12:35:52
#
#
#
# 403 error on NIS-2018-CROSS-M/cross-lingual-morph-analysis at 2021-06-14 12:35:52403 error on shifengsuisha/kaiju-1.7.3-linux-x86_64.tar.gz at 2021-06-14 12:35:52
# 403 error on Autodesk-Forge/forge-digital-twin at 2021-06-14 12:35:52403 error on CUAHSI/Azure-Hydroservertools at 2021-06-14 12:35:52403 error on mostafa1382/plane_bot at 2021-06-14 12:35:52
#
#
# 403 error on bruel-gabrielsson/MobileMindfulness at 2021-06-14 12:35:52
# 403 error on blackguard3/blackguard at 2021-06-14 12:35:52403 error on mahdi-jannati/zede_spam at 2021-06-14 12:35:52
#
#
# 403 error on rajhraval1/My100DaysOfSwift at 2021-06-14 12:35:52403 error on NickBranstein/Nomis2 at 2021-06-14 12:35:52403 error on Robotslam/ros-workspace at 2021-06-14 12:35:52
# 403 error on tuananh-vn/clone_datalab at 2021-06-14 12:35:52403 error on telegramxmanbot/m at 2021-06-14 12:35:52403 error on Kalcode/gatsby-starter-netlify-cms at 2021-06-14 12:35:52
#
#
# 403 error on pouya-joker/Telecat at 2021-06-14 12:35:52403 error on abrasseu/lo21-projet at 2021-06-14 12:35:52403 error on mporcheron/co-curator at 2021-06-14 12:35:52
# 403 error on kiarash14/llll-k at 2021-06-14 12:35:52
#
#
#
# 403 error on forceprojets/forceprojets.github.io at 2021-06-14 12:35:52
# 403 error on sina1380/amaabot at 2021-06-14 12:35:52403 error on SAEONData/deploy-thredds at 2021-06-14 12:35:52
#
# 403 error on suzanasvm/SmileFace at 2021-06-14 12:35:52
#
# 403 error on panos3oesp/sxolikosfylakas at 2021-06-14 12:35:52
# 403 error on ProboCI/probo-image-builder at 2021-06-14 12:35:52
# 403 error on baptiste-bordet/heroku-angular-seed at 2021-06-14 12:35:52403 error on BostonGlobe/charts at 2021-06-14 12:35:52403 error on neylemke/neylemke.github.io at 2021-06-14 12:35:52
# 403 error on php-xapi/xapi-model at 2021-06-14 12:35:52
#
# 403 error on mpaulweeks/double-biscuit at 2021-06-14 12:35:52
#
# 403 error on gemrb/iesh at 2021-06-14 12:35:52
# 403 error on eduardoportilho/testing-workshop at 2021-06-14 12:35:52
# 403 error on manishrc/apify-act-crawler-test at 2021-06-14 12:35:53403 error on makseq/testarium at 2021-06-14 12:35:53
#
# 403 error on skamz/postal_server at 2021-06-14 12:35:53403 error on nsomar/Guaka at 2021-06-14 12:35:53
#
# 403 error on barclayadam/blueprint at 2021-06-14 12:35:53403 error on fanmuzhi/UFT at 2021-06-14 12:35:53
#
# 403 error on ology/Music-Intervals at 2021-06-14 12:35:53
# 403 error on ShaneQi/ZEGBot at 2021-06-14 12:35:53403 error on allinreality/webxrsamples at 2021-06-14 12:35:53
#
# 403 error on alisaha80/megabot at 2021-06-14 12:35:53403 error on UMM-CSci-3601-F19/lab-1-kedrick-and-waller at 2021-06-14 12:35:53403 error on emmasax/angular-demo at 2021-06-14 12:35:53
#
# 403 error on jordivila/Net_MVC_NLayer_Result at 2021-06-14 12:35:53
#
# 403 error on JeffreyWay/Laravel-4-Generators at 2021-06-14 12:35:53403 error on jasny/db-mongo at 2021-06-14 12:35:53403 error on LemonPi/benchtracker at 2021-06-14 12:35:53403 error on Concussion-Studios/tfcs-assets at 2021-06-14 12:35:53403 error on TheClimateCorporation/claypoole at 2021-06-14 12:35:53
#
#
# 403 error on fedora-iot/zezere at 2021-06-14 12:35:53
# 403 error on jasonsnider/tinker-mvc at 2021-06-14 12:35:53
# 403 error on 1001hz/ng6 at 2021-06-14 12:35:53403 error on jokeralish/robot at 2021-06-14 12:35:53403 error on falko0000/moduleEProc at 2021-06-14 12:35:53403 error on michaelsharpe/inconnu-2 at 2021-06-14 12:35:53
# 403 error on tud-ccc/riscv-custom-extension at 2021-06-14 12:35:53
#
# 403 error on thaerkh/vim-workspace at 2021-06-14 12:35:53403 error on gscales/Exch-Rest at 2021-06-14 12:35:53
# 403 error on jsfowles/gatsby-starter at 2021-06-14 12:35:53
#
#
# 403 error on GuillemD/PendingNameEngine-3D at 2021-06-14 12:35:53
#
#
# 403 error on Kribrain/one-click-hugo-cms at 2021-06-14 12:35:53403 error on The-Reading-Exchange/TheReadingExchange at 2021-06-14 12:35:53
# 403 error on CRKatri/ldid at 2021-06-14 12:35:53
#
# 403 error on danielpradilla/version-to-age at 2021-06-14 12:35:53403 error on iawells/networking-vpp at 2021-06-14 12:35:53
# 403 error on saybuser/FD-SAT-Plan at 2021-06-14 12:35:53403 error on uwex-learning-tech/gvp at 2021-06-14 12:35:53
#
# 403 error on deevroman/WOW at 2021-06-14 12:35:53
# 403 error on CoffeeChou/CoffeeChou.github.io at 2021-06-14 12:35:53
#
# 403 error on TeleDALAD/spam at 2021-06-14 12:35:53403 error on obsrvbl/flowlogs-reader at 2021-06-14 12:35:53
# 403 error on YeOldeDM/lets-godot-roguelike at 2021-06-14 12:35:53403 error on pirhoo/iframe-scaffolder at 2021-06-14 12:35:53
# 403 error on coldserenity/tij4-exercises at 2021-06-14 12:35:53
#
#
# 403 error on eendroroy/twitterz.api at 2021-06-14 12:35:53
#
# 403 error on mixalturek/anotherfsm at 2021-06-14 12:35:53403 error on vossjo/ase-espresso at 2021-06-14 12:35:53
#
# 403 error on tspivey/books at 2021-06-14 12:35:53
# 403 error on byung-u/byung-u.github.io at 2021-06-14 12:35:53403 error on kigster/makeabox at 2021-06-14 12:35:53403 error on michaelfangman/portfolio-grav at 2021-06-14 12:35:53
# 403 error on pbehseta/sample-cloud-native-toolchain-tutorial-20180321213717021 at 2021-06-14 12:35:53
#
# 403 error on hfjgjfg/rsm20 at 2021-06-14 12:35:53403 error on olebedev/go-duktape at 2021-06-14 12:35:53403 error on Tejal011089/digitales_frappe_bench at 2021-06-14 12:35:53403 error on MaciejSzulc1/WatsonOnlineStore-old at 2021-06-14 12:35:53403 error on Amsterdam/basiskaart at 2021-06-14 12:35:53
# 403 error on wallclockbuilder/stringutil at 2021-06-14 12:35:53
#
# 403 error on scrumdaybrazil/scrum-day-short at 2021-06-14 12:35:53
#
#
# 403 error on razorpay/razorpay-php at 2021-06-14 12:35:53403 error on NESCent/pmdb at 2021-06-14 12:35:53403 error on wholladay/directives at 2021-06-14 12:35:53
# 403 error on davidjhardman/djh-cms at 2021-06-14 12:35:53
#
#
# 403 error on alxndrwllmsn/inverse-pfb at 2021-06-14 12:35:53
# 403 error on frihaka/deltaRpkm at 2021-06-14 12:35:53
# 403 error on fritz-c/one-click-hugo-cms at 2021-06-14 12:35:53
#
# 403 error on KotlinNLP/TokensEncoder at 2021-06-14 12:35:53403 error on eulegang/romulus at 2021-06-14 12:35:53403 error on buttonwoodcx/bcx-validation at 2021-06-14 12:35:53403 error on digiah/memberconnect at 2021-06-14 12:35:53
# 403 error on Hwesta/advent-of-code at 2021-06-14 12:35:53
# 403 error on giantomakin/presentation at 2021-06-14 12:35:53403 error on abasshacker/abbas00 at 2021-06-14 12:35:53
#
#
# 403 error on neben/pep at 2021-06-14 12:35:53403 error on LuckyJustCoder/ShikimoriFix at 2021-06-14 12:35:53403 error on GriffinSchneider/DRYUI at 2021-06-14 12:35:53
#
#
#
#
# 403 error on feiser2016/Heimdall at 2021-06-14 12:35:53
# 403 error on eightlittlebits/elbsms at 2021-06-14 12:35:53
# 403 error on nihlaeth/dnd at 2021-06-14 12:35:53
#
# 403 error on metabrainz/artwork-redirect at 2021-06-14 12:35:53403 error on electerious/rosid-handler-js at 2021-06-14 12:35:53
# 403 error on manhnt9/illusion at 2021-06-14 12:35:53403 error on tomix86/hpcpm at 2021-06-14 12:35:53
#
#
# 403 error on paazmaya/image-duplicate-remover at 2021-06-14 12:35:53
# 403 error on Modeso/ModesoNavigationTabs at 2021-06-14 12:35:53
# 403 error on asw3asw/M- at 2021-06-14 12:35:53
# 403 error on collinscraig/one-click-hugo-cms at 2021-06-14 12:35:53
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-117-0f61c9e36414> in <module>
#       9 status_log = []
#      10 for result in pool.imap_unordered(scrape_readmes, slugs):
# ---> 11     slug_log.append(result[0])
#      12     readme_log.append(result[1])
#      13     asof_log.append(result[2])
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# ### Batch Monitoring
#
# https://docs.google.com/spreadsheets/d/1GJNa0yt_CnBmMTIxKVVFJnZT9cmK7Lt0I7Id88LhQTQ/edit#gid=0

# %%
os.chdir('/project/class/bii_sdad_dspg/ncses_oss_2021/requests_scrape/')
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
combined_csv = combined_csv[combined_csv['status'] == 'Done']
combined_csv = combined_csv.sort_values("batch")
combined_csv.count()
#combined_csv.to_csv('/project/class/bii_sdad_dspg/ncses_oss_2021/requests_scrape/oss_readme_aggregated/oss_readme_data_061521.csv', sep=',', encoding='utf-8', index=False)
# Out:
# slug           6207
# readme_text    6189
# batch          6207
# as_of          6207
# status         6207
# dtype: int64
# 404 error on david95thinkcode/pharmawine-android
# 404 error on srujankumar/cell-structure
# 404 error on fletaio/deprecated_framework
# 404 error on zhangwei5095/commons-el
# 404 error on ASStoredProcedures/ASStoredProcedures

# %%
os.chdir('/project/class/bii_sdad_dspg/ncses_oss_2021/requests_scrape/')
check = pd.read_csv('oss_readme_batch1_8.csv')
check
# Out:
#                                              slug  \
# 0                                 shahabsaf1/copy
# 1                              stephan0992/week-1
# 2     SynapseProject/handlers.ActiveDirectory.net
# 3                               mraggi/discreture
# 4                  karlstroetmann/Lineare-Algebra
# ...                                           ...
# 2174                              pkalro/project8
# 2175                          Tizzio/WifiTransfer
# 2176                      PAPARA-ZZ-I/PAPARA-ZZ-I
# 2177              Capital-T-Industries/docker-elk
# 2178                           volpejoaquin/racer
#
#                                             readme_text                batch  \
# 0     # [InfernalTG](https://telegram.me/TeleInferna...  oss_readme_batch1_8
# 1     # Jekyll Now\n\n**Jekyll** is a static site ge...  oss_readme_batch1_8
# 2     # handlers.ActiveDirectory.net\nActive Directo...  oss_readme_batch1_8
# 3     [![Build Status](https://travis-ci.org/mraggi/...  oss_readme_batch1_8
# 4     Lineare-Algebra\n===============\n\nIn diesem ...  oss_readme_batch1_8
# ...                                                 ...                  ...
# 2174  # angular-seed â€” the seed for AngularJS apps...  oss_readme_batch1_8
# 2175  # WifiTransfer\nDirect wifi file transfer betw...  oss_readme_batch1_8
# 2176  # PAPARA(ZZ)I\nCopyright 2015-2017 Yann Marcon...  oss_readme_batch1_8
# 2177  # The ELK stack (Elasticsearch, Logstash, Kiba...  oss_readme_batch1_8
# 2178  <p align="center">\n<a href="https://github.co...  oss_readme_batch1_8
#
#                     as_of status
# 0     2021-06-14 12:20:52   Done
# 1     2021-06-14 12:20:52   Done
# 2     2021-06-14 12:20:52   Done
# 3     2021-06-14 12:20:52   Done
# 4     2021-06-14 12:20:52   Done
# ...                   ...    ...
# 2174  2021-06-14 12:35:51   Done
# 2175  2021-06-14 12:35:51   Done
# 2176  2021-06-14 12:35:51   Done
# 2177  2021-06-14 12:35:51   Done
# 2178  2021-06-14 12:35:51   Done
#
# [2179 rows x 5 columns]

# %%
test_slugs = ["brandonleekramer/diversity", 
              'cjbd/src'
              "uva-bi-sdad/oss-2020", 
              "facebook/react", 
              "RichardLitt/standard-readme",            
]

looped_data = []
for slug in test_slugs:
    results = scrape_readmes(slug)
    looped_data.append(results)
    final_data = pd.DataFrame(looped_data, columns=["slug", "readme_text", "as_of", "status"])

final_data
# Out:
# brandonleekramer/diversity
# 404 error on slug cjbd/srcuva-bi-sdad/oss-2020
# facebook/react
# RichardLitt/standard-readme
#                            slug  \
# 0    brandonleekramer/diversity
# 1  cjbd/srcuva-bi-sdad/oss-2020
# 2                facebook/react
# 3   RichardLitt/standard-readme
#
#                                          readme_text                as_of  \
# 0  \n#### The Rise of Diversity and Population Te...  2021-06-11 16:38:42
# 1                              404 ERROR - NO README  2021-06-11 16:38:42
# 2  # [React](https://reactjs.org/) · [![GitHub li...  2021-06-11 16:38:42
# 3  # Standard Readme\n\n[![standard-readme compli...  2021-06-11 16:38:42
#
#   status
# 0   Done
# 1   Done
# 2   Done
# 3   Done

# %%
batch_name = 'batch1_5000_commits' 

looped_data = []
for slug in slugs:
    results = scrape_readmes(slug)
    looped_data.append(results)
    final_data = pd.DataFrame(looped_data, columns=["slug", "readme_text", "as_of", "status"])
    final_data.to_csv('/project/class/bii_sdad_dspg/ncses_oss_2021/requests_scrape/'+batch_name+'.csv', sep=',', encoding='utf-8', index=True)

final_data
