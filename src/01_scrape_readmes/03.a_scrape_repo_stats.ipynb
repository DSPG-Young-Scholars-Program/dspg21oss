# %% [markdown]
# # Scrap repo stats using PyGitHub

# %% [markdown]
# ### Author: Crystal Zang

# %% [markdown]
# This notebook utilized GitHub access tokens (PAT) to scrape GitHub repository statistics such as stargazers, watchers, forks, and topics. One PAT would scrape at a rate of 5000 repositories per hour. Utilizing 36 PATs we would scrape 10,288,063 repositories in about XXX hours at a rate of 15,514 repositories per hour.

# %% [markdown]
# #### Warnings
# You should not commit any access topen to GitHub, which would result in access token being revoked.

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
# load packages 
import os
import psycopg2 as pg
from sqlalchemy import create_engine
import pandas as pd
import requests as r
import string 
import json
import base64
import urllib.request
import itertools 
import numpy as np
from bs4 import BeautifulSoup
from dotenv import load_dotenv
from github import Github, RateLimitExceededException, BadCredentialsException, BadAttributeException, GithubException, UnknownObjectException, BadUserAgentException
import warnings
import datetime

import multiprocessing
#from multiprocessing.pool import ThreadPool as Pool
from multiprocessing import Pool, freeze_support

import concurrent.futures

warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
#os.environ['db_user'] = ''
#os.environ['db_pwd'] = ''

# connect to the database, download data, limit to repos with at least 20,000 commits?
connection = pg.connect(host = 'postgis1', database = 'sdad', 
                        user = os.environ.get('db_user'), 
                        password = os.environ.get('db_pwd'))

raw_slug_data = '''SELECT * FROM gh_2007_2020.repos_ranked WHERE (commits BETWEEN '700' AND '800')'''
#raw_slug_data = '''SELECT * FROM gh_2007_2020.repos_ranked WHERE commits < 1000'''

# convert to a dataframe, show how many missing we have (none)
raw_slug_data = pd.read_sql_query(raw_slug_data, con=connection)

connection.close()


print(raw_slug_data.head())
print(raw_slug_data.shape)
print(raw_slug_data.isna().sum())

# %%
raw_slug_data = pd.read_csv('/home/zz3hs/git/dspg21oss/data/dspg21oss/crystal_to_scrape_0706.csv') #import csv
raw_slug_data
# Out:
#                                                     slug
# 0                                          zvini/website
# 1                                  tiagoanatar/ninjagame
# 2                                    Liujingfang1/kprune
# 3                                   exing1984/moodlemoot
# 4                             charterresources/moodle3.2
# ...                                                  ...
# 88774             tempio-della-grande-madre/grande-madre
# 88775                   dirkdeyne/zk-spring-boot-starter
# 88776                             spider-gazelle/bindata
# 88777  jenkinsci/osf-builder-suite-for-sfcc-deploy-pl...
# 88778                                  ptdave20/helpdesk
#
# [88779 rows x 1 columns]

# %%
#get rid of leading and ending space, save slugs to a list
raw_slugs = raw_slug_data["slug"].tolist()
slugs = []
for s in raw_slugs:
    slugs.append(s.strip())  
print(len(slugs))
print(slugs[0], slugs[len(slugs)-1])
# Out:
# 88779
# zvini/website ptdave20/helpdesk

# %%
#os.environ['db_user'] = ''
#os.environ['db_pwd'] = ''

# connect to the database, download data, limit to repos with at least 20,000 commits?
connection = pg.connect(host = 'postgis1', database = 'sdad', 
                        user = os.environ.get('db_user'), 
                        password = os.environ.get('db_pwd'))

#PATs access token, saved as a dataframe
github_pats = '''SELECT * FROM gh_2007_2020.pats_update'''
github_pats = pd.read_sql_query(github_pats, con=connection)

#PATs access token, saved as a list
access_tokens = github_pats["token"]

#number of tokens available for use, a numeric value
num_token = '''SELECT COUNT(*) FROM gh_2007_2020.pats_update'''
num_token = pd.read_sql_query(num_token, con=connection)
num_token=num_token.iloc[0]['count']

connection.close()

# %%
slugs_try = slugs[0:100]
print(slugs_try[0], slugs_try[99])
# Out:
# eevvnnxx/catuserbot YueLinHo/serf

# %%
# index ranges from 0 to maximum number of PATs available
def get_access_token(github_pat_index):
    if github_pat_index < num_token:
       # print("Extracting access token #", github_pat_index+1,", total", num_token, "tokens are available.")
        return github_pats.token[github_pat_index]
    else:
        print("token exceed limit")

# %%
#practice on 7 slugs, one invalid slug 
slugs_example = ["moderndive/ModernDive_book", "DSPG-Young-Scholars-Program/dspg21oss", 
                 "unknownrepo", "moderndive/ModernDive_book", "lsst/ip_diffim", "esrlabs/chipmunk", "paulmillr/chokidar"]

# %%
len(access_tokens)
# Out:
# 32

# %% [markdown]
# # Not using any multiprocessing

# %%
def pull_repo_stats(github_pat_index, slugs):
    df_repo_stats = pd.DataFrame()
    for slug in slugs:
        if github_pat_index >= len(access_tokens):
            github_pat_index -= len(access_tokens)
            print("***Pat access token exceed limit, restart access token loop with #", github_pat_index)
        while github_pat_index < len(access_tokens):
            try:
                access_token = get_access_token(github_pat_index)
                #print("Scrapping --", slug,". Extracting access token #", github_pat_index+1,", total", num_token, "tokens are available.")
                #if false, retry until true, max number of retry is 20 times
                g = Github(access_token, retry = 20, timeout = 15)
                repo = g.get_repo(slug)
                df_repo_stats = df_repo_stats.append({
                    "slug": slug,
                    'stars': repo.stargazers_count,
                    'watchers': repo.subscribers_count,
                    'forks': repo.forks_count,
                    'topics': repo.get_topics()
                }, ignore_index = True)
            except RateLimitExceededException as e:
                print(e.status)
                print('Rate limit exceeded --', slug, ", using access token #", github_pat_index)
                print("Current time:", datetime.datetime.now())
                #time.sleep(300)
                github_pat_index+=1
                print("***Exit current access token, proceed with next aceess token #", github_pat_index, "rescrape --",slug)
                break
            except BadCredentialsException as e:
                print(e.status)
                print('Bad credentials exception --', slug, ", using access token #", github_pat_index)
                print("Current time:", datetime.datetime.now())
                github_pat_index+=1
                print("***Exit current access token, proceed with next aceess token #", github_pat_index, "rescrape --",slug)
                break
            except UnknownObjectException as e:
                print(e.status)
                print('Unknown object exception --', slug)
                break
            except GithubException as e:
                print(e.status)
                print('General exception --', slug)
                break
            except r.exceptions.ConnectionError as e:
                print('Retries limit exceeded --', slug)
                print(str(e))
                time.sleep(10)
                continue
            except r.exceptions.Timeout as e:
                print('Time out exception --', slug)
                print(str(e))
                time.sleep(10)
                continue
            break
    return df_repo_stats

# %%
slugs1 = slugs[0:20000]

start_time = datetime.datetime.now()
print("Start scraping:", start_time)
df_repo_stats = pull_repo_stats(0, slugs1)
end_time =  datetime.datetime.now()
print("Finished scraping", len(df_repo_stats), "of", len(slugs1), "records at", end_time)
print("It took", end_time-start_time, "to run.")
# Out:
# Start scraping: 2021-07-06 20:41:30.603796
# 404
# Unknown object exception -- zvini/website
# 404
# Unknown object exception -- tiagoanatar/ninjagame
# 404
# Unknown object exception -- Liujingfang1/kprune
# 404
# Unknown object exception -- exing1984/moodlemoot
# 404
# Unknown object exception -- charterresources/moodle3.2
# 404
# Unknown object exception -- CornwallCollege/Master-Moodle
# 404
# Unknown object exception -- ltu-solent/moodle32test
# 404
# Unknown object exception -- sarahjcotton/gitflowtesting
# 404
# Unknown object exception -- Mets3D/blender
# 404
# Unknown object exception -- josenorberto/moodle-docker-alpine
# 404
# Unknown object exception -- gregorycv/moodle_quiz_extended
# 404
# Unknown object exception -- kk37111754/homebrew-python3.6
# 404
# Unknown object exception -- tjanas94/emacs
# 404
# Unknown object exception -- saidganim/llvm_clone
# 404
# Unknown object exception -- firemax13/android_kernel_sm6150_unified
# 404
# Unknown object exception -- firemax13/a80kernel
# 404
# Unknown object exception -- tonlib/TON-Compiler
# 404
# Unknown object exception -- cjbd/src
# 404
# Unknown object exception -- SiroPlugins/SiroLibrary
# 404
# Unknown object exception -- leonstirk/kekeno
# 404
# Unknown object exception -- aelguindy/djenerator
# 404
# Unknown object exception -- samuelbeard/excursions
# 404
# Unknown object exception -- Praetorian-honeypot/alsdb
# 404
# Unknown object exception -- codesidian/Java-MusicSocialNetwork
# 404
# Unknown object exception -- sandeepkrgupt/Angular1
# 404
# Unknown object exception -- yuoohmaths/academic-kickstart
# 404
# Unknown object exception -- albergar2/personal-site
# 404
# Unknown object exception -- KirillBelovTest/MathematicaSimpleServer
# 404
# Unknown object exception -- galexite/eleventy-base-blog
# 404
# Unknown object exception -- scottjwilson/bailee
# 404
# Unknown object exception -- daniellephillips/newmoon
# 404
# Unknown object exception -- getpoirot/Router
# 404
# Unknown object exception -- Mohammadrsi98/MohammadRSI98
# 404
# Unknown object exception -- ups216/TailwindTraders-Backend-1907
# 404
# Unknown object exception -- mchristopher/tca-website
# 404
# Unknown object exception -- ralsei/wmrc
# 404
# Unknown object exception -- CloudVessel/foldr.com
# 404
# Unknown object exception -- yikaraman/ilkerkaramanli
# 404
# Unknown object exception -- nsivertsen/eleventy-netlify-boilerplate
# 404
# Unknown object exception -- trijuhari/GatsbyJS-Netlify
# 403
# Rate limit exceeded -- Jincheng-Sun/Kylearn , using access token # 0
# Current time: 2021-07-06 20:51:04.964604
# ***Exit current access token, proceed with next aceess token # 1 rescrape -- Jincheng-Sun/Kylearn
# 404
# Unknown object exception -- krlex/backend-krletron.tk
# 404
# Unknown object exception -- danielfilho/dotfiles
# 404
# Unknown object exception -- j3ffhubb/libshds
# 404
# Unknown object exception -- aime01efh/artificial-intelligence
# 404
# Unknown object exception -- vadikmash/codejam-culture-portal
# 404
# Unknown object exception -- newsdev/geoip
# 404
# Unknown object exception -- dtidigitalcrafters/gestao-a-vista-orion
# 404
# Unknown object exception -- creativeminds3a1/Pi_WebSymfony
# 404
# Unknown object exception -- razvanra2/tema2_so
# 404
# Unknown object exception -- franaudo/sphinx_theme
# 404
# Unknown object exception -- isharaka/marvel-death
# 404
# Unknown object exception -- devincornell/easytext
# 404
# Unknown object exception -- orbitwebmaster/kiosk
# 404
# Unknown object exception -- pip-services/pip-services-net-dotnet
# 404
# Unknown object exception -- gridfinity/gfpsgo
# 403
# Rate limit exceeded -- yyssc/ssc-dev-server , using access token # 1
# Current time: 2021-07-06 21:01:03.051669
# ***Exit current access token, proceed with next aceess token # 2 rescrape -- yyssc/ssc-dev-server
# 401
# Bad credentials exception -- interactiveRob/gatsby-wp-test , using access token # 2
# Current time: 2021-07-06 21:01:03.121540
# ***Exit current access token, proceed with next aceess token # 3 rescrape -- interactiveRob/gatsby-wp-test
# 404
# Unknown object exception -- tianao97/tilda
# 404
# Unknown object exception -- Scorbie/LifeAPI
# 404
# Unknown object exception -- epyepy/geoxplore-web
# 404
# Unknown object exception -- CarloMicieli/spring-mvc-movies
# 404
# Unknown object exception -- Jagepard/Rudra-Connector
# 404
# Unknown object exception -- MatthieuScarset/drupal-camp-montreal
# 404
# Unknown object exception -- LiveStreamHelper/BiliBiliHelper
# 404
# Unknown object exception -- PinkelNet/AzureStackTools
# 404
# Unknown object exception -- dubswalker/victor-hugo
# 404
# Unknown object exception -- Agueliethun/villain-simulator-ui
# 404
# Unknown object exception -- timfoster/mantav1
# 404
# Unknown object exception -- abeln/null-calculus
# 404
# Unknown object exception -- fobidlim/portfolio
# 404
# Unknown object exception -- wariox3/ardid
# 404
# Unknown object exception -- oujezdsky/various_stuff
# 404
# Unknown object exception -- mooncn/ss-panel-v3-mod_UIChanges
# 404
# Unknown object exception -- zoud/methbank-v2
# 404
# Unknown object exception -- GodwatchMonitor/node-godwatch
# 404
# Unknown object exception -- mkantzer/HomeLinux
# 404
# Unknown object exception -- greywx/wehalo
# 404
# Unknown object exception -- mddev202/cloudco-insurance-catalog
# 404
# Unknown object exception -- TEJIMIT/TEJIMIT.github.io
# 403
# Rate limit exceeded -- nicholasray/navpush , using access token # 3
# Current time: 2021-07-06 21:11:05.314741
# ***Exit current access token, proceed with next aceess token # 4 rescrape -- nicholasray/navpush
# 404
# Unknown object exception -- alsmirn/muton
# 404
# Unknown object exception -- liangshi7/liangshi7.github.io
# 404
# Unknown object exception -- utx0/gatsby-starter-default
# 404
# Unknown object exception -- 21re/play-eventsource
# 404
# Unknown object exception -- Caidentp/python-data-structures
# 404
# Unknown object exception -- joshschmelzle/dotfiles
# 404
# Unknown object exception -- hoangnhatminh-dev/T1908A_TeamVit
# 404
# Unknown object exception -- rocketpack-ui/rocketpack
# 404
# Unknown object exception -- CameronNicolson/Leaf-It-To-Us
# 404
# Unknown object exception -- MedoAlSaRaE/Lord-lang
# 404
# Unknown object exception -- ghost1497/gatsby-starter-hero-blog
# 404
# Unknown object exception -- Risab/dad-online
# 404
# Unknown object exception -- 1291945816/DSAExp_ManagementOfHotel
# 404
# Unknown object exception -- impact-initiatives/reach-jor-zaatari-data
# 404
# Unknown object exception -- SmartZane/MediaSelector
# 404
# Unknown object exception -- nicolas-suarez/academic-nsuarez-v2
# 404
# Unknown object exception -- ad-roller/filters
# 404
# Unknown object exception -- jansentim1/Programmeerproject
# 404
# Unknown object exception -- dmbarbour/haskell-vcache
# 404
# Unknown object exception -- MicrosoftEdge/CharMap
# 404
# Unknown object exception -- michaelnetbiz/mistt-solution
# 404
# Unknown object exception -- clebi/auth-server
# 404
# Unknown object exception -- Joe-Jackman/rails_tutorial_extension
# 404
# Unknown object exception -- ar363/jerkyll-blg-prod
# 404
# Unknown object exception -- DavidHamburg/experiments-xplatform-editor
# 403
# Rate limit exceeded -- EdubotOtavalo/edubot.github.io , using access token # 4
# Current time: 2021-07-06 21:21:06.867960
# ***Exit current access token, proceed with next aceess token # 5 rescrape -- EdubotOtavalo/edubot.github.io
# 404
# Unknown object exception -- mmidzik/mmidzik.github.io
# 404
# Unknown object exception -- willmkt/bauhaus
# 404
# Unknown object exception -- crundberg/cr-smart-home
# 404
# Unknown object exception -- jthurteau/saf7_test
# 404
# Unknown object exception -- makerdao/oasis-landing
# 404
# Unknown object exception -- julienetie/yogafire
# 404
# Unknown object exception -- billyjanitsch/mixcreant
# 404
# Unknown object exception -- woai3c/recommended-books
# 404
# Unknown object exception -- key2000/MATSim_test01
# 404
# Unknown object exception -- ogroshev/cpp-conf2017-ci
# 404
# Unknown object exception -- heyitaki/Tetrament
# 404
# Unknown object exception -- swts/brittle
# 404
# Unknown object exception -- blockhaus/Kimai-MacOS-iOS
# 404
# Unknown object exception -- NHKK/hackcloneboil
# 404
# Unknown object exception -- tsugutoma/car_count
# 404
# Unknown object exception -- cyberheartmi9/Sublist3r
# 404
# Unknown object exception -- mrn/DiscordBot-JohnSchmitz
# 404
# Unknown object exception -- pytesNET/tail.DateTime
# 404
# Unknown object exception -- v5zhu/mfx-micro-service
# 403
# Rate limit exceeded -- Hari-Nagarajan/gatsby-starter-portfolio-cara , using access token # 5
# Current time: 2021-07-06 21:31:08.152907
# ***Exit current access token, proceed with next aceess token # 6 rescrape -- Hari-Nagarajan/gatsby-starter-portfolio-cara
# 404
# Unknown object exception -- Leslieying/academic-kickstart
# 404
# Unknown object exception -- zbase/libvbucket
# 404
# Unknown object exception -- toothless2390/aem_dev_plugin
# 404
# Unknown object exception -- luketudge/stats-tutorials
# 404
# Unknown object exception -- aporeto-inc/trireme-example
# 404
# Unknown object exception -- AdrianBZG/SyncMe
# 404
# Unknown object exception -- z007/Environmental
# 404
# Unknown object exception -- msindwan/mycache
# 404
# Unknown object exception -- VilasWang/HttpRequest-master
# 404
# Unknown object exception -- saltyNoodles/cudd.io
# 404
# Unknown object exception -- pierceboggan/Verses
# 404
# Unknown object exception -- ViewMachine/ViewMachine-Server
# 404
# Unknown object exception -- kmmiller10/ratatouille
# 404
# Unknown object exception -- juribeparada/YSF2DMR
# 404
# Unknown object exception -- Asver77/gulp-starter-kit
# 404
# Unknown object exception -- BryceHayden/ui-elements
# 404
# Unknown object exception -- HambergerS/Autokonfigurator
# 403
# Rate limit exceeded -- bionitio-team/bionitio-python , using access token # 6
# Current time: 2021-07-06 21:41:06.134036
# ***Exit current access token, proceed with next aceess token # 7 rescrape -- bionitio-team/bionitio-python
# 404
# Unknown object exception -- yumemi-omi/muuuuminn_blog

# %%
# read in the file and check
df_repo_stats.head()
#print(df_repo_stats)
#print(df_repo_stats.isna().sum())
#print(df_repo_stats.shape)
# Out:
#    forks                             slug  stars  \
# 0    0.0              eevvnnxx/catuserbot    0.0
# 1    0.0                    voxsim/badook    1.0
# 2    0.0           ProofPilot/PP-Frontend    0.0
# 3    2.0         TransComics/TransBubbles    1.0
# 4   88.0  Astrotomic/laravel-translatable  712.0
#
#                                               topics  watchers
# 0                                                 []       1.0
# 1                                                 []       0.0
# 2                                                 []       6.0
# 3                                                 []       4.0
# 4  [laravel, translation, eloquent, database, lan...      14.0

# %%
#df_repo_stats.to_csv(r'/home/zz3hs/git/dspg21oss/data/dspg21oss/repo_stats_bt_800_900.csv', index = False)

# %% [markdown]
# # Function to scrape one slug using specified pat index

# %%
#global github_pat_index
def pull_repo_stats(slug, github_pat_index):
    #github_pat_index = 1
   # if github_pat_index >= len(access_tokens):
   #     github_pat_index -= len(access_tokens)
   #     print("***Pat access token exceed limit, restart access token loop with #", github_pat_index)
    while True:
        try:
            if github_pat_index >= len(access_tokens):
                github_pat_index -= len(access_tokens)
                print(f"***Pat access token exceed limit, restart access token loop with #", github_pat_index)  
                
            access_token = get_access_token(github_pat_index)
            #print("Scrapping --", slug,". Extracting access token #", github_pat_index+1,", total", num_token, "tokens are available.")
            #if false, retry until true, max number of retry is set to 3 times
            g = Github(access_token, retry = 3, timeout = 15)
            repo = g.get_repo(slug)
            stars = repo.stargazers_count
            watchers = repo.subscribers_count
            forks = repo.forks_count
            topics = repo.get_topics()
        except RateLimitExceededException as e:
          #  print(e.status)
          #  print('WARNING: Rate limit exceeded --', slug, ", using access token #", github_pat_index)
            #time.sleep(300)
            github_pat_index+=1
          #  print("***Exit current access token, proceed with next aceess token #", github_pat_index, "rescrape --",slug)
            break
        except BadCredentialsException as e:
           # print(e.status)
           # print('WARNING: Bad credentials exception --', slug, ", using access token #", github_pat_index)
            github_pat_index+=1
           # print("***Exit current access token, proceed with next aceess token #", github_pat_index, "rescrape --",slug)
            break
        except UnknownObjectException as e:
           # print(e.status)
           # print('WARNING: Unknown object exception --', slug)
            stars = None
            watchers = None
            forks =  None
            topics = None
            return slug, stars, watchers, forks, topics
            break
        except GithubException as e:
           # print(e.status)
           # print('General exception --', slug)
            break
        except r.exceptions.ConnectionError as e:
           # print('Retries limit exceeded --', slug)
           # print(str(e))
            time.sleep(10)
            continue
        except r.exceptions.Timeout as e:
           # print('Time out exception --', slug)
           # print(str(e))
            time.sleep(10)
            continue
            
        results = (slug, stars, watchers, forks, topics)
        #return slug, stars, watchers, forks, topics
        return results

# %%
# Example
i = 0
print(slugs_example[i])
result = pull_repo_stats(slugs_example[i], 0)
print(result[3])

#print(result[0])
#print(result[1] ==None)
# Out:
# moderndive/ModernDive_book
# 295

# %% [markdown]
# ## Multiprocessing approach: pool.apply_async for multiple parameters

# %%
def get_result(results):
    global slug_log
    global stars_log
    global watchers_log
    global forks_log
    global topics_log
    if result is None:
        slug_log.append(None)
        stars_log.append(None)
        watchers_log.append(None)
        forks_log.append(None)
        topics_log.append(None)  
    else:
        slug_log.append(results[0])
        stars_log.append(results[1])
        watchers_log.append(results[2])
        forks_log.append(results[3])
        topics_log.append(results[4])
        #print("appending results")

# %%
def get_stars(stars):
    global stars_log
    stars_log.append(stars)
    print("appending results")

# %%
stars_log = []
#practice on 2 slugs, one invalid slug 
#slugs_example = ["moderndive/ModernDive_book", "unknownrepo"]

#practice on 7 slugs, one invalid slug 
slugs_example = ["moderndive/ModernDive_book", "DSPG-Young-Scholars-Program/dspg21oss", 
                 "unknownrepo", "moderndive/ModernDive_book", "lsst/ip_diffim", "esrlabs/chipmunk", "paulmillr/chokidar"]


slugs_100 = slugs[0:100]

# %%
multiprocessing.cpu_count()
# Out:
# 40

# %%
# Approach 2. pool.apply_async for multiple parameters
if __name__ == '__main__':
    cores_available = multiprocessing.cpu_count() - 1
    print(f'There are {cores_available} CPUs available.')
    #pool = multiprocessing.Pool(cores_available)
    pool = multiprocessing.Pool(10)
    
    # now we will feed in all of the remaining slugs 
    slug_log = []
    stars_log = []
    watchers_log = []
    forks_log = []
    topics_log = []

    start_time = datetime.datetime.now()
    print("Start scraping. Start time:", start_time)
    
    for slug in slugs_try:        
        pat_i = 3
        pool.apply_async(pull_repo_stats, args=(slug,  pat_i),callback = get_result)        
        print("~~~~~~~~~~~~~~~slug: ",slug, "using access token #", pat_i, "~~~~~~~~~~~~~~~~")
    pool.close()
    pool.join()
    
    final_log = pd.DataFrame({'slug': slug_log, "stars": stars_log, 'watchers': watchers_log, 'forks': forks_log, 'topics': topics_log}, columns=["slug", "stars", "watchers", "forks", "topics"])

    end_time = datetime.datetime.now()
    print("Finished scraping", len(final_log), "of", len(slugs_try), "records at", end_time)
    print("It took", end_time-start_time, "to run.")
# Out:
# There are 39 CPUs available.
# Start scraping. Start time: 2021-06-28 11:02:33.855801
# ~~~~~~~~~~~~~~~slug:  voxsim/badook using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Denver-userbot/D-USERBOT using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  thoniraq/IQTHON using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Baqrted/telethoncat using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Denver-userbot/rushi using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  MrASquare/verge-wallet using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ItzSjDude/Plus using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Velocies/raptor-ads using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nikolai5slo/jamvm using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  bhaii126272/userbot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nobody-repo/nObOdY-lOvEsYOU using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sahilgamer07d/SahilGamer555 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ryanpetrello/draughtcraft using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  goodmeow/xtrauserbot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  XavierNextStep/Xavier using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Krishna666Shrivastav/UserBot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  YoungLeung/CodingMart_iOS using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  cobracommander-snakexenziagang/CatMod using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  deyar-bb/Lite using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  limingxinleo/kong-phalcon using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dvjsworld/tr using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Lazybotk/hsje using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Baqrted/bybaqr using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Asalem1/AptRater using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dhruvgodara1999/CatBot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sndwvs/images_build_kit using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kits-ab/LogLady using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  youinmyhumiliation/project using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ececilla/jsa using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  TrevorSundberg/LynxChan using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sunpho84/SUNphi using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  fauzanaditia7/telebot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  prashanthkokkula06/AWS_Practice using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  cattele/telethoncat using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jcwimer/wrestlingApp using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  manas1111/manasbot2 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Baqrted/nottele using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  gamerfuckerofficial/Gamerfucker using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  wltribble/frost using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  klanrali/tastEnd using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  devunt/hydrocarbon using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Cincinesh/tue using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  flaviut/poetry using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ceylon/ceylon-module-resolver using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  qiupfyp/archillian_API using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  cloudfoundry-incubator/eirini-release using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ckr215/ckr215.github.io using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  qt-jorge-tovar/mean-app using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dieterich-lab/circtools using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  donatid/faveo-helpdesk using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  blmousee/repo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  selective-inference/R-software using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  MmxBoy/newbot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  tangjinhui951023/axios using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sundowndev/underbase using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rhenium/aclog using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  eminemdordie/mailer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  agdsn/hades using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  HenryFBP/2019-team-07f-dockerized using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  NLeSC/spot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  pkp/ots using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  skyhisi/xfce4-mailwatch-plugin using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ChristopherChudzicki/math3d-react using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  filerjs/filer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ascclemens/paste using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dllhlx/libcgroup using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  csikfer/lanview2 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Pyrdacor/freeserf.net using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Doxito/Ri-Core using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  crandrade/PokemonGo-Map using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  vigilo/correlator using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  centre-for-educational-technology/RADA using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  begla/Intrinsic using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  allourideas/pairwise-api using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  springernature/halfpipe using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  CivicHaxx/ok_councillr using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  csstree/csstree using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ronthecookie/discordboats-ARCHIVE using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  svenhjol/lockers using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  markhepburn/dotemacs using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  pothitos/naxos using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Cryru/Emotion using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Paperspace/gradient-cli using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  shiguredo/momo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  reactjs/React.NET using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  RegalOwl/HyperConomy using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Mego/Seriously using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  CryptoSpaces/tronwallet-mobile using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  staltz/manyverse using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  pyconau2017/symposion using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  solutious/stella using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  maksmaisak/Saxion_Y2Q4_Project_Exposure using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rootulp/exercism using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  twilio/twilio-node using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  triton-inference-server/server using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Quinter/trebek using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  partylover/openwrt-node-packages using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  venkateshshukla/libdivecomputer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  vigna/ne using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  conwayste/conwayste using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  MartinYik/AppleALC using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  symfony/cache using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  JuliaPackageMirrors/Wallace.jl using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  opentechinstitute/luci-commotion using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  linnovate/mean-on-openshift using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nextcloud/windows-universal using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  maraf/Money using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  qcha0s/theSpot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  EmurgoHK/cardanoupdate using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  gwt-plugins/gwt-eclipse-plugin using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  marsbard/puppet-alfresco using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  JaneaSystems/nodejs-mobile-gyp using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  adamturnerphotography/photogrpahiccms using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  1522140840/xxl-job using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rvetere/electron-react-boiler using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  stanfordnlp/spinn using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  andy-schulz/thekla using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ablyler/daemonizing-php using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mbkumar/pycdt using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  lierdakil/ide-haskell-hie using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  niefermar/google-maps-services-java using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rivinduw/fairseq_ntf using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  OpenTreeOfLife/propinquity using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  gwsystems/wasmception-libcxxabi using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  FarragoFiction/DollLibCorrect using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ledgerconnect/hivesigner-api using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Luodina/web-starter using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  eonarmy/xuserbot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kangso1/ppy using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  openva/richmondsunlight.com using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  datianshi/weblogic-buildpack using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mtezych/libcxxabi using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  JJJJJJJack/crazyflie-firmware using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kervin521/xxl-job-v1.9.1 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ib-ruby/ib-ruby using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  adib1380/iranian_bot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  eonarmy/xhackunaluserbot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  srvmsr/symfony-demo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  webrtc-lizp/chromium-llvm-project-libcxxabi using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  x86-64/frozen using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  JEMRIS/jemris using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  heroicefforts/java-buildpack-pyclid using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mlhartme/lavender using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  elpassion/mainframer-intellij-plugin using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dreamcatcherit/wooey-django22 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  DXsmiley/mathbot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Babelz/SaNi using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  samlanh/aseansm using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dpblh/BPM.js using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  CMSCollection/piranha.core using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  bobotang992/123 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  markllama/jenkins-jobs using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  DiegoValdivia/mean_practice using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  cool-robot-pals/pancakes-or-waffles using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  zion64/spring-ldap using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  hafslundnett/hdd-style using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  RubyIT/Android using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  IIIF-Commons/manifesto using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  xiyoujiyjy/free-programming-books-zh_CN using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  openstack/networking-bgpvpn using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ManageIQ/azure-armrest using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Ineedajob/RSBot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  tecknicaltom/cgdb-working using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  netgroup/srv6-pm-dp-ipset using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  phase2/grunt-drupal-tasks using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  cha0s/shrub using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  swoft-cloud/swoft-http-message using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  netnivaran/test using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  B3ST/B3 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  SitecoreUnicorn/Unicorn using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rudymatela/leancheck using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  devinbalkind/nyc-prepared using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ska80/parenscript using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  zipmark/rspec_api_documentation using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  bh-consulting/snack using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  justjavac/free-programming-books-zh_CN using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  zycet/iTRLib using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  blackops97/TEAM using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  frogbywyplay/git-repo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kinnarisanghvi/cloud-computing-AWS-Springboot-App using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  gonghao9527/-9527 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  fluidtrends/chunky using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mpracek/Diploma using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ChronosTeam/ChronosGL using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ops4j/org.ops4j.pax.wicket using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  artdiev/akommo-dashboard using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  evansde77/cirrus using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ExtraCells/ExtraCells2 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  r73inc/AR.ja using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  LeonWanjau/ecoms-dashboard using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  2martens/2martens.de using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  aronezhang/operator-sdk using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  eve-seat/seat using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  guildai/_guild-legacy using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  libyui/libyui-qt using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  shahabsaf1/merbot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  audy/dotflies using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  treewei/balancer-core using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dappnet-one/hivemind using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  itdddjulius/ConceptH using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nFnK/Workerman using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  coderIML/NAudio using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  TeaBough/st using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rahulyhg/generatte using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  bravelab/pilgrimage-dashboard using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  vmware/differential-datalog using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  TransparencyToolkit/LookingGlass using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  zetaops/pyoko using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  hpcloud-mon/monasca-events-api using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sjtu-rr-homework/PokemonAR-running using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  SoleeChoi/iamport-electron-example using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  NDLANO/image-api using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  monsterlabs/HumanRightsTracker using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  joaqoliva/TABLERODECONTROL using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mihirjh/cwtdashboard using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  strengejacke/sjmisc using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  iron-io/iron_worker_ruby_ng using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  persaianbot/XY using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mirumee/saleor-dashboard using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Sygmei/ObEngine using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mdgriffith/style-elements using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  reworkhow/JWAS.jl using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rmobis/unistream using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  OpenSDE/mnemosyne using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  pulai/ZXing.Net using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Zippen-Huang/auto-vehicle-PythonRobotics using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  boxcrittersmods/bc-mod-api using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  instructure/canvas-ios using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mrlitong/fpsgame using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Coolcord/Level-Headed using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  pv/gwaei-stuff using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  saiichihashimoto/eslint-config-saiichihashimoto using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  orange-cloudfoundry/cf-ops-automation using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  strukturag/VLCKit using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  miss-invincible/oauth2-bshaffer-implementation-in-slim using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  lmaurits/BEASTling using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Team-FreeDom/PB_Management using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jmigueldelgado/buhayra using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kaazing/http2.js using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  toruscomputer/tcodc using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  INAETICS/Drones-Simulator using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mb44/food-supply-pi using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  redhat-developer/codeready-workspaces using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  geoffroy-aubry/Indefero using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  yhfudev/php-indefero using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  readysetstem/readysetstem-api using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nheist/CaLiGraph using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  geodynamics/Rayleigh using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  gwolf0719/fjuexam using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  SBuild-org/sbuild using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  zk25796/niklasvh-html2canvas using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  itajenglish/apollo_frontend using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  PrestaShop/ps_facetedsearch using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  play-co/native-android using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  2420048520/https-github.com-analysys-EasyScheduler using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  prasannata/StackX using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  NLPatVCU/medaCy using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  UCSB-CMPTGCS-1A-F16/UCSB-CMPTGCS-1A-F16.github.io using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  phptal/PHPTAL using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  SciCompKL/CoDiPack using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  noahbenson/neuropythy using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  abh/ezmlm-idx using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  AnhellO/DAS_Sistemas using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ArmanIr/UltraJonzi using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  DaveBackus/Data_Bootcamp using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  bagelswitch/java-8-buildpack using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  reactojango/javascript_testing using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Kromey/roglick using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  paulshorey/ps using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  pmorou/quantasma using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  HTBox/crisischeckin using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  heroku/heroku-buildpack-nodejs using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  gmcabrita/dotfiles using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  lathonez/clicker using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Bnei-Baruch/mdb using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  vaishnaviallampallewar/nodejsCopied using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  shitwolfymakes/Endless-Sky-Mission-Builder using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  paluh/icecast using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  TheWorst1/1 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  klartext/any-dl using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jmcameron/attachments_translations using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mhardcastle/ddf-pipeline using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  RobertTheMagnificent/scrib using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mrrigealijan/mer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ljsun88/data_bootcamp_nyu using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  AmitKumarDas/Decisions using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Bogswagen/genieacs_herman using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  hochoy18/json4s using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  openservicebrokerapi/servicebroker using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  genieacs/genieacs using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  NUmeroAndDev/SojoDia-android using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Lyndir/Pearl using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  bitcoincashorg/bitcoincash.org using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Chris7/Mudlet2 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Sainan/Universal-Bypass using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nicoespeon/abracadabra using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jantoniomartin/condottieri-old using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  usagecontrolsystem/usagecontrolsystem using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  aparcar/asu using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  alscorsi/Streamming using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  esdoc-next/esdoc-next using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kiwix/kiwix-js-windows using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ahtss/213 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  barbelity/jfrog-cli-core-test using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ENCODE-DCC/chip-seq-pipeline using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  LeesinDong/ribbon using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Douglas-County-CO/NearMeDC using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  JenSte/libsigrokdecode using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  vincenthz/hs-gauge using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  PandaCrushSaga/PandaCrushSaga using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Ethck/PathOfBuilding using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mrsarutobi/https-github.com-Azure-Samples-media-services-dotnet-functions-integration using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mickey0524/leetcode using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  thinklikes/guapp-front-end using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  gabrielyuyang/test2 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  AxGord/Pony using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dheerajhanda/G using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kstoreyf/foo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  cassandra-project/platform using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  johnwbyrd/brakefile using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dongikpark/contrail using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  viren85/moviemirchi using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mrrigealijan/spm1 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  SpilledMilkCOM/MooveePicker using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  openeuler-mirror/infrastructure using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Zippen-Huang/donkeycar using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  EDRN/labcas-backend using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Qiyy1/Mytest using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  afderrick/Mudlet using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jfrog/jfrog-cli-core using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  pbrooks/dotfiles using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  apache/axis-axis2-java-sandesha using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ufu-games/freshmans-quest using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  gabrielyuyang/test3 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  anilreyhan/forktest using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  johndevedu/react-electron-rest-client using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sonnenhaft/pandax_angular-1.5 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  micos7/blog_laravel using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  gofed/gofed using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  5AMsan/Neorizons using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mercenem/devopsfolks using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Evildavo/SGD103-Homeless using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  osorubeki-fujita/odpt_tokyo_metro using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  SwatiJadhav46/html2canvas using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  art-locale/art-haus using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nathanchere/stx using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  OpenSocialCSN/incontact-desktop using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rahulram93/wysihtml-tables-demo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jbrowneuk/jblog using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jfrog/jfrog-cli using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  AthensFramework/Core using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  tantalum420/Docker using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  oomba/oomba-wiki using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  AYCHErp/Invoicing using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  QoboLtd/cakephp-utils using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  E-ARK-Software/earkweb using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Blockost/google-seq2seq using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rdewilde-ion/ion-electrum-server using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  wzthu/esATAC using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dkushner/ArborJs-Playground using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  leeper/leeper.github.io using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  andrecronje/gource using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Ohkiam/jQuery-contextMenu using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  oliverychen/oliverychen.github.io using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  krjivesh/star using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  KittyHawkIrc/modules using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  weixiaolv/micro-go-plugins using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ssilverm/pcsx-piplay using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sachinkanodia/rtools using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sonata-project/SonataNewsBundle using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ycz3792/Meka using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ivanoats/parade using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mkg20001/pkg-bundle using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  hbxq2018/xxl-job using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  leondraceus/PMDVN-Nexus-Bot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dcposch/go using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  OPI-PIB/navoica-platform using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  qingqiu8/zheng using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  swapnil-pathak/mbed-cli using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  khalahan/old_namecoin using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  JoinMarket-Org/joinmarket-clientserver using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  blomm/meanio_template using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  fjelltopp/meerkat_abacus using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kaltura/playkit-android using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  KIZI/EasyMiner-EasyMinerCenter using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  cloudflare/quiche using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dobruy2517/robot_tests_kap using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  apinf/openapi-designer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  breddy31/bandit1 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  carlsonp/kort using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kurthill4/d8 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  DarthMike/indielib-crossplatform using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  hieunguyenformos/lumX using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  tonyxiao/segment-debugger using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ishmilan2/ishmilan.github.io using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  guokai27/VUE-AD using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ShiZhan/fs-crawler using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  AakashOfficial/Calculator using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Teino1978-Corp/Teino1978-Corp-gulp using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Ultr4-Froz3n/spamer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  StanfordLegion/psana-legion using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ChinHuatAng/meta-virtualization using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dcdanko/BioBitBot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  johnnycook/gatsby-starter-netlify-cms using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  treeder/functions using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  manuelcortez/socializer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  LIVVkit/LIVVkit using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ebellity/geocoder using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  malramsay64/statdyn-simulation using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Softman65/abooks using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  haojianxun/mirror-quay.io using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rodrigosilvaluz/FaveoHelpDesk using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  naturenet/naturenet-viz using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  bin-nuance-bat/project using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  davkal/WP-contributions using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  doitroot/flannel using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  BUTSpeechFIT/beer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kungfumas/jsoneditor using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  evpobr/oggz using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  provegard/ncdbg using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  fyndiq/fyndiq-woocommerce-module using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  distribute-protocol/distribute-app using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  brightwind-dev/brightwind using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  frictionlessdata/specs using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Brightspace/D2L.Security.OAuth2 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  MagicForrest/DGVMTools using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nicferrier/elnode using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  openwebnet/openwebnet-android using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  raatiniemi/sonar-objective-c using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  CruceGameDevel/CruceGame using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  KenSuenobu/rust-pushrod using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  wp-plugins/subscribe2 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Azure/azure-event-hubs using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  haohlin/yolov3customtraining using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kwery/kwery using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Bandwidth/bandwidth.github.io using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  cisocrgroup/ocrd-postcorrection using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kenfehling/react-router-nested-history using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kimurakenshi/caravanas using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Ghostkeeper/SettingsGuide using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  esheldon/fitsio using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Promises/Warcraft-Maul-Buildtools using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  shawt/Arduino-Create-for-iForge using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Voog/wysihtml using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Waikato/meka using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  wtbarnes/synthesizAR using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  AppLozic/ApplozicSwift using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mentor81/spamer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  larrydiamond/typescriptcollectionsframework using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  bootc/ulogd2 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jeblad/Pickle using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  uken/fluent-plugin-elasticsearch using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mobinlord/xybot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  GoogleCloudPlatform/esp-v2 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  GNOME/gnome-klotski using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ronin-rb/ronin-db using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Maxsteam/EE using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kenavolic/statismo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  beer-asr/beer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  swisnl/jQuery-contextMenu using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  scoverage/scalac-scoverage-plugin using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  irvined1982/lavaflow using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  wikimedia/mediawiki-skins-Refreshed using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  prettier/plugin-php using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  BunkersAndBadasses/MetaDND using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nesbarse/mountain-blog using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mozilla/contain-facebook using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mkb2091/blockconvert using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  turnpike/libcxxabi using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Gubaer/josm-scripting-plugin using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Symphony-DAS/symphony-matlab using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  DoctorMcKay/node-steam-user using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  seclib/cerberus using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  TehNut/VoidCraft using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  codica2/vue-timebot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  symmetryinvestments/autowrap using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ITBE-Lab/MA using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  davidhu2000/youtube_desktop using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jagi/meteor-astronomy using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  shartge/netcomics using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  naazgull/zapata using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  opencredit/badgeos using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ferreusveritas/DynamicTrees using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  zauner/vvvv.js using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  curtbinder/AndroidStatus using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  vidaaudrey/avanta using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  TypeStrong/typedoc using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kemtol/solusikonveksi using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  lizardsystem/lizard-auth-server using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ShibeTemple/iChangerApp using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  python-provy/provy using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  bevacqua/node-emoji-random using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  emberjs/ember-qunit using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  achesak/weatherlog using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  pibemillo/unveil-gatsby-netlify-cms using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Disslove77777/AAAA using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  cooperhewitt/Planetary using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  apmckinlay/gsuneido using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  zet-evacuation/zet using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ymmah/carbon-c-relay using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  orlenko/bccf using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  filipemarruda/meanTest using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  pedronasser/functions using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  soruly/anilist-chinese using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  linuxmuster/linuxmuster-schulkonsole using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  halfline/polari using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  arackaf/cr-build-dashboard using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  MrLetsplay2003/MrCore using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  goldwasserexchange/public using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kinvolk/coreos-cloudinit using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  CaptainFact/captain-fact-api using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  smtcrms/Android-Iconics using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  RhenaudTheLukark/Botfire using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  xcwill/my_seq2seq using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  communcom/cyber-swift using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  infor-cloud/cloud-store using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  TinkerEdgeR-Android/build_blueprint using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Miner1305/ccdev using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  singhiam/ElectronTest using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  hkg36/SBJson_amenmod using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  almonteb/scoot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  arlac77/chunk-tokenizer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  wesh9999/cloud-store-import-test using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  alephdata/followthemoney using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Offensive101/MLproject using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  APDevTeam/Movecraft using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  glennmatthews/cot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dquinteros/quad using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  MaSven/simavr-solus-packaging using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  wkw/react-draft-editor-shell using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  veyrats/cf-java-buildpack-production using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  underdogg-forks/faveocleandecember using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  agrover/kmod using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  quangthuyhoang/dashboard using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  joomlatools/joomlatools-framework-activities using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  IHA114/mattata using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  epfl-vlsc/bwa using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  purilarp/openhab-openhab-core using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  reserva-facil/minimalist using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  paypal/paypal-smart-payment-buttons using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  larrybotha/dotfiles using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  maxsite/cms using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Gwion/gwion-sporth using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  csonchen/electron-react using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  arlac77/registry-mixin using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sravel/scripts using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dotnetcore/AspectCore-Framework using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  TelescopeSt/Telescope using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  chavdar/gobblin using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  identicurse/statusnet.py using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  reubano/tophubbers using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kbbgl/ecOptimizer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  AaronNGray/typedoc-next using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  codejamninja/charts using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  cc-daveloper/mist.io_vaadin-grid using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  PMKielstra/catfish using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  AYCH-Inc/aych.electrum using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  alisterk/chromiumfx-orign using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  vkefallinos/typedoc using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  SevenSinS02/selfie using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ging/fiware-idm using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  maxdrift/safari-client using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  liangtg/git-repo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Qarj/WebImblaze using access token # 3 ~~~~~~~~~~~~~~~~
# ...
# ~~~~~~~~~~~~~~~slug:  philroche/simplestreams-clone using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  camunda/blog.camunda.org using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  5monkeys/bpython using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  alanjia163/first1 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ganibc/btcpool using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  llccrr/tarot-master-electron using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nandiso/rest-client using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  snitheesh/rest-client using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ilariapiva/rest-client using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  videni/rest-client using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  vegeth1985/rest-client using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  npsyche/rest-client using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ZacksTsang/rest-client using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jmsosa/rest-client using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dark88888/rest-client using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  hiro117/rest-client using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  treatys/rest-client using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  acidgenomics/r-deseqanalysis using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  joe-lz/TodoKit2019 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  zhouchunyu/wechat using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mittagessen/kraken using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  omid1212/spam using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  tallerify/shared-server using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  codex-corp/flashls using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Trendyol/quarkify using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  bhermansyah/ANDMA-datacenter using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  leo-project/leo_redundant_manager using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kranz/vai using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Kane07008/findom using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  z0x010/lynis using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sl17/cyclone.github.io using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  noxor0/c-fastq-barcode using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  gSilas/space-assault using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  thanhcao/rd3next using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dmitriy-korotayev/macros using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  aofei/air using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  allomov/jenkins-buildpack-v2 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  WikiEducationFoundation/Wiki-Playlist using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  zioc/git-repo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ydh7611/VIP using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Adrianrp/electron using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  horde/hermes using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  generalbao/phpmailer6 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  aalice072/XFMaps using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  elbstack/elbstack-hackreact-web-3 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  bgkrupesh/BlockMarbleTest1 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  aymanamer/Dank-Memer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  HuntWS/Jenkins-Plugin using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  vaniila/graphql using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  papillonads/papillonads.draft using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  giteshsawar/ledger using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  socialsudo/socialsudo.github.io using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  myzainn/free-video using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  k1988/git-repo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  hzypage/TestPy using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dyukusi/shout_for_ff14 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kiazhu/repo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sambhavdutt/fabric-ca using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sysadmws/sysadmws-formula using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jancelin/geo-poppy using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  vaartjesd/test using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  phanindra032/projectpractice1 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  YatsukBogdan1/SelectWood using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rwaschewski/vue-storefront-tracomodo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  JMensch/openwiki-nyt using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Toppington/insert_android2 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sailfishos-mirror/telepathy-haze using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Turing-Circle/sens-main using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  moodlebox/moodlebox.net using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  modelfarm/AR.js using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  cloudbase/cinder-ci using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  at0mzk1/facturacion using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  prashantkashyap09/BasicReact using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nirmal0001/master using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kukudan/Use-for-learn-vnpys using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  noah-smith-dev/upstack-test using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  cguerrerCS/pokenest-finder using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  lncm/pi-factory using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  shadowbeam/allan-watson using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  NOBITABRO/prosecbot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  bidah/storytime-feria using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  aleidaolvera/gusa-library using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  CharlesDDNoble/broncode using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  spacekitteh/git-repo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  egor5q/loshadbot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  qrtc/uWebSockets using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  eth-sri/eth-sri.github.io using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  waartaa/waartaa using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  alabs/petateca using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ironandsilk/ar using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  msuliborski/the-nightmare using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  openflexo-team/connie using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nanoporetech/medaka using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  freedesktop/telepathy-haze using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  telefonicaid/fiware-sth-comet using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  influxdata/influxdb-comparisons using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  xfce-mirror/xfce4-notes-plugin using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  digabi/rich-text-editor using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ethantw/Han using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ypzhuang/web-console-starter-bk using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  asgardphp/asgard using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kevoj/nodetomic-api-swagger using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Splawik/pytigon using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ansjory/mids-w205-crook using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  citizenlabsgr/openbudgetwy using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  spring-cloud/spring-cloud-dataflow-ui using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nirantarnoy/prasit using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  arwystli/getlocations_dr using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  moment/luxon using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jjzhang166/libcss using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  tkgamegroup/flame using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Ashkanovich/Bring using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dymajo/waka using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sazboom/pophealth-mihin using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  MateusVMachado/etm using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  churchthemes/church-theme-content using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  TelepathyIM/telepathy-haze using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Rareson/LammpsRelated using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  linuxpanpan/repo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  aicirt2012/icm-server using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Film-Solutions-LLC/fsregistry using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rejeep/apes using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  radjkarl/pyqtgraph_karl using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  pwafire/pwafire using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Zematus/Worlds using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Azure/AzureStack-Tools using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  synapsestudios/oidc-platform using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  goldenrivertek/git-repo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  furlongm/patchman using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  GHPReporter/Ghpr.Core using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  xuperchain/go-libp2p-kad-dht using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  MassEffectModder/MassEffectModder using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  tiarebalbi/fortaleza-ui-theme using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Saintway-Technology/repo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  canonical-web-and-design/cn.ubuntu.com using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  voteamerica/backend using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  UMM-CSci-3601-S18/iteration-4-readme-md using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  joomlatools/joomlatools-vagrant using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  MarcGrol/golangAnnotations using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  louissong7912/SMP_libaacs using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  serverboards/serverboards-plugins-oss using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  platformio/platformio-atom-ide using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  borzz/sysbench using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  pprotasov/dbapi using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ZcashFoundation/zecwallet using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  hhvm/hhast using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rescatux/rescatux using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  zdavatz/oddb2xml using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dalek-cryptography/bulletproofs using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mdickinson/bigfloat using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  angrykoala/wendigo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  open-eid/MOPP-iOS using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  apache/flex-flexunit using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  diachron/quality using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  OGGM/oggm using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rspeele/Rezoom.SQL using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nlsynth/iroha using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  criswell/uca-gpl using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  WhisperChi/owt-client-native-windows using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  freedesktop-unofficial-mirror/telepathy__telepathy-haze using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  unfaiyted/cactbot-settings-app using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  slfyusufu/git-repo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Lambda-School-Labs/labs10-shopping-list using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  twada/power-assert-runtime using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dreaminghell/repo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ruby-amqp/march_hare using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  zpy807/https-github.com-binux-pyspider using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mperreir/HyblabDDJ2018 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  1busyguy/ARfaceSwap using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Miner1305/loki using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  JuananRodriguez/Dashboard-Electron using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Achain-Dev/act.cdt using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Max7641/linux_knowledge using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  swarm00/nanodbc using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ericgsmith/d7patternlab using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Arpple/projectend using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  roycastro/AppsX11 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  deiscc/builder using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Edgarpz/boss_charts using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  chzhong/git-repo using access token # 3 ~~~~~~~~~~~~~~~~
# Exception in thread Thread-15:
# Traceback (most recent call last):
#   File "/home/zz3hs/.conda/envs/crystal/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/home/zz3hs/.conda/envs/crystal/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zz3hs/.conda/envs/crystal/lib/python3.7/multiprocessing/pool.py", line 486, in _handle_results
#     cache[job]._set(i, obj)
#   File "/home/zz3hs/.conda/envs/crystal/lib/python3.7/multiprocessing/pool.py", line 662, in _set
#     self._callback(self._value)
#   File "<ipython-input-37-ca40cdba5350>", line 14, in get_result
#     slug_log.append(results[0])
# TypeError: 'NoneType' object is not subscriptable

# %%
#print(final_log)
final_log
# Out:
#                                     slug   stars  watchers  forks  \
# 0                            unknownrepo     NaN       NaN    NaN
# 1             moderndive/ModernDive_book   548.0      28.0  295.0
# 2             moderndive/ModernDive_book   548.0      28.0  295.0
# 3  DSPG-Young-Scholars-Program/dspg21oss     0.0       3.0    0.0
# 4                         lsst/ip_diffim     5.0      45.0    7.0
# 5                       esrlabs/chipmunk   285.0      11.0   23.0
# 6                     paulmillr/chokidar  7990.0      85.0  511.0
#
#                                               topics
# 0                                               None
# 1  [moderndive, data-science, tidyverse, statisti...
# 2  [moderndive, data-science, tidyverse, statisti...
# 3                                                 []
# 4                                                 []
# 5  [logs-analysis, logviewer, search, logstash, l...
# 6       [watch-files, fsevents, watcher, filesystem]

# %% [markdown]
# ## Multiprocessing approach: pool.imap_unordered

# %%
cores_available = multiprocessing.cpu_count() - 1
print(f'There are {cores_available} cores available.')
pool = Pool(cores_available)

# now we will feed in all of the remaining slugs 
slug_log = []
stars_log = []
watchers_log = []
forks_log = []
topics_log = []

start_time = datetime.datetime.now()
print("Start scraping. Start time:", start_time)
for result in pool.imap_unordered(pull_repo_stats, slugs_example):
    print("~~~~~~~~~~~~~~~result: ",result, "~~~~~~~~~~~~~~~~")
    if result is None:
        slug_log.append(None)
        stars_log.append(None)
        watchers_log.append(None)
        forks_log.append(None)
        topics_log.append(None)  
    else:
        slug_log.append(result[0])
        stars_log.append(result[1])
        watchers_log.append(result[2])
        forks_log.append(result[3])
        topics_log.append(result[4])


final_log = pd.DataFrame({'slug': slug_log, "stars": stars_log, 'watchers': watchers_log, 'forks': forks_log, 'topics': topics_log}, columns=["slug", "stars", "watchers", "forks", "topics"])

end_time = datetime.datetime.now()
print("Finished scraping", len(final_log), "of", len(slugs), "records at", end_time)
print("It took", end_time-start_time, "to run.")
# Out:
# There are 39 cores available.
# 404
# WARNING: Unknown object exception -- rrrrrrrrr
# Start scraping. Start time: 2021-06-23 11:22:11.104201
# ~~~~~~~~~~~~~~~result:  ('rrrrrrrrr', None, None, None, None) ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~result:  ('DSPG-Young-Scholars-Program/dspg21oss', 0, 3, 0, []) ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~result:  ('moderndive/ModernDive_book', 548, 28, 295, ['moderndive', 'data-science', 'tidyverse', 'statistical-inference', 'r', 'ggplot2', 'infer', 'hypothesis-testing', 'confidence-intervals', 'regression', 'regression-models', 'data-visualization', 'data-wrangling', 'tidy', 'rstudio', 'rstats', 'dplyr', 'bootstrap-method', 'permutation-test']) ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~result:  ('moderndive/ModernDive_book', 548, 28, 295, ['moderndive', 'data-science', 'tidyverse', 'statistical-inference', 'r', 'ggplot2', 'infer', 'hypothesis-testing', 'confidence-intervals', 'regression', 'regression-models', 'data-visualization', 'data-wrangling', 'tidy', 'rstudio', 'rstats', 'dplyr', 'bootstrap-method', 'permutation-test']) ~~~~~~~~~~~~~~~~
# Finished scraping 4 of 4 records at 2021-06-23 11:22:11.378817
# It took 0:00:00.274616 to run.

# %%
final_log
# Out:
#                                     slug  stars  watchers  forks  \
# 0                              rrrrrrrrr    NaN       NaN    NaN
# 1  DSPG-Young-Scholars-Program/dspg21oss    0.0       3.0    0.0
# 2             moderndive/ModernDive_book  548.0      28.0  295.0
# 3             moderndive/ModernDive_book  548.0      28.0  295.0
#
#                                               topics
# 0                                               None
# 1                                                 []
# 2  [moderndive, data-science, tidyverse, statisti...
# 3  [moderndive, data-science, tidyverse, statisti...

# %%
#final_log.to_csv(r'/home/zz3hs/git/dspg21oss/data/dspg21oss/final_log_try.csv', index = False)

# %%
# read in the file and check
print(final_log.head())
print(final_log)
print(final_log.isna().sum())
print(final_log.shape)
# Out:
#                                     slug  stars  watchers  forks  \
# 0                              rrrrrrrrr    NaN       NaN    NaN
# 1  DSPG-Young-Scholars-Program/dspg21oss    0.0       3.0    0.0
# 2             moderndive/ModernDive_book  548.0      28.0  295.0
# 3             moderndive/ModernDive_book  548.0      28.0  295.0
#
#                                               topics
# 0                                               None
# 1                                                 []
# 2  [moderndive, data-science, tidyverse, statisti...
# 3  [moderndive, data-science, tidyverse, statisti...
#                                     slug  stars  watchers  forks  \
# 0                              rrrrrrrrr    NaN       NaN    NaN
# 1  DSPG-Young-Scholars-Program/dspg21oss    0.0       3.0    0.0
# 2             moderndive/ModernDive_book  548.0      28.0  295.0
# 3             moderndive/ModernDive_book  548.0      28.0  295.0
#
#                                               topics
# 0                                               None
# 1                                                 []
# 2  [moderndive, data-science, tidyverse, statisti...
# 3  [moderndive, data-science, tidyverse, statisti...
# slug        0
# stars       1
# watchers    1
# forks       1
# topics      1
# dtype: int64
# (4, 5)

# %% [raw]
# # concactinate scrapped dataframes together
# df1 = pd.read_csv('/home/zz3hs/git/dspg21oss/data/dspg21oss/repo_stats_bt_1000_1500.csv') #import csv
# print(df1.shape)
# df2 = pd.read_csv('/home/zz3hs/git/dspg21oss/data/dspg21oss/repo_stats_bt_1500_2000.csv') #import csv
# print(df2.shape)
# df3 = pd.read_csv('/home/zz3hs/git/dspg21oss/data/dspg21oss/repo_stats_bt_2000_4500.csv') #import csv
# print(df3.shape)
# df4 = pd.read_csv('/home/zz3hs/git/dspg21oss/data/dspg21oss/repo_stats_gt_3000.csv') #import csv
# print(df4.shape)
#
#
# frames = [df1, df2, df3, df4]
#
# repo_stats_gt_1000 = pd.concat(frames)
#
# repo_stats_gt_1000 = repo_stats_gt_1000.drop_duplicates(subset = 'slug', keep = 'first')
# print("We scrapped",repo_stats_gt_1000.shape[0], "repos, that have greater than 1000 commits.")
#
# #repo_stats_gt_3000.to_csv(r'/home/zz3hs/git/dspg21oss/data/dspg21oss/repo_stats_gt_3000.csv', index = False)
