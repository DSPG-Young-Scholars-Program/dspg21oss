# %% [markdown]
# # Scrap repo stats using PyGitHub

# %% [markdown]
# ### Author: Crystal Zang

# %% [markdown]
# This notebook utilized GitHub access tokens (PAT) to scrape GitHub repository statistics such as stargazers, watchers, forks, and topics. One PAT would scrape at a rate of 5000 repositories per hour. Utilizing 36 PATs we would scrape 10,288,063 repositories in about XXX hours at a rate of 15,514 repositories per hour.

# %% [markdown]
# #### Warnings
# You should not commit any access topen to GitHub, which would result in access token being revoked.

# %%
# %reset

# %%
# load packages 
import os
import psycopg2 as pg
from sqlalchemy import create_engine
import pandas as pd
import requests as r
import string 
import json
import base64
import urllib.request
import itertools 
import numpy as np
from bs4 import BeautifulSoup
from dotenv import load_dotenv
from github import Github, RateLimitExceededException, BadCredentialsException, BadAttributeException, GithubException, UnknownObjectException, BadUserAgentException
import warnings
import datetime

import multiprocessing
#from multiprocessing.pool import ThreadPool as Pool
from multiprocessing import Pool, freeze_support

import concurrent.futures

warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
#os.environ['db_user'] = ''
#os.environ['db_pwd'] = ''

# connect to the database, download data, limit to repos with at least 20,000 commits?
connection = pg.connect(host = 'postgis1', database = 'sdad', 
                        user = os.environ.get('db_user'), 
                        password = os.environ.get('db_pwd'))

raw_slug_data = '''SELECT * FROM gh_2007_2020.repos_ranked WHERE (commits BETWEEN '800' AND '900')'''
#raw_slug_data = '''SELECT * FROM gh_2007_2020.repos_ranked WHERE commits < 1000'''

# convert to a dataframe, show how many missing we have (none)
raw_slug_data = pd.read_sql_query(raw_slug_data, con=connection)
print(raw_slug_data.head())
print(raw_slug_data.shape)
print(raw_slug_data.isna().sum())

#get rid of leading and ending space, save slugs to a list
raw_slugs = raw_slug_data["slug"].tolist()
slugs = []
for s in raw_slugs:
    slugs.append(s.strip())  
print(len(slugs))
print(slugs[0], slugs[len(slugs)-1])

#PATs access token, saved as a dataframe
github_pats = '''SELECT * FROM gh_2007_2020.pats_update'''
github_pats = pd.read_sql_query(github_pats, con=connection)

#PATs access token, saved as a list
access_tokens = github_pats["token"]

#number of tokens available for use, a numeric value
num_token = '''SELECT COUNT(*) FROM gh_2007_2020.pats_update'''
num_token = pd.read_sql_query(num_token, con=connection)
num_token=num_token.iloc[0]['count']

connection.close()
# Out:
#                                  id        spdx  \
# 0  MDEwOlJlcG9zaXRvcnkyMTMyODQzNTc=     GPL-3.0
# 1  MDEwOlJlcG9zaXRvcnkyODA0MjM4OTc=    AGPL-3.0
# 2  MDEwOlJlcG9zaXRvcnkyODYxMzAxOTQ=  Apache-2.0
# 3  MDEwOlJlcG9zaXRvcnk1NDYzMjIwNA==    LGPL-3.0
# 4  MDEwOlJlcG9zaXRvcnkxODAzNjMxNTU=     GPL-3.0
#
#                               slug           createdat  \
# 0                ryuffhant/candyJM 2019-10-07 03:05:14
# 1  onlyforuserbot/Personal-userbot 2020-07-17 12:54:10
# 2                   awserv/Game-Pl 2020-08-08 22:43:52
# 3            DGLABArquivos/roda-in 2016-03-24 10:00:23
# 4                   veloren/legacy 2019-04-09 12:35:46
#
#                                          description primarylanguage  \
# 0              aplikasi CBT modifikasi dari candyCBT             PHP
# 1                                               None          Python
# 2                                               None      JavaScript
# 3  RODA-in is a tool specially designed for produ...            Java
# 4                                               None            Rust
#
#                                          branch  commits                asof  \
# 0  MDM6UmVmMjEzMjg0MzU3OnJlZnMvaGVhZHMvbWFzdGVy      900 2021-01-04 04:40:52
# 1  MDM6UmVmMjgwNDIzODk3OnJlZnMvaGVhZHMvbWFzdGVy      899 2021-01-03 15:39:22
# 2  MDM6UmVmMjg2MTMwMTk0OnJlZnMvaGVhZHMvbWFzdGVy      899 2021-01-03 19:08:17
# 3  MDM6UmVmNTQ2MzIyMDQ6cmVmcy9oZWFkcy9tYXN0ZXI=      899 2021-01-03 19:19:23
# 4  MDM6UmVmMTgwMzYzMTU1OnJlZnMvaGVhZHMvbWFzdGVy      899 2021-01-03 17:12:52
#
#   status
# 0   Init
# 1   Init
# 2   Init
# 3   Init
# 4   Init
# (12531, 10)
# id                    0
# spdx                  0
# slug                  0
# createdat             0
# description        5131
# primarylanguage     148
# branch                0
# commits               0
# asof                  0
# status                0
# dtype: int64
# 12531
# ryuffhant/candyJM pressbooks/pressbooks-book

# %%
# index ranges from 0 to maximum number of PATs available
def get_access_token(github_pat_index):
    if github_pat_index < num_token:
       # print("Extracting access token #", github_pat_index+1,", total", num_token, "tokens are available.")
        return github_pats.token[github_pat_index]
    else:
        print("token exceed limit")

# %% [markdown]
# ## Function to scrape one slug using specified pat index

# %%
#global github_pat_index
def pull_repo_stats(slug, github_pat_index):
    if github_pat_index >= len(access_tokens):
        github_pat_index -= len(access_tokens)
        print(f"***Pat access token exceed limit, restart access token loop with #", github_pat_index)  

    access_token = get_access_token(github_pat_index)
    #print("Scrapping --", slug,". Extracting access token #", github_pat_index+1,", total", num_token, "tokens are available.")
    #if false, retry until true, max number of retry is set to 3 times
    #g = Github(access_token, retry = 3, timeout = 15)
    g = Github(access_token)
    repo = g.get_repo(slug)
    stars = repo.stargazers_count
    watchers = repo.subscribers_count
    forks = repo.forks_count
    topics = repo.get_topics()

    results = (slug, stars, watchers, forks, topics)
    return results

# %%
def get_result(results):
    global slug_log
    global stars_log
    global watchers_log
    global forks_log
    global topics_log
    if results is None:
        slug_log.append(None)
        stars_log.append(None)
        watchers_log.append(None)
        forks_log.append(None)
        topics_log.append(None)  
    else:
        slug_log.append(results[0])
        stars_log.append(results[1])
        watchers_log.append(results[2])
        forks_log.append(results[3])
        topics_log.append(results[4])
        print("appending results")

# %%
# Example
slugs_example = ["moderndive/ModernDive_book", "DSPG-Young-Scholars-Program/dspg21oss", 
                 "unknownrepo", "moderndive/ModernDive_book", "lsst/ip_diffim", "esrlabs/chipmunk", "paulmillr/chokidar"]

i = 0
print(slugs_example[i])
result = pull_repo_stats(slugs_example[i], 40)
print(result[3])

slug_log = []
stars_log = []
watchers_log = []
forks_log = []
topics_log = []

get_result(result)
print(slug_log)
#print(result[0])
#print(result[1] ==None)
# Out:
# moderndive/ModernDive_book
# ***Pat access token exceed limit, restart access token loop with # 8
# 295
# appending results
# ['moderndive/ModernDive_book']

# %%
slugs_try = slugs[0:100]
print(slugs_try)
print(slugs_try[0], slugs_try[99])
# Out:
# ['ryuffhant/candyJM', 'onlyforuserbot/Personal-userbot', 'awserv/Game-Pl', 'DGLABArquivos/roda-in', 'veloren/legacy', 'TeleThonX/TELEPLUS', 'zaid900/iraq.thon', 'HACKERZKALI/Telebot', 'idkqh7/dionaea', 'dsharlet/ComputerAlgebra', 'Devil666Satan/DevilBot', 'Rahul-Venugopal/Image-augmentation_1', 'lucid-services/serviser', 'HACKERZKALI/userbot', 'Shubham1204/hackto', 'Maachoddunga/RevengersX', 'shekhawat2/catuserbot', 'hjozwiak/tintin-kallisti-pack', 'icpioop/blocklygame', 'figter-lgnd/catuserbot', 'piku-adhi/catyuserbot', 'kirodewal/X-tra-Telegram', 'LyoSU/LyAdminBot', 'chirag4979/CatUser_Bot', 'deadlyzero/bot-repo', 'nonilole/Conan', 'gamerfuckerofficial/userbot', 'alcyper/alcyper', 'Babyshark1993/roms', 'allani230791/Repository', 'klanrali/telethon-iraq', 'anirbanpolvolt/friddayy', 'JamesMGreene/nestdb', 'venomTNG/Venom', 'DavidHoan/XCDYouTubeKit', 'klanrali/TeleThon-IQ', 'Wandalen/wPathBasic', 'windisf/Winn', 'safeandeasypasswords/safeandeasypasswords.github.io', 'seomoz/roger-mesos-tools', 'LegendaryCoinTech/MyEtherWallet', 'SkillsFundingAgency/das-campaign', 'yunlongbai/spring-boot', 'NOREADMEStudios/ProjectII', 'jiankaiwang/tcdcwebar', 'zk25796/jointjs', 'NUBIC/CRR', 'fandrei/AppMetrics', '190025375/lager', 'facultyai/faculty', 'bcgov/nrts-prc-admin', 'numixproject/numix-gtk-theme', 'jhuapl-boss/boss', 'PSITiano/edk2-BaseTools', 'jasoncorbett/cli', 'mech-lang/syntax', 'rpm-software-management/hawkey', 'dmacvicar/terraform-provider-libvirt', 'dl-stuff/dl', 'JeffDeCola/my-go-examples', 'scop/portecle', 'b1ueb1ues/dl', 'bobwhitelock/dotfiles', 'pavaneshaddala/workout', 'onewaterdrop/reviewcenter', 'CenterForOpenScience/isp', 'LaxarJS/laxar', 'backdrop-contrib/getlocations', 'atlasphp/Atlas.Orm', 'taweili/ardublock', 'nebulasio/explorer', 'Sage-Bionetworks/ResearchUXFactory-iOS', 'TLeonardUK/MicroBuild', 'stoically/temporary-containers', 'gsanhueza/BlastSight', 'csstree/csstree', 'ronthecookie/discordboats-ARCHIVE', 'svenhjol/lockers', 'markhepburn/dotemacs', 'pothitos/naxos', 'Cryru/Emotion', 'Paperspace/gradient-cli', 'shiguredo/momo', 'reactjs/React.NET', 'RegalOwl/HyperConomy', 'Mego/Seriously', 'CryptoSpaces/tronwallet-mobile', 'staltz/manyverse', 'pyconau2017/symposion', 'solutious/stella', 'maksmaisak/Saxion_Y2Q4_Project_Exposure', 'rootulp/exercism', 'twilio/twilio-node', 'triton-inference-server/server', 'Quinter/trebek', 'partylover/openwrt-node-packages', 'venkateshshukla/libdivecomputer', 'vigna/ne', 'conwayste/conwayste', 'MartinYik/AppleALC']
# ryuffhant/candyJM MartinYik/AppleALC

# %%
def get_stars(stars):
    global stars_log
    stars_log.append(stars)
    print("appending results")

# %% [markdown]
# ## Multiprocessing approach: pool.apply_async for multiple parameters

# %%
# Approach 2. pool.apply_async for multiple parameters
if __name__ == '__main__':
    pool = multiprocessing.Pool(10)
    
    slug_log = []
    stars_log = []
    watchers_log = []
    forks_log = []
    topics_log = []

    start_time = datetime.datetime.now()
    print("Start scraping. Start time:", start_time)
    while True:
        try:
            for slug in slugs_try:       
                pat_i = 3
                pool.apply_async(pull_repo_stats, args=(slug,  pat_i),callback = get_result)        
                print("~~~~~~~~~~~~~~~slug: ",slug, "using access token #", pat_i, "~~~~~~~~~~~~~~~~")
               # print(stars_log)
            break 
        except RateLimitExceededException as e:
            print(e.status)
            print('WARNING: Rate limit exceeded --', slug, ", using access token #", pat_i)
            #time.sleep(300)
            pat_i+=1
            print("***Exit current access token, proceed with next aceess token #", pat_i, "rescrape --",slug)
            break
        except BadCredentialsException as e:
            print(e.status)
            print('WARNING: Bad credentials exception --', slug, ", using access token #", pat_i)
            pat_i+=1
            print("***Exit current access token, proceed with next aceess token #", pat_i, "rescrape --",slug)
            break
        except UnknownObjectException as e:
            print(e.status)
            print('WARNING: Unknown object exception --', slug)
            break
        except GithubException as e:
            print(e.status)
            print('General exception --', slug)
            break
        except r.exceptions.ConnectionError as e:
            print('Retries limit exceeded --', slug)
            print(str(e))
            time.sleep(10)
            continue
        except r.exceptions.Timeout as e:
            print('Time out exception --', slug)
            print(str(e))
            time.sleep(10)
            continue
    pool.close()
    pool.join()
    
    print(stars_log)
    final_log = pd.DataFrame({'slug': slug_log, "stars": stars_log, 'watchers': watchers_log, 'forks': forks_log, 'topics': topics_log}, columns=["slug", "stars", "watchers", "forks", "topics"])

    end_time = datetime.datetime.now()
    print("Finished scraping", len(final_log), "of", len(slugs_try), "records at", end_time)
    print("It took", end_time-start_time, "to run.")
# Out:
# Start scraping. Start time: 2021-06-28 14:27:47.964663
# ~~~~~~~~~~~~~~~slug:  ryuffhant/candyJM using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  onlyforuserbot/Personal-userbot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  awserv/Game-Pl using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  DGLABArquivos/roda-in using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  veloren/legacy using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  TeleThonX/TELEPLUS using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  zaid900/iraq.thon using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  HACKERZKALI/Telebot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  idkqh7/dionaea using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dsharlet/ComputerAlgebra using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Devil666Satan/DevilBot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Rahul-Venugopal/Image-augmentation_1 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  lucid-services/serviser using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  HACKERZKALI/userbot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Shubham1204/hackto using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Maachoddunga/RevengersX using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  shekhawat2/catuserbot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  hjozwiak/tintin-kallisti-pack using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  icpioop/blocklygame using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  figter-lgnd/catuserbot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  piku-adhi/catyuserbot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kirodewal/X-tra-Telegram using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  LyoSU/LyAdminBot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  chirag4979/CatUser_Bot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  deadlyzero/bot-repo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nonilole/Conan using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  gamerfuckerofficial/userbot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  alcyper/alcyper using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Babyshark1993/roms using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  allani230791/Repository using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  klanrali/telethon-iraq using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  anirbanpolvolt/friddayy using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  JamesMGreene/nestdb using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  venomTNG/Venom using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  DavidHoan/XCDYouTubeKit using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  klanrali/TeleThon-IQ using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Wandalen/wPathBasic using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  windisf/Winn using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  safeandeasypasswords/safeandeasypasswords.github.io using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  seomoz/roger-mesos-tools using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  LegendaryCoinTech/MyEtherWallet using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  SkillsFundingAgency/das-campaign using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  yunlongbai/spring-boot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  NOREADMEStudios/ProjectII using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jiankaiwang/tcdcwebar using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  zk25796/jointjs using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  NUBIC/CRR using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  fandrei/AppMetrics using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  190025375/lager using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  facultyai/faculty using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  bcgov/nrts-prc-admin using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  numixproject/numix-gtk-theme using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jhuapl-boss/boss using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  PSITiano/edk2-BaseTools using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jasoncorbett/cli using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mech-lang/syntax using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rpm-software-management/hawkey using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dmacvicar/terraform-provider-libvirt using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dl-stuff/dl using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  JeffDeCola/my-go-examples using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  scop/portecle using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  b1ueb1ues/dl using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  bobwhitelock/dotfiles using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  pavaneshaddala/workout using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  onewaterdrop/reviewcenter using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  CenterForOpenScience/isp using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  LaxarJS/laxar using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  backdrop-contrib/getlocations using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  atlasphp/Atlas.Orm using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  taweili/ardublock using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nebulasio/explorer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Sage-Bionetworks/ResearchUXFactory-iOS using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  TLeonardUK/MicroBuild using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  stoically/temporary-containers using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  gsanhueza/BlastSight using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  csstree/csstree using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ronthecookie/discordboats-ARCHIVE using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  svenhjol/lockers using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  markhepburn/dotemacs using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  pothitos/naxos using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Cryru/Emotion using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Paperspace/gradient-cli using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  shiguredo/momo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  reactjs/React.NET using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  RegalOwl/HyperConomy using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Mego/Seriously using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  CryptoSpaces/tronwallet-mobile using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  staltz/manyverse using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  pyconau2017/symposion using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  solutious/stella using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  maksmaisak/Saxion_Y2Q4_Project_Exposure using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rootulp/exercism using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  twilio/twilio-node using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  triton-inference-server/server using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Quinter/trebek using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  partylover/openwrt-node-packages using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  venkateshshukla/libdivecomputer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  vigna/ne using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  conwayste/conwayste using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  MartinYik/AppleALC using access token # 3 ~~~~~~~~~~~~~~~~
# []
# Finished scraping 0 of 100 records at 2021-06-28 14:27:48.888596
# It took 0:00:00.923933 to run.

# %%
#print(final_log)
final_log
# Out:
#                                     slug   stars  watchers  forks  \
# 0                            unknownrepo     NaN       NaN    NaN
# 1             moderndive/ModernDive_book   548.0      28.0  295.0
# 2             moderndive/ModernDive_book   548.0      28.0  295.0
# 3  DSPG-Young-Scholars-Program/dspg21oss     0.0       3.0    0.0
# 4                         lsst/ip_diffim     5.0      45.0    7.0
# 5                       esrlabs/chipmunk   285.0      11.0   23.0
# 6                     paulmillr/chokidar  7990.0      85.0  511.0
#
#                                               topics
# 0                                               None
# 1  [moderndive, data-science, tidyverse, statisti...
# 2  [moderndive, data-science, tidyverse, statisti...
# 3                                                 []
# 4                                                 []
# 5  [logs-analysis, logviewer, search, logstash, l...
# 6       [watch-files, fsevents, watcher, filesystem]

# %% [markdown]
# ## Multiprocessing approach: pool.imap_unordered

# %%
cores_available = multiprocessing.cpu_count() - 1
print(f'There are {cores_available} cores available.')
pool = Pool(cores_available)

# now we will feed in all of the remaining slugs 
slug_log = []
stars_log = []
watchers_log = []
forks_log = []
topics_log = []

start_time = datetime.datetime.now()
print("Start scraping. Start time:", start_time)
for result in pool.imap_unordered(pull_repo_stats, slugs_example):
    print("~~~~~~~~~~~~~~~result: ",result, "~~~~~~~~~~~~~~~~")
    if result is None:
        slug_log.append(None)
        stars_log.append(None)
        watchers_log.append(None)
        forks_log.append(None)
        topics_log.append(None)  
    else:
        slug_log.append(result[0])
        stars_log.append(result[1])
        watchers_log.append(result[2])
        forks_log.append(result[3])
        topics_log.append(result[4])


final_log = pd.DataFrame({'slug': slug_log, "stars": stars_log, 'watchers': watchers_log, 'forks': forks_log, 'topics': topics_log}, columns=["slug", "stars", "watchers", "forks", "topics"])

end_time = datetime.datetime.now()
print("Finished scraping", len(final_log), "of", len(slugs), "records at", end_time)
print("It took", end_time-start_time, "to run.")
# Out:
# There are 39 cores available.
# 404
# WARNING: Unknown object exception -- rrrrrrrrr
# Start scraping. Start time: 2021-06-23 11:22:11.104201
# ~~~~~~~~~~~~~~~result:  ('rrrrrrrrr', None, None, None, None) ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~result:  ('DSPG-Young-Scholars-Program/dspg21oss', 0, 3, 0, []) ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~result:  ('moderndive/ModernDive_book', 548, 28, 295, ['moderndive', 'data-science', 'tidyverse', 'statistical-inference', 'r', 'ggplot2', 'infer', 'hypothesis-testing', 'confidence-intervals', 'regression', 'regression-models', 'data-visualization', 'data-wrangling', 'tidy', 'rstudio', 'rstats', 'dplyr', 'bootstrap-method', 'permutation-test']) ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~result:  ('moderndive/ModernDive_book', 548, 28, 295, ['moderndive', 'data-science', 'tidyverse', 'statistical-inference', 'r', 'ggplot2', 'infer', 'hypothesis-testing', 'confidence-intervals', 'regression', 'regression-models', 'data-visualization', 'data-wrangling', 'tidy', 'rstudio', 'rstats', 'dplyr', 'bootstrap-method', 'permutation-test']) ~~~~~~~~~~~~~~~~
# Finished scraping 4 of 4 records at 2021-06-23 11:22:11.378817
# It took 0:00:00.274616 to run.

# %%
final_log
# Out:
#                                     slug  stars  watchers  forks  \
# 0                              rrrrrrrrr    NaN       NaN    NaN
# 1  DSPG-Young-Scholars-Program/dspg21oss    0.0       3.0    0.0
# 2             moderndive/ModernDive_book  548.0      28.0  295.0
# 3             moderndive/ModernDive_book  548.0      28.0  295.0
#
#                                               topics
# 0                                               None
# 1                                                 []
# 2  [moderndive, data-science, tidyverse, statisti...
# 3  [moderndive, data-science, tidyverse, statisti...

# %%
#final_log.to_csv(r'/home/zz3hs/git/dspg21oss/data/dspg21oss/final_log_try.csv', index = False)

# %%
# read in the file and check
print(final_log.head())
print(final_log)
print(final_log.isna().sum())
print(final_log.shape)
# Out:
#                                     slug  stars  watchers  forks  \
# 0                              rrrrrrrrr    NaN       NaN    NaN
# 1  DSPG-Young-Scholars-Program/dspg21oss    0.0       3.0    0.0
# 2             moderndive/ModernDive_book  548.0      28.0  295.0
# 3             moderndive/ModernDive_book  548.0      28.0  295.0
#
#                                               topics
# 0                                               None
# 1                                                 []
# 2  [moderndive, data-science, tidyverse, statisti...
# 3  [moderndive, data-science, tidyverse, statisti...
#                                     slug  stars  watchers  forks  \
# 0                              rrrrrrrrr    NaN       NaN    NaN
# 1  DSPG-Young-Scholars-Program/dspg21oss    0.0       3.0    0.0
# 2             moderndive/ModernDive_book  548.0      28.0  295.0
# 3             moderndive/ModernDive_book  548.0      28.0  295.0
#
#                                               topics
# 0                                               None
# 1                                                 []
# 2  [moderndive, data-science, tidyverse, statisti...
# 3  [moderndive, data-science, tidyverse, statisti...
# slug        0
# stars       1
# watchers    1
# forks       1
# topics      1
# dtype: int64
# (4, 5)

# %% [raw]
# # concactinate scrapped dataframes together
# df1 = pd.read_csv('/home/zz3hs/git/dspg21oss/data/dspg21oss/repo_stats_bt_1000_1500.csv') #import csv
# print(df1.shape)
# df2 = pd.read_csv('/home/zz3hs/git/dspg21oss/data/dspg21oss/repo_stats_bt_1500_2000.csv') #import csv
# print(df2.shape)
# df3 = pd.read_csv('/home/zz3hs/git/dspg21oss/data/dspg21oss/repo_stats_bt_2000_4500.csv') #import csv
# print(df3.shape)
# df4 = pd.read_csv('/home/zz3hs/git/dspg21oss/data/dspg21oss/repo_stats_gt_3000.csv') #import csv
# print(df4.shape)
#
#
# frames = [df1, df2, df3, df4]
#
# repo_stats_gt_1000 = pd.concat(frames)
#
# repo_stats_gt_1000 = repo_stats_gt_1000.drop_duplicates(subset = 'slug', keep = 'first')
# print("We scrapped",repo_stats_gt_1000.shape[0], "repos, that have greater than 1000 commits.")
#
# #repo_stats_gt_3000.to_csv(r'/home/zz3hs/git/dspg21oss/data/dspg21oss/repo_stats_gt_3000.csv', index = False)
