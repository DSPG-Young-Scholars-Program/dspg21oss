# %% [markdown]
# # Scrap repo stats using PyGitHub

# %% [markdown]
# ### Author: Crystal Zang

# %% [markdown]
# This notebook utilized GitHub access tokens (PAT) to scrape GitHub repository statistics such as stargazers, watchers, forks, and topics. One PAT would scrape at a rate of 5000 repositories per hour. Utilizing 36 PATs we would scrape 10,288,063 repositories in about XXX hours at a rate of 15,514 repositories per hour.

# %% [markdown]
# #### Warnings
# You should not commit any access topen to GitHub, which would result in access token being revoked.

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
# load packages 
import os
import psycopg2 as pg
from sqlalchemy import create_engine
import pandas as pd
import requests as r
import string 
import json
import base64
import urllib.request
import itertools 
import numpy as np
from bs4 import BeautifulSoup
from dotenv import load_dotenv
from github import Github, RateLimitExceededException, BadCredentialsException, BadAttributeException, GithubException, UnknownObjectException, BadUserAgentException
import warnings
import datetime

import multiprocessing
#from multiprocessing.pool import ThreadPool as Pool
from multiprocessing import Pool, freeze_support

import concurrent.futures

warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
#os.environ['db_user'] = ''
#os.environ['db_pwd'] = ''

# connect to the database, download data, limit to repos with at least 20,000 commits?
connection = pg.connect(host = 'postgis1', database = 'sdad', 
                        user = os.environ.get('db_user'), 
                        password = os.environ.get('db_pwd'))

raw_slug_data = '''SELECT * FROM gh_2007_2020.repos_ranked WHERE (commits BETWEEN '700' AND '800')'''
#raw_slug_data = '''SELECT * FROM gh_2007_2020.repos_ranked WHERE commits < 1000'''

# convert to a dataframe, show how many missing we have (none)
raw_slug_data = pd.read_sql_query(raw_slug_data, con=connection)

connection.close()


print(raw_slug_data.head())
print(raw_slug_data.shape)
print(raw_slug_data.isna().sum())

# %%
raw_slug_data = pd.read_csv('/home/zz3hs/git/dspg21oss/data/dspg21oss/crystal_to_scrape_0712.csv') #import csv

# %%
#get rid of leading and ending space, save slugs to a list
raw_slugs = raw_slug_data["slug"].tolist()
slugs = []
for s in raw_slugs:
    slugs.append(s.strip())  
print(len(slugs))
print(slugs[0], slugs[len(slugs)-1])
# Out:
# 144196
# coderZsq/coderZsq.project.ios moxi624/mogu_blog_v2

# %%
os.environ['db_user'] = ''
os.environ['db_pwd'] = ''

# connect to the database, download data, limit to repos with at least 20,000 commits?
connection = pg.connect(host = 'postgis1', database = 'sdad', 
                        user = os.environ.get('db_user'), 
                        password = os.environ.get('db_pwd'))

#PATs access token, saved as a dataframe
github_pats = '''SELECT * FROM gh_2007_2020.pats_update'''
github_pats = pd.read_sql_query(github_pats, con=connection)

#PATs access token, saved as a list
access_tokens = github_pats["token"]

#number of tokens available for use, a numeric value
num_token = '''SELECT COUNT(*) FROM gh_2007_2020.pats_update'''
num_token = pd.read_sql_query(num_token, con=connection)
num_token=num_token.iloc[0]['count']

connection.close()

# %%
# index ranges from 0 to maximum number of PATs available
def get_access_token(github_pat_index):
    if github_pat_index < num_token:
       # print("Extracting access token #", github_pat_index+1,", total", num_token, "tokens are available.")
        return github_pats.token[github_pat_index]
    else:
        print("token exceed limit")

# %%
len(access_tokens)
# Out:
# 34

# %% [markdown]
# # Not using any multiprocessing

# %%
def pull_repo_stats(github_pat_index, slugs):
    df_repo_stats = pd.DataFrame()
    for slug in slugs:
        if github_pat_index >= len(access_tokens):
            github_pat_index -= len(access_tokens)
            print("***Pat access token exceed limit, restart access token loop with #", github_pat_index)
        while github_pat_index < len(access_tokens):
            try:
                access_token = get_access_token(github_pat_index)
                #print("Scrapping --", slug,". Extracting access token #", github_pat_index+1,", total", num_token, "tokens are available.")
                #if false, retry until true, max number of retry is 20 times
                g = Github(access_token, retry = 20, timeout = 15)
                repo = g.get_repo(slug)
                df_repo_stats = df_repo_stats.append({
                    "slug": slug,
                    'stars': repo.stargazers_count,
                    'watchers': repo.subscribers_count,
                    'forks': repo.forks_count,
                    'topics': repo.get_topics()
                }, ignore_index = True)
            except RateLimitExceededException as e:
                print(e.status)
                print('Rate limit exceeded --', slug, ", using access token #", github_pat_index)
                print("Current time:", datetime.datetime.now())
                #time.sleep(300)
                github_pat_index+=1
                print("***Exit current access token, proceed with next aceess token #", github_pat_index, "rescrape --",slug)
                break
            except BadCredentialsException as e:
                print(e.status)
                print('Bad credentials exception --', slug, ", using access token #", github_pat_index)
                print("Current time:", datetime.datetime.now())
                github_pat_index+=1
                print("***Exit current access token, proceed with next aceess token #", github_pat_index, "rescrape --",slug)
                break
            except UnknownObjectException as e:
                print(e.status)
                print('Unknown object exception --', slug)
                break
            except GithubException as e:
                print(e.status)
                print('General exception --', slug)
                break
            except r.exceptions.ConnectionError as e:
                print('Retries limit exceeded --', slug)
                print(str(e))
                time.sleep(10)
                continue
            except r.exceptions.Timeout as e:
                print('Time out exception --', slug)
                print(str(e))
                time.sleep(10)
                continue
            break
    return df_repo_stats

# %%
len(slugs)
# Out:
# 144196

# %%
slugs1 = slugs[0:20000] 
slugs2 = slugs[20001:40000] 
slugs3 = slugs[40001:60000] 


start_time = datetime.datetime.now()
print("Start scraping:", start_time)
df_repo_stats = pull_repo_stats(0, slugs3)
end_time =  datetime.datetime.now()
print("Finished scraping", len(df_repo_stats), "of", len(slugs3), "records at", end_time)
print("It took", end_time-start_time, "to run.")
# Out:
# Start scraping: 2021-07-12 21:32:52.087075
# 404
# Unknown object exception -- xalid77/morelinq
# 404
# Unknown object exception -- jbaglion/angular6-example-app-Ismaestro
# 404
# Unknown object exception -- Blarse/dwm
# 404
# Unknown object exception -- zhangjing5208/node.js
# 404
# Unknown object exception -- neilmovva/netlifytest-hugo
# 404
# Unknown object exception -- garrettseward/react-router-reborn
# 404
# Unknown object exception -- gitalvininfo/ecommerece
# 404
# Unknown object exception -- dasbadgersen/HoomeDomotica
# 404
# Unknown object exception -- macchioni/one-click-hugo-cms
# 404
# Unknown object exception -- greyspot09/macbootstrap
# 404
# Unknown object exception -- MarcoBiscar/react_rails_example
# 404
# Unknown object exception -- DoctaRay/winit-veloren
# 404
# Unknown object exception -- Cryptorubic/rubic_scanner
# 404
# Unknown object exception -- james5deutschland/schroot_new
# 404
# Unknown object exception -- josenorberto/moodle-docker-alpine
# 404
# Unknown object exception -- GiulioGx/RNNs
# 404
# Unknown object exception -- markcaudill/pubstrate
# 404
# Unknown object exception -- notsupposed/netlify-hugo
# 404
# Unknown object exception -- snowman03/Discord.RSS
# 404
# Unknown object exception -- FxMain/ardupilot
# 404
# Unknown object exception -- Highjhacker/hello_world_zererzaazereareza_core
# 404
# Unknown object exception -- wjmiller/one-click-hugo-cms
# 404
# Unknown object exception -- saurav2799/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- sbngross/sdwm
# 404
# Unknown object exception -- Highjhacker/my_demo_chain_explorer
# 404
# Unknown object exception -- Highjhacker/my_demo_chain_core
# 404
# Unknown object exception -- JayPatel1314/Tanjiro-Kamado
# 404
# Unknown object exception -- Uday0011/Ashtestbot
# 404
# Unknown object exception -- yekta/natrium_wallet_flutter
# 404
# Unknown object exception -- cjbd/dav1d
# 404
# Unknown object exception -- Kuscko/runelite
# 404
# Unknown object exception -- dredaz3/dotfiles2
# 404
# Unknown object exception -- cjbd/openh264
# 404
# Unknown object exception -- mofax/cardpeek
# 404
# Unknown object exception -- gmassei/wfrog
# 404
# Unknown object exception -- hemetsu/davidhuang
# 404
# Unknown object exception -- ddppfamily/xgb
# 404
# Unknown object exception -- cyberheartmi9/interactive-tutorials
# 404
# Unknown object exception -- margyUnipi/MyOverallApp
# 404
# Unknown object exception -- teriusbin/airflow
# 404
# Unknown object exception -- newaosvp2019/android_build_kati
# 404
# Unknown object exception -- gsezis/mobileApp
# 404
# Unknown object exception -- BluestNight/Midnight
# 404
# Unknown object exception -- simmonn/ant-design-pro
# 404
# Unknown object exception -- TheBezik/ytSubscribersCount
# 404
# Unknown object exception -- csrui/price-check
# 404
# Unknown object exception -- kellygorr/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- JohnBrower/ngx-datatable-insight
# 404
# Unknown object exception -- mdts-dev/fairpharma-landing
# 404
# Unknown object exception -- zxostudio/gatsby-starter-default
# 404
# Unknown object exception -- Ihhar/gatsby-starter-default
# 404
# Unknown object exception -- 4nkit-5hukla/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- christiankopac/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- dai-dinamici/dinamici-web
# 404
# Unknown object exception -- Tuba202/faceswapelliot
# 403
# Rate limit exceeded -- reactDev037/angular-2-grid , using access token # 0
# Current time: 2021-07-12 21:38:45.289061
# ***Exit current access token, proceed with next aceess token # 1 rescrape -- reactDev037/angular-2-grid
# 404
# Unknown object exception -- MdotMertens/personal-website
# 404
# Unknown object exception -- ArrenBryan/Sansa
# 404
# Unknown object exception -- hunsalz/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- faom/faom-test-jam
# 404
# Unknown object exception -- likens/mygorma-netlify
# 404
# Unknown object exception -- VictorGabrielCorrea/panel-docker
# 404
# Unknown object exception -- derickboss1/st
# 404
# Unknown object exception -- kwaledesign/test-gatsby-netlify
# 404
# Unknown object exception -- hanson-hex/vue-element-admin
# 404
# Unknown object exception -- tttranquilooo/tttranquilooo.github.io
# 404
# Unknown object exception -- gfappsandroid/extra-tunnel
# 404
# Unknown object exception -- leroyrosales/one-click-hugo-cms
# 404
# Unknown object exception -- malusursidae/hugo-cms3
# 404
# Unknown object exception -- cheechster/waterboard-sean-hannity
# 404
# Unknown object exception -- coldsink/dwm
# 404
# Unknown object exception -- sector7g/nssm
# 404
# Unknown object exception -- ayuemoy/youtube-dl-1
# 404
# Unknown object exception -- bianan/bianan.github.io
# 404
# Unknown object exception -- Alwnikrotikz/formalchemy
# 404
# Unknown object exception -- uqlibrary/fez
# 404
# Unknown object exception -- RandallDW/Aruba_plugin
# 404
# Unknown object exception -- marcinbedus/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- Go-Merk/Ackee
# 404
# Unknown object exception -- prenkert/netlify_cms_starter
# 404
# Unknown object exception -- awyxx/dwm
# 404
# Unknown object exception -- dynamicstrategies/dsio-education
# 404
# Unknown object exception -- ashwinpreet/gatsby-starter-default
# 404
# Unknown object exception -- arnebackstein/Backstein-host
# 404
# Unknown object exception -- Abbath90/AdminLTE
# 404
# Unknown object exception -- slmr/lyrics-gatsby
# 404
# Unknown object exception -- sheeshkebab/workshops
# 404
# Unknown object exception -- Abbath90/fiasko_bro
# 404
# Unknown object exception -- Abbath90/jekyll
# 404
# Unknown object exception -- thyphenj/timeoff-management
# 404
# Unknown object exception -- lynzhen/mike
# 404
# Unknown object exception -- kappamax/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- javagoza/Seeed
# 404
# Unknown object exception -- vaporry/pyethapp
# 404
# Unknown object exception -- vaporry/evmjit
# 404
# Unknown object exception -- vaporry/pyethereum
# 404
# Unknown object exception -- vaporry/mix
# 404
# Unknown object exception -- vaporry/ethereum-buildbot
# 404
# Unknown object exception -- vaporry/solidity
# 404
# Unknown object exception -- MicroFocus/cluster-tasks-service
# 404
# Unknown object exception -- manishnegi007/Nothing
# 404
# Unknown object exception -- philjzmith/pjzmith-cv
# 404
# Unknown object exception -- weinni2000/lisigruen
# 404
# Unknown object exception -- Desterio/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- wvrossem/sts-migtec-cms
# 404
# Unknown object exception -- wldlsmttn/sneakersblack
# 404
# Unknown object exception -- optlsnd/gatsby-starter-netlify-cms-test
# 404
# Unknown object exception -- Kheirah/Spirits-Dont-Fly-Website
# 404
# Unknown object exception -- sbadillo/testHugo
# 404
# Unknown object exception -- iotexproject/web-native-staking-v2
# 404
# Unknown object exception -- Sdeakin93/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- xavierconnelly/gatsby-starter-default
# 404
# Unknown object exception -- japetheape/one-click-hugo-cms
# 404
# Unknown object exception -- demominwt/one-click-hugo-cms
# 404
# Unknown object exception -- trioctodev/Triocto-CMS-Test
# 404
# Unknown object exception -- trioctodev/hugo-cms-in-one-click
# 403
# Rate limit exceeded -- hackersden09/fatrat , using access token # 1
# Current time: 2021-07-12 21:43:29.156855
# ***Exit current access token, proceed with next aceess token # 2 rescrape -- hackersden09/fatrat
# 401
# Bad credentials exception -- romaaji/WebShell , using access token # 2
# Current time: 2021-07-12 21:43:29.223287
# ***Exit current access token, proceed with next aceess token # 3 rescrape -- romaaji/WebShell
# 404
# Unknown object exception -- lceric/nodebb
# 404
# Unknown object exception -- yangxu351/yxu-yolov3-xview
# 404
# Unknown object exception -- larskarbo/one-click-hugo-cms
# 404
# Unknown object exception -- JakeRoggenbuck/st
# 404
# Unknown object exception -- TheMysteryperson/tn-test
# 404
# Unknown object exception -- bwalden1/netlify-identity-test
# 404
# Unknown object exception -- lilinghai/tidb-ansible
# 404
# Unknown object exception -- raphaelSFGP/SFGP.Healthcheck
# 404
# Unknown object exception -- annwntech/micro
# 404
# Unknown object exception -- atlancloud/atlas
# 404
# Unknown object exception -- petrachor/blockscout
# 404
# Unknown object exception -- elementh/elguayabot
# 404
# Unknown object exception -- daviur/dotfiles
# 404
# Unknown object exception -- AdiBev/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- monsieurmonsieur/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- baiwen908/3322
# 404
# Unknown object exception -- shawner18/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- lawleagle/dwm
# 404
# Unknown object exception -- mroberts1/mrsh
# 404
# Unknown object exception -- Quillee/northwell_presentation
# 404
# Unknown object exception -- CandleFW/wick
# 404
# Unknown object exception -- AnandRao82/bigbluebutton
# 404
# Unknown object exception -- ampie/test
# 404
# Unknown object exception -- bubnov-mikhail/sitebeat
# 404
# Unknown object exception -- arramos84/cs169-hw5
# 404
# Unknown object exception -- looeee/blackthreaddesign.com
# 404
# Unknown object exception -- rafaga3r/ar-01
# 404
# Unknown object exception -- jdrag12/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- ethanwhite/one-click-hugo-cms
# 404
# Unknown object exception -- Highjhacker/conflictozzzza_core
# 404
# Unknown object exception -- ji4mh/ariang
# 404
# Unknown object exception -- quintablet/googletest
# 404
# Unknown object exception -- crdschurch/crds-corkboard
# 404
# Unknown object exception -- davidam/libremanuals.github.io
# 404
# Unknown object exception -- yasinfakhar/yasin-fakhar-cms
# 404
# Unknown object exception -- minato-kei/go-app
# 404
# Unknown object exception -- ndminhdev/blog-netlify-cms
# 404
# Unknown object exception -- vitorvanacor/netlify-cms-test
# 404
# Unknown object exception -- wodeyaoyao/electron-vue
# 403
# Rate limit exceeded -- Edith2pointOh/gatsby-starter-netlify-cms , using access token # 3
# Current time: 2021-07-12 21:48:16.147464
# ***Exit current access token, proceed with next aceess token # 4 rescrape -- Edith2pointOh/gatsby-starter-netlify-cms
# 403
# Rate limit exceeded -- rameshmusvathi/10th-Nov-gatsby-starter-netlify-cms , using access token # 4
# Current time: 2021-07-12 21:48:16.222136
# ***Exit current access token, proceed with next aceess token # 5 rescrape -- rameshmusvathi/10th-Nov-gatsby-starter-netlify-cms
# 404
# Unknown object exception -- prajna-io/rengu-data
# 404
# Unknown object exception -- gabrielmedel/gatsby-starter-default
# 404
# Unknown object exception -- Ezhik-777/Java-NIO
# 404
# Unknown object exception -- gentoo-mirror/causelay
# 403
# Rate limit exceeded -- TeleAgentsTeam/TeleAgents , using access token # 5
# Current time: 2021-07-12 21:48:57.805064
# ***Exit current access token, proceed with next aceess token # 6 rescrape -- TeleAgentsTeam/TeleAgents
# 404
# Unknown object exception -- melodycurtis/jackson
# 404
# Unknown object exception -- vachanmn123/MCGG
# 404
# Unknown object exception -- tomiwaAdey/gatsby-starter-netlify-cms-tomiwa-1
# 403
# Rate limit exceeded -- italonascimento/nina-farkas-cms , using access token # 6
# Current time: 2021-07-12 21:49:44.858331
# ***Exit current access token, proceed with next aceess token # 7 rescrape -- italonascimento/nina-farkas-cms
# 404
# Unknown object exception -- adrianfaciu/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- addismulugeta/mulugeta.partners
# 404
# Unknown object exception -- tp1234/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- isp13/Resume_yandex
# 404
# Unknown object exception -- abbott567/bsp-agent
# 404
# Unknown object exception -- jasmine-tt/py_arima
# 404
# Unknown object exception -- nickolansk/ncdc
# 404
# Unknown object exception -- ymmah/secp256k1
# 404
# Unknown object exception -- lab-lion/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- Amorpheuz/temporary-gatsby-starter-netlify-cms
# 404
# Unknown object exception -- gaiachik/gatsby-starter-netlify-cms-2
# 404
# Unknown object exception -- SalomonAber/dmenu
# 404
# Unknown object exception -- facturaperu/facturadorpro20201220
# 404
# Unknown object exception -- alvarobelmonte/graphic-designer-website
# 404
# Unknown object exception -- ict4g/ssror13_material
# 403
# Rate limit exceeded -- AlexZhidkov/polina-sasha , using access token # 7
# Current time: 2021-07-12 21:50:46.428402
# ***Exit current access token, proceed with next aceess token # 8 rescrape -- AlexZhidkov/polina-sasha
# 404
# Unknown object exception -- devillers/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- realparmesan/chris-website
# 404
# Unknown object exception -- oliverw1/GildedRose-Refactoring-Kata
# 404
# Unknown object exception -- MickNorris/blog
# 404
# Unknown object exception -- zofepod/zofe
# 404
# Unknown object exception -- aequologica/buildhub
# 404
# Unknown object exception -- aequologica/shakuntala
# 404
# Unknown object exception -- isbmremde/jib
# 404
# Unknown object exception -- vuongdh/fabcar
# 404
# Unknown object exception -- S-TraceStudio/Crashpad
# 404
# Unknown object exception -- EuanScott/ionic5_animations
# 403
# Rate limit exceeded -- bamboolife/NCalendar , using access token # 8
# Current time: 2021-07-12 21:51:46.198366
# ***Exit current access token, proceed with next aceess token # 9 rescrape -- bamboolife/NCalendar
# 404
# Unknown object exception -- botijo/october
# 404
# Unknown object exception -- holypoli/gatsby-netlify-cms
# 404
# Unknown object exception -- kenanajkunic/st
# 404
# Unknown object exception -- DanielaValero/one-click-hugo-cms
# 404
# Unknown object exception -- rlarkdms/rlarkdms.github.io
# 404
# Unknown object exception -- Quasimobi/one-click-hugo-cms
# 404
# Unknown object exception -- zjla/one-click-hugo-cms
# 404
# Unknown object exception -- Faris0520/fork-nadeko
# 404
# Unknown object exception -- china-liweihong/oa_system
# 404
# Unknown object exception -- ad798/atuk-blog
# 404
# Unknown object exception -- thehiddencheese/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- 0x9dhcf/dwm
# 404
# Unknown object exception -- filippo20u/test-cms
# 404
# Unknown object exception -- dejavuejs/orca
# 404
# Unknown object exception -- newpathfly/newpathfly-website
# 403
# Rate limit exceeded -- neillj14/gatsbytut , using access token # 9
# Current time: 2021-07-12 21:52:35.892298
# ***Exit current access token, proceed with next aceess token # 10 rescrape -- neillj14/gatsbytut
# 401
# Bad credentials exception -- fratava/one-click-hugo-cms , using access token # 10
# Current time: 2021-07-12 21:52:35.960318
# ***Exit current access token, proceed with next aceess token # 11 rescrape -- fratava/one-click-hugo-cms
# 404
# Unknown object exception -- fuxii/sd2iec
# 404
# Unknown object exception -- skehya/cms
# 404
# Unknown object exception -- abmera/ZXing
# 403
# Rate limit exceeded -- sunrex-taga/srx-editest , using access token # 11
# Current time: 2021-07-12 21:53:24.978430
# ***Exit current access token, proceed with next aceess token # 12 rescrape -- sunrex-taga/srx-editest
# 404
# Unknown object exception -- marquesinijatinha/dev2.braytech.org
# 404
# Unknown object exception -- TheRealCasadaro/gatsby-starter-blog
# 404
# Unknown object exception -- reddcraft/provider-engine
# 404
# Unknown object exception -- Druddigon/react-redux-learn
# 404
# Unknown object exception -- exoeconomy/EXOSFullNode
# 403
# Rate limit exceeded -- matthiasludwig/deep-learning-udacity-material , using access token # 12
# Current time: 2021-07-12 21:54:12.695479
# ***Exit current access token, proceed with next aceess token # 13 rescrape -- matthiasludwig/deep-learning-udacity-material
# 404
# Unknown object exception -- chanchann/chanchann.github.io
# 404
# Unknown object exception -- josh38/bitcoin_
# 404
# Unknown object exception -- meanmdevs/one-click-hugo-cms
# 404
# Unknown object exception -- facturaperu/facturadorpro20201116
# 404
# Unknown object exception -- alephzerofoundation/Proof-of-Concept
# 404
# Unknown object exception -- ansible/ansible-bare
# 404
# Unknown object exception -- shangcheng233/-
# 404
# Unknown object exception -- ss4ws/one-click-hugo-cms
# 404
# Unknown object exception -- devdarren7/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- Dsantiagomj/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- apl-kris/one-click-hugo-cms
# 404
# Unknown object exception -- apl-kris/gatsby-netlify-kp
# 404
# Unknown object exception -- dong0833/study1
# 404
# Unknown object exception -- MilanPospisil/ansible_galaxy
# 404
# Unknown object exception -- Ravi-Kaushish/swagger-editor
# 404
# Unknown object exception -- rassabin/mmdetection_aircraft
# 404
# Unknown object exception -- sfc-gh-sca-sa/snowflake-jdbc-wss
# 403
# Rate limit exceeded -- PolicyStat/ckeditor-plugin-structured-headings , using access token # 13
# Current time: 2021-07-12 21:55:46.384423
# ***Exit current access token, proceed with next aceess token # 14 rescrape -- PolicyStat/ckeditor-plugin-structured-headings
# 404
# Unknown object exception -- sulaimanvesal/speech-to-text-nodejs-1481642083847
# 404
# Unknown object exception -- crdschurch/crds-mp-tools
# 404
# Unknown object exception -- crdschurch/crds-service-finance
# 404
# Unknown object exception -- emergenetwork/go-loom
# 404
# Unknown object exception -- emergenetwork/loom-js
# 404
# Unknown object exception -- cysys/ghost-openshift
# 404
# Unknown object exception -- brierley/brierley.github.io
# 403
# Rate limit exceeded -- psyphh/lslx , using access token # 14
# Current time: 2021-07-12 21:56:45.959433
# ***Exit current access token, proceed with next aceess token # 15 rescrape -- psyphh/lslx
# 404
# Unknown object exception -- gentoo-mirror/didactic-duck
# 404
# Unknown object exception -- ndtom/Signull-Android
# 404
# Unknown object exception -- gameloophub/Gameloop
# 404
# Unknown object exception -- Highjhacker/fooblehzenzou_core
# 404
# Unknown object exception -- Khan-Design/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- julessaysrawr/one-click-hugo-cms
# 404
# Unknown object exception -- Highjhacker/fooblehzenzou_explorer
# 404
# Unknown object exception -- cloudera/kafka
# 403
# Rate limit exceeded -- aymenlaadhari/ionicStarter , using access token # 15
# Current time: 2021-07-12 21:57:46.006767
# ***Exit current access token, proceed with next aceess token # 16 rescrape -- aymenlaadhari/ionicStarter
# 404
# Unknown object exception -- YangXi8888/ionicApp
# 404
# Unknown object exception -- soura99/st
# 404
# Unknown object exception -- quiply/quiply-website-hugo-netlify
# 404
# Unknown object exception -- quiply/quiply-website-hugo-cms
# 404
# Unknown object exception -- pz-mxu/one-click-hugo-cms
# 404
# Unknown object exception -- efah/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- naveenrnimmala/one-click-hugo-cms
# 404
# Unknown object exception -- malemu17/gatsby-starter-default
# 404
# Unknown object exception -- wnesbv69/nlp
# 404
# Unknown object exception -- nagahebbar/app7
# 404
# Unknown object exception -- gregvissing/lets-revue
# 404
# Unknown object exception -- JorriFransen/zodiac_attempt_2
# 403
# Rate limit exceeded -- codejtech/codejtech-netlify-cms , using access token # 16
# Current time: 2021-07-12 21:58:46.140586
# ***Exit current access token, proceed with next aceess token # 17 rescrape -- codejtech/codejtech-netlify-cms
# 404
# Unknown object exception -- stellamathew/sd
# 404
# Unknown object exception -- Ultimate-Hosts-Blacklist/hpHosts---GRM
# 404
# Unknown object exception -- galenguyer/GenericBot
# 404
# Unknown object exception -- AvaroOS/GnomeUI
# 404
# Unknown object exception -- kasymovga/fteqcc
# 403
# Rate limit exceeded -- Scrum/slims , using access token # 17
# Current time: 2021-07-12 21:59:46.048090
# ***Exit current access token, proceed with next aceess token # 18 rescrape -- Scrum/slims
# 404
# Unknown object exception -- polarcat/dwm
# 404
# Unknown object exception -- ColErr/creepr-workbench
# 404
# Unknown object exception -- jacksoncodispoti/mp1
# 404
# Unknown object exception -- spray2gray/sockshop-microservices-demo
# 404
# Unknown object exception -- shubhamchopade/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- m0strils/hugo-cms
# 404
# Unknown object exception -- Pablets/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- gbif/ssg-bid
# 403
# Rate limit exceeded -- KoreaCloudObjectStorage/swift3 , using access token # 18
# Current time: 2021-07-12 22:00:44.629743
# ***Exit current access token, proceed with next aceess token # 19 rescrape -- KoreaCloudObjectStorage/swift3
# 404
# Unknown object exception -- silenc3502/VehicleIntegrationRepo
# 404
# Unknown object exception -- gentoo-mirror/imaging
# 404
# Unknown object exception -- PEPSINEX/laradock
# 404
# Unknown object exception -- eybarra10/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- dbessa1/cordova-plugin-firebase_TOPSALAO_1086
# 404
# Unknown object exception -- dennys-bd/blog
# 404
# Unknown object exception -- logogriph2/cognigraph
# 404
# Unknown object exception -- onweru/carl
# 403
# Rate limit exceeded -- chattyzilla-labs/emoji-selector , using access token # 19
# Current time: 2021-07-12 22:01:46.060947
# ***Exit current access token, proceed with next aceess token # 20 rescrape -- chattyzilla-labs/emoji-selector
# 404
# Unknown object exception -- srcUp/u-root-old
# 404
# Unknown object exception -- claudineyqr/ispconfig3
# 404
# Unknown object exception -- catho/spalatum
# 404
# Unknown object exception -- Safary1094/MultiQC
# 404
# Unknown object exception -- shengwen-tw/ursus-pilot_with_optical-flow
# 404
# Unknown object exception -- soorosh/soorosh
# 404
# Unknown object exception -- soorosh/appshackbot
# 403
# Rate limit exceeded -- moxon-lab-codebase/MATLAB-offline-neural-analysis , using access token # 20
# Current time: 2021-07-12 22:02:46.001044
# ***Exit current access token, proceed with next aceess token # 21 rescrape -- moxon-lab-codebase/MATLAB-offline-neural-analysis
# 404
# Unknown object exception -- LincolnTechOpenSource/lincoln-gps
# 404
# Unknown object exception -- Technical-Elite/Elite
# 404
# Unknown object exception -- yqrashawn/fzf
# 404
# Unknown object exception -- wespiper/skar
# 404
# Unknown object exception -- setherroni/homebridge-broadlink-rm
# 403
# Rate limit exceeded -- yiqi19940531/collections , using access token # 21
# Current time: 2021-07-12 22:03:45.840155
# ***Exit current access token, proceed with next aceess token # 22 rescrape -- yiqi19940531/collections
# 404
# Unknown object exception -- cpontet/play14-netlify
# 404
# Unknown object exception -- techdot/one-click-hugo-cms
# 404
# Unknown object exception -- havardgulldahl/pling-plong-odometer
# 404
# Unknown object exception -- len/Domains
# 404
# Unknown object exception -- MikeiLL/MaterialSage
# 403
# Rate limit exceeded -- aci-ref/aci-ref.github.io , using access token # 22
# Current time: 2021-07-12 22:04:45.634814
# ***Exit current access token, proceed with next aceess token # 23 rescrape -- aci-ref/aci-ref.github.io
# 403
# Rate limit exceeded -- cbg-ethz/perturbatr , using access token # 23
# Current time: 2021-07-12 22:05:00.372005
# ***Exit current access token, proceed with next aceess token # 24 rescrape -- cbg-ethz/perturbatr
# 403
# Rate limit exceeded -- benrau87/fark , using access token # 24
# Current time: 2021-07-12 22:05:00.442735
# ***Exit current access token, proceed with next aceess token # 25 rescrape -- benrau87/fark
# 403
# Rate limit exceeded -- lcappuccio/filtering-ads-with-linux , using access token # 25
# Current time: 2021-07-12 22:05:00.526007
# ***Exit current access token, proceed with next aceess token # 26 rescrape -- lcappuccio/filtering-ads-with-linux
# 404
# Unknown object exception -- takaxp/org-mode
# 404
# Unknown object exception -- SherG/gridsome
# 404
# Unknown object exception -- reggaeman1/mycodepad
# 404
# Unknown object exception -- ParthoTech/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- rawluck/gatsby-blog
# 404
# Unknown object exception -- nrenc027/gatsby-starter-default
# 403
# Rate limit exceeded -- jeffBaz/respond , using access token # 26
# Current time: 2021-07-12 22:05:50.016620
# ***Exit current access token, proceed with next aceess token # 27 rescrape -- jeffBaz/respond
# 404
# Unknown object exception -- SuperSupeng/javaWebProjects
# 404
# Unknown object exception -- rssntn67/SubscriptionManagementDashboard
# 404
# Unknown object exception -- sarahjcotton/gitflowtesting
# 404
# Unknown object exception -- SiberianCrab/OMW-from-Capo
# 404
# Unknown object exception -- Mets3D/blender
# 404
# Unknown object exception -- elevatorup/eu-suspenders
# 404
# Unknown object exception -- nglglhtr/one-click-hugo-cms
# 404
# Unknown object exception -- Highjhacker/my_chainqsdqdqsdqgretertgerds_explorer
# 404
# Unknown object exception -- Highjhacker/my_chainqsdqdqsdqgretertgerds_core
# 404
# Unknown object exception -- Highjhacker/myfdqfdsqfdsqfqsdfsq_chain_explorer
# 404
# Unknown object exception -- ESpolit/Musicans
# 403
# Rate limit exceeded -- Jahia/javascript-components , using access token # 27
# Current time: 2021-07-12 22:06:47.874524
# ***Exit current access token, proceed with next aceess token # 28 rescrape -- Jahia/javascript-components
# 404
# Unknown object exception -- lmcgrath/sterling
# 404
# Unknown object exception -- holgern/HiveJ
# 404
# Unknown object exception -- gabrielbonifaz/geonode2.10
# 404
# Unknown object exception -- uyupun/chat-mammoth
# 404
# Unknown object exception -- uport-project/developers
# 404
# Unknown object exception -- m3nt0l/testcolor
# 404
# Unknown object exception -- jcarboneri/simple-tc-pi-blx-demo
# 404
# Unknown object exception -- ymmah/BitGoJS
# 404
# Unknown object exception -- ZroIsHere/opennos.netcore
# 403
# Rate limit exceeded -- wdlkmpx/lxrandr , using access token # 28
# Current time: 2021-07-12 22:07:32.925028
# ***Exit current access token, proceed with next aceess token # 29 rescrape -- wdlkmpx/lxrandr
# 404
# Unknown object exception -- coderlabx/spambox
# 404
# Unknown object exception -- antonellocaroli/script64-1.6
# 404
# Unknown object exception -- sunny2019/ETLearning
# 404
# Unknown object exception -- aprilyw/cawws-site
# 404
# Unknown object exception -- l0rdmoney/webtest
# 404
# Unknown object exception -- pamandrejko/marbles-20180314131837301
# 404
# Unknown object exception -- cnscottluo/rocketmq-all-learn
# 404
# Unknown object exception -- estlin/marbles-20180822201901659
# 404
# Unknown object exception -- estlin/marbles-20180822195611322
# 404
# Unknown object exception -- volkansoner/volkansonerozsoy.github.io
# 404
# Unknown object exception -- estlin/marbles-20180822204202345
# 404
# Unknown object exception -- ArteFrancoMolina/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- AlexVagrant/Vue-Description
# 404
# Unknown object exception -- davidegallesi/hugo
# 404
# Unknown object exception -- narushimas/isucon9-qualify
# 404
# Unknown object exception -- SVSKHD/h
# 404
# Unknown object exception -- tashinoki/seminar_05_12
# 403
# Rate limit exceeded -- ryanfaria/gatsby-starter-netlify-cms , using access token # 29
# Current time: 2021-07-12 22:08:46.100757
# ***Exit current access token, proceed with next aceess token # 30 rescrape -- ryanfaria/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- mchen9129/mchen9129.github.io
# 404
# Unknown object exception -- theapplegates/gat-start-netlify-cms
# 404
# Unknown object exception -- qbunt/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- agoulziprod/one-click-hugo-cms
# 404
# Unknown object exception -- tomireland/cafe-fika-dot-coffee
# 404
# Unknown object exception -- disappearTesting/workspace
# 403
# Rate limit exceeded -- paulloft/garden , using access token # 30
# Current time: 2021-07-12 22:09:47.803028
# ***Exit current access token, proceed with next aceess token # 31 rescrape -- paulloft/garden
# 404
# Unknown object exception -- andrewdever/boardlife
# 404
# Unknown object exception -- ceyhun/website
# 404
# Unknown object exception -- niederschlag/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- MaxBuckley/turf-boss
# 404
# Unknown object exception -- anibalcascais/gatsby-starter-bootstrap
# 404
# Unknown object exception -- mrtechghost/git
# 404
# Unknown object exception -- mp-pinheiro/pda
# 404
# Unknown object exception -- TechNightt/vuejs
# 404
# Unknown object exception -- lass-net/archive
# 404
# Unknown object exception -- ChinJCheung/biocode
# 404
# Unknown object exception -- ao/aogl
# 403
# Rate limit exceeded -- theParadox42/EFE-Web , using access token # 31
# Current time: 2021-07-12 22:10:34.180192
# ***Exit current access token, proceed with next aceess token # 32 rescrape -- theParadox42/EFE-Web
# 404
# Unknown object exception -- stnly/instalooter
# 404
# Unknown object exception -- madzarmr/cms-porto-madzar
# 404
# Unknown object exception -- CDombrowski/cdombrowski.github.io
# 404
# Unknown object exception -- Highjhacker/hello_world_zer_zur_explorer
# 404
# Unknown object exception -- Highjhacker/hello_world_zer_zur_core
# 404
# Unknown object exception -- deadcanaries/depends-docstrap
# 404
# Unknown object exception -- qqyfly/attitude_adjustment
# 404
# Unknown object exception -- dev-manager-uk/node-sqlcipher-2020
# 404
# Unknown object exception -- robertscottbeattie/xcsoardev
# 404
# Unknown object exception -- dev-manager-uk/node-sqlcipher-2020-fix
# 404
# Unknown object exception -- HenkkaAwar/phplab
# 404
# Unknown object exception -- dev-manager-uk/sqlcipher
# 404
# Unknown object exception -- dev-manager-uk/node-sqlcipher-fix
# 404
# Unknown object exception -- ChaostixZix/PM
# 404
# Unknown object exception -- maidenlane/gql
# 404
# Unknown object exception -- zifengcng/apollo
# 404
# Unknown object exception -- handofmidasproject/GithubSecurityTesting
# 404
# Unknown object exception -- CyouRyuu/carefree0910_MachineLearning
# 403
# Rate limit exceeded -- nestoragent/JavaLearn , using access token # 32
# Current time: 2021-07-12 22:11:45.173253
# ***Exit current access token, proceed with next aceess token # 33 rescrape -- nestoragent/JavaLearn
# 404
# Unknown object exception -- AmrIKhudair/my-resume
# 404
# Unknown object exception -- manhattan-art/modelica
# 404
# Unknown object exception -- emoji-mw/tari
# 404
# Unknown object exception -- fmjconsulting/ansible_install_postgresql
# 404
# Unknown object exception -- jlnbxn/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- whyallusernametaken/sk
# 404
# Unknown object exception -- yajnasteju/code2bug-netlify-cms-admin
# 404
# Unknown object exception -- SA7ANI/MinecraftServer
# 404
# Unknown object exception -- LedgerHQ/ledger-wallet-daemon
# 404
# Unknown object exception -- alanlemoine/personal
# 404
# Unknown object exception -- ymmah/bitcoin-unlimited
# 404
# Unknown object exception -- blcktqq/electron
# 404
# Unknown object exception -- steinroe/club-cms
# 403
# Rate limit exceeded -- MikleBogdanov/wPks21 , using access token # 33
# Current time: 2021-07-12 22:12:46.561497
# ***Exit current access token, proceed with next aceess token # 34 rescrape -- MikleBogdanov/wPks21
# ***Pat access token exceed limit, restart access token loop with # 0
# 403
# Rate limit exceeded -- redacademy/monkiri-spring-2019 , using access token # 0
# Current time: 2021-07-12 22:12:46.633516
# ***Exit current access token, proceed with next aceess token # 1 rescrape -- redacademy/monkiri-spring-2019
# 403
# Rate limit exceeded -- cristicismas/top-budget , using access token # 1
# Current time: 2021-07-12 22:12:46.705857
# ***Exit current access token, proceed with next aceess token # 2 rescrape -- cristicismas/top-budget
# 401
# Bad credentials exception -- NikhilSrinivas/blogg-app , using access token # 2
# Current time: 2021-07-12 22:12:46.755505
# ***Exit current access token, proceed with next aceess token # 3 rescrape -- NikhilSrinivas/blogg-app
# 403
# Rate limit exceeded -- SamWM/gatsby-starter-default , using access token # 3
# Current time: 2021-07-12 22:12:46.805258
# ***Exit current access token, proceed with next aceess token # 4 rescrape -- SamWM/gatsby-starter-default
# 403
# Rate limit exceeded -- newsum2019/laravel-modules , using access token # 4
# Current time: 2021-07-12 22:12:46.878421
# ***Exit current access token, proceed with next aceess token # 5 rescrape -- newsum2019/laravel-modules
# 404
# Unknown object exception -- orienteed/valido-web
# 404
# Unknown object exception -- TIS2010/jslibs
# 404
# Unknown object exception -- boriel/python-is-not-java
# 404
# Unknown object exception -- seiichi115/gatsby-starter-tailwind
# 404
# Unknown object exception -- gntouts/one-click-hugo-cms
# 404
# Unknown object exception -- amontes-org/assets
# 404
# Unknown object exception -- Atulin/Mentax
# 404
# Unknown object exception -- chrisfroeschl/dwm
# 403
# Rate limit exceeded -- dmnks/dotfiles , using access token # 5
# Current time: 2021-07-12 22:13:43.912470
# ***Exit current access token, proceed with next aceess token # 6 rescrape -- dmnks/dotfiles
# 404
# Unknown object exception -- aregpetrosyan/web
# 404
# Unknown object exception -- marco-carvalho/modal
# 404
# Unknown object exception -- jaan-c/time-tracker
# 404
# Unknown object exception -- Benwebdev/gatsby-starter-netlify-cms
# 403
# Rate limit exceeded -- DrCyber1167/sepehrobot , using access token # 6
# Current time: 2021-07-12 22:14:45.702860
# ***Exit current access token, proceed with next aceess token # 7 rescrape -- DrCyber1167/sepehrobot
# 404
# Unknown object exception -- Alwnikrotikz/volatility
# 404
# Unknown object exception -- Alwnikrotikz/kegbot
# 404
# Unknown object exception -- Alwnikrotikz/marave
# 404
# Unknown object exception -- topblossom/icgbooks-front
# 404
# Unknown object exception -- jackerschott/st
# 404
# Unknown object exception -- brykov/hugo-test
# 403
# Rate limit exceeded -- dGlezGall/TelxiusAngular , using access token # 7
# Current time: 2021-07-12 22:15:31.971881
# ***Exit current access token, proceed with next aceess token # 8 rescrape -- dGlezGall/TelxiusAngular
# 404
# Unknown object exception -- okys/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- trezy-studios/trezy-nodecg
# 404
# Unknown object exception -- uport-project/daf-mobile
# 404
# Unknown object exception -- glasnostic/microservices-demo-private
# 404
# Unknown object exception -- peihuiin/frp
# 404
# Unknown object exception -- Murphy0/apollo
# 404
# Unknown object exception -- marcelocampana/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- SleepwalkrX/sleepwalkrx.github.io
# 404
# Unknown object exception -- robotTRG/gatsby-starter-default
# 404
# Unknown object exception -- mitchellfox/jeli-admin
# 404
# Unknown object exception -- iliaselmatani/cms-test
# 404
# Unknown object exception -- compimprove/KingBot
# 404
# Unknown object exception -- rozumny/vpn
# 403
# Rate limit exceeded -- ImmoweltGroup/flow-mono-cli , using access token # 8
# Current time: 2021-07-12 22:16:46.758281
# ***Exit current access token, proceed with next aceess token # 9 rescrape -- ImmoweltGroup/flow-mono-cli
# 404
# Unknown object exception -- eonist/eonist.github.io
# 404
# Unknown object exception -- ymmah/dash
# 404
# Unknown object exception -- kianjr/pjrashidi-blog
# 404
# Unknown object exception -- ryelo/ryelo.dev
# 404
# Unknown object exception -- Rednass/StraatTest
# 404
# Unknown object exception -- sethm/emacs-files
# 404
# Unknown object exception -- Rednass/StraatDev
# 404
# Unknown object exception -- w1ldzer0/deployer
# 404
# Unknown object exception -- facturaperu/facturadorpro20201118
# 403
# Rate limit exceeded -- jilleb/mqb-pm , using access token # 9
# Current time: 2021-07-12 22:17:36.634677
# ***Exit current access token, proceed with next aceess token # 10 rescrape -- jilleb/mqb-pm
# 401
# Bad credentials exception -- privacyint/ThornSec , using access token # 10
# Current time: 2021-07-12 22:17:36.700430
# ***Exit current access token, proceed with next aceess token # 11 rescrape -- privacyint/ThornSec
# 404
# Unknown object exception -- Library-of-Kaeon/Library-of-Kaeon
# 404
# Unknown object exception -- kl0u/beam
# 403
# Rate limit exceeded -- willjoseph/cpparch , using access token # 11
# Current time: 2021-07-12 22:18:26.002328
# ***Exit current access token, proceed with next aceess token # 12 rescrape -- willjoseph/cpparch
# 404
# Unknown object exception -- KazroFox/sickbeard
# 404
# Unknown object exception -- gooddata/GoodData-CL
# 404
# Unknown object exception -- Alwnikrotikz/pyglet
# 404
# Unknown object exception -- catx23/xgrid
# 404
# Unknown object exception -- Alwnikrotikz/django-page-cms
# 403
# Rate limit exceeded -- labscript-suite-temp-2-archive-old1/kjustis-labscriptkelseyversion--forked-from--labscript_suite-labscript , using access token # 12
# Current time: 2021-07-12 22:19:13.354473
# ***Exit current access token, proceed with next aceess token # 13 rescrape -- labscript-suite-temp-2-archive-old1/kjustis-labscriptkelseyversion--forked-from--labscript_suite-labscript
# 404
# Unknown object exception -- IsoVoyd/DiscordBot
# 403
# Rate limit exceeded -- lfzawacki/musical-artifacts , using access token # 13
# Current time: 2021-07-12 22:19:28.594331
# ***Exit current access token, proceed with next aceess token # 14 rescrape -- lfzawacki/musical-artifacts
# 404
# Unknown object exception -- matthewl20/buweb-content-models
# 404
# Unknown object exception -- melvin-hamilton-digital/spryker-vsbridge
# 404
# Unknown object exception -- comp30022-itproject/COMP30022-IT-Project
# 404
# Unknown object exception -- tulasikrishan89/Appium-Test-Distribution
# 404
# Unknown object exception -- masterfake2/hacktoberfest
# 404
# Unknown object exception -- RebirthGamesStudio/quicklook
# 404
# Unknown object exception -- SimpleLiam/one-click-hugo-cms
# 404
# Unknown object exception -- davidstocker/gatsby-starter-blog
# 404
# Unknown object exception -- williamli/netlify-cms-hugo-starter
# 404
# Unknown object exception -- methodofaction/one-click-hugo-cms
# 404
# Unknown object exception -- fahadsaleemfd/one-click-hugo-cmss
# 404
# Unknown object exception -- nobbbyyy/hugo-sprouty
# 404
# Unknown object exception -- MarAngle/ant-design-template
# 404
# Unknown object exception -- appespace/framework
# 403
# Rate limit exceeded -- silinternational/simplesamlphp-module-silauth , using access token # 14
# Current time: 2021-07-12 22:20:38.932801
# ***Exit current access token, proceed with next aceess token # 15 rescrape -- silinternational/simplesamlphp-module-silauth
# 404
# Unknown object exception -- PinkelNet/azure-quickstart-templates
# 404
# Unknown object exception -- marcomow/qf
# 404
# Unknown object exception -- evan-zang/wpftoolkit
# 403
# Rate limit exceeded -- sillsdev/transcriber , using access token # 15
# Current time: 2021-07-12 22:20:59.209796
# ***Exit current access token, proceed with next aceess token # 16 rescrape -- sillsdev/transcriber
# 404
# Unknown object exception -- kingaboros/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- hacker44-h44/PH-BOT
# 404
# Unknown object exception -- hacker44-h44/PH-BOT2
# 404
# Unknown object exception -- key2000/Kagawa20181017
# 404
# Unknown object exception -- fredericoo/marianaavelar
# 403
# Rate limit exceeded -- fjxiaozifeng1/fjxiaozifeng1 , using access token # 16
# Current time: 2021-07-12 22:21:46.152067
# ***Exit current access token, proceed with next aceess token # 17 rescrape -- fjxiaozifeng1/fjxiaozifeng1
# 404
# Unknown object exception -- alexander-hagen/zenbot
# 404
# Unknown object exception -- enweazudaniel/build_scripts
# 404
# Unknown object exception -- jackerschott/surf
# 404
# Unknown object exception -- ar363/one-click-hugo-cms
# 404
# Unknown object exception -- mialkin/waves-documentation
# 404
# Unknown object exception -- Billybobbonnet/one-click-hugo-cms
# 404
# Unknown object exception -- jackerschott/dmenu
# 404
# Unknown object exception -- KenjiYamane/one-click-hugo-cms
# 404
# Unknown object exception -- incarnadinedream/one-click-hugo-cms
# 404
# Unknown object exception -- kaiyangl/milkbox-site
# 404
# Unknown object exception -- bryanjhickey/gatsby-starter-netlify-cms
# 403
# Rate limit exceeded -- rajeshbhoir15/SchoolERP , using access token # 17
# Current time: 2021-07-12 22:22:45.878616
# ***Exit current access token, proceed with next aceess token # 18 rescrape -- rajeshbhoir15/SchoolERP
# 404
# Unknown object exception -- johannesanchez/sc-app
# 404
# Unknown object exception -- radgra/access_attacks
# 404
# Unknown object exception -- abbott567/cookie-consent
# 404
# Unknown object exception -- davidmoltin/one-click-hugo-cms
# 404
# Unknown object exception -- jiangbo2015/gatsby-blog-starter
# 404
# Unknown object exception -- htmlandbacon/cookie-monster
# 404
# Unknown object exception -- Odinwan/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- jiangbo2015/one-click-hugo-cms
# 404
# Unknown object exception -- ratatusznei/rst
# 404
# Unknown object exception -- coolcash/one-click-hugo-cms
# 403
# Rate limit exceeded -- Thursasprengir/AtlantisMuLemuria , using access token # 18
# Current time: 2021-07-12 22:23:56.148624
# ***Exit current access token, proceed with next aceess token # 19 rescrape -- Thursasprengir/AtlantisMuLemuria
# 404
# Unknown object exception -- BoxService/PoracleJS
# 404
# Unknown object exception -- NimaFakoor/iathena
# 404
# Unknown object exception -- kasylozy/ispconfig_setup
# 404
# Unknown object exception -- d3lct7gd/blog-1
# 404
# Unknown object exception -- irfansonmez/etliekmek
# 404
# Unknown object exception -- Redcroft/dwm
# 404
# Unknown object exception -- BeyoncesHomeboy/health-app
# 404
# Unknown object exception -- zachalexander/harlem-dashboard
# 404
# Unknown object exception -- hmrc/address-reputation-ingester
# 403
# Rate limit exceeded -- takcy/openid4java , using access token # 19
# Current time: 2021-07-12 22:24:43.313270
# ***Exit current access token, proceed with next aceess token # 20 rescrape -- takcy/openid4java
# 404
# Unknown object exception -- salymk/gatsby-starter-netlify-cms2
# 404
# Unknown object exception -- eliasleyton/gatsby-starter-netlify-cms2
# 404
# Unknown object exception -- kazushi-eguchi/docs-intellibot
# 404
# Unknown object exception -- nickakey/playbyear.io
# 404
# Unknown object exception -- gantushig/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- Kazumaeric/Zackaz
# 404
# Unknown object exception -- lirimh/one-click-hugo-cms
# 404
# Unknown object exception -- Zakhvm/one-click-hugo-cms
# 404
# Unknown object exception -- NomeQ/tita-hugo-site
# 404
# Unknown object exception -- selner/jobs_scooper
# 404
# Unknown object exception -- pepesan/ejemplos-junit5
# 404
# Unknown object exception -- tan63000/mod-mail-plugins
# 404
# Unknown object exception -- Videowelder/videowelder.xyz
# 404
# Unknown object exception -- sharpcsu/dubbo-study
# 404
# Unknown object exception -- 16mi/mindmeld
# 403
# Rate limit exceeded -- SudoNikon/boxen , using access token # 20
# Current time: 2021-07-12 22:25:46.588206
# ***Exit current access token, proceed with next aceess token # 21 rescrape -- SudoNikon/boxen
# 404
# Unknown object exception -- InfinitySoftwareLTD/Infinity_Explorer
# 404
# Unknown object exception -- mykt0ngc0/nuxt-playground
# 404
# Unknown object exception -- zhangjing5208/-
# 404
# Unknown object exception -- george124816/st
# 404
# Unknown object exception -- SanuKumar/react-bolierplate-saga
# 404
# Unknown object exception -- Kaygex/shedlight
# 404
# Unknown object exception -- 94iwen/BaseCode
# 404
# Unknown object exception -- temesxgn/gatsby-starter-default
# 404
# Unknown object exception -- statsbiblioteket/digital-pligtaflevering-aviser-tools
# 403
# Rate limit exceeded -- NYULibraries/dlts-enm , using access token # 21
# Current time: 2021-07-12 22:26:33.911525
# ***Exit current access token, proceed with next aceess token # 22 rescrape -- NYULibraries/dlts-enm
# 404
# Unknown object exception -- umich-brcf-bioinf/Watermelon
# 404
# Unknown object exception -- ryeden/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- sandromacedo/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- nakamura196/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- openbracellc/hugo-2020JAN4_v1
# 404
# Unknown object exception -- johangeel/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- peterpaw/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- NickZ1969/Speeduino-November
# 404
# Unknown object exception -- videoedge/kernel-source
# 404
# Unknown object exception -- mohammadmosazade47/lp
# 404
# Unknown object exception -- mohammadmosazade47/l
# 404
# Unknown object exception -- traaittPlatform/node-stratum-pool-yescrypt
# 404
# Unknown object exception -- dldhk97/WeHateJava
# 404
# Unknown object exception -- wentbackward-org/wekan-win7
# 403
# Rate limit exceeded -- wasdk/WebAssemblyStudio , using access token # 22
# Current time: 2021-07-12 22:27:46.485128
# ***Exit current access token, proceed with next aceess token # 23 rescrape -- wasdk/WebAssemblyStudio
# 403
# Rate limit exceeded -- iawia002/annie , using access token # 23
# Current time: 2021-07-12 22:27:46.578077
# ***Exit current access token, proceed with next aceess token # 24 rescrape -- iawia002/annie
# 404
# Unknown object exception -- BOFG/one-click-hugo-cms
# 404
# Unknown object exception -- EstebanMarin/gatsby-starter-blog
# 404
# Unknown object exception -- theapplegates/gatsby-starter-algolia
# 404
# Unknown object exception -- abbott567/bsp-claim-manager
# 404
# Unknown object exception -- johnnygan/laravel52
# 404
# Unknown object exception -- MagicKey23/OSS
# 404
# Unknown object exception -- augustoalmeida/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- BalintBernhardt/gatsby-starter-netlify-cms
# 403
# Rate limit exceeded -- nerdi-caveman/gatsby-starter-default , using access token # 24
# Current time: 2021-07-12 22:28:47.662335
# ***Exit current access token, proceed with next aceess token # 25 rescrape -- nerdi-caveman/gatsby-starter-default
# 404
# Unknown object exception -- Ashirkhan857/pythonApplicationWeb
# 404
# Unknown object exception -- alien-art/papatest
# 404
# Unknown object exception -- fderobien/TestFlutter
# 404
# Unknown object exception -- cryops/default-toolchain-1490678701809
# 403
# Rate limit exceeded -- kenhys/hibahub-client , using access token # 25
# Current time: 2021-07-12 22:29:51.536754
# ***Exit current access token, proceed with next aceess token # 26 rescrape -- kenhys/hibahub-client
# 404
# Unknown object exception -- fallphenix/source-integration-merging
# 404
# Unknown object exception -- tawseef007/techstore
# 404
# Unknown object exception -- thy2213/olaindex
# 404
# Unknown object exception -- refixshow/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- sht47/ogrenci-home-page-CMS
# 404
# Unknown object exception -- xkl1bur/kclean-arch-template
# 404
# Unknown object exception -- kotaemin/kotaemin.github.io
# 404
# Unknown object exception -- GMR828/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- JAASharp/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- lui89/one-click-hugo-cms
# 403
# Rate limit exceeded -- marmite22/gatsby-starter-netlify-cms , using access token # 26
# Current time: 2021-07-12 22:30:46.690512
# ***Exit current access token, proceed with next aceess token # 27 rescrape -- marmite22/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- jtsafran/o365-moodle
# 404
# Unknown object exception -- japj/ortp
# 404
# Unknown object exception -- LeCuay/mta-olympus
# 404
# Unknown object exception -- Tusharpalx/itachiRobot
# 404
# Unknown object exception -- yakjs/yakjs
# 403
# Rate limit exceeded -- sanger-archive/barcode_warehouse , using access token # 27
# Current time: 2021-07-12 22:31:35.934358
# ***Exit current access token, proceed with next aceess token # 28 rescrape -- sanger-archive/barcode_warehouse
# 404
# Unknown object exception -- spearuav/ardupilot
# 404
# Unknown object exception -- ismaell/gnu-mtools
# 404
# Unknown object exception -- Xero-Hige/Magus
# 404
# Unknown object exception -- otsimogames/video-modeling
# 404
# Unknown object exception -- AREADELTASAT/alliance-plugins
# 404
# Unknown object exception -- neuroconductor/LESYMAP
# 403
# Rate limit exceeded -- hacklabr/viradacultural , using access token # 28
# Current time: 2021-07-12 22:32:29.420131
# ***Exit current access token, proceed with next aceess token # 29 rescrape -- hacklabr/viradacultural
# 404
# Unknown object exception -- therealjaypo/riofs-mimetypes
# 404
# Unknown object exception -- PulsePanda/CHS-old
# 403
# Rate limit exceeded -- Senney/CPSC599-RPG , using access token # 29
# Current time: 2021-07-12 22:32:50.409177
# ***Exit current access token, proceed with next aceess token # 30 rescrape -- Senney/CPSC599-RPG
# 404
# Unknown object exception -- CheeKC/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- libby-glo/effective-succatash
# 403
# Rate limit exceeded -- yonachan/yonachan.github.io , using access token # 30
# Current time: 2021-07-12 22:33:20.421458
# ***Exit current access token, proceed with next aceess token # 31 rescrape -- yonachan/yonachan.github.io
# 404
# Unknown object exception -- modelfarm/AR.js
# 404
# Unknown object exception -- freedomhui/kcpm
# 404
# Unknown object exception -- johangeel/one-click-hugo-cms
# 404
# Unknown object exception -- todddecapua/one-click-hugo-cms
# 404
# Unknown object exception -- onlineth/heroku-buildpack-php
# 404
# Unknown object exception -- arc986/dwm
# 404
# Unknown object exception -- aposashenko/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- thiagoreis/one-click-hugo-cms
# 404
# Unknown object exception -- ENDRSD/react_app
# 404
# Unknown object exception -- jwcjf/jeff-admin
# 404
# Unknown object exception -- zxostudio/gatsby-stack
# 404
# Unknown object exception -- Rachana876/rachana
# 404
# Unknown object exception -- Craig-Stowers/one-click-hugo-cms
# 404
# Unknown object exception -- iamsonnn/gatsby-starter-netlify-cms
# 403
# Rate limit exceeded -- Detry322/marble-rider , using access token # 31
# Current time: 2021-07-12 22:34:51.181553
# ***Exit current access token, proceed with next aceess token # 32 rescrape -- Detry322/marble-rider
# 404
# Unknown object exception -- annwntech/go-micro
# 404
# Unknown object exception -- myth5/go-admin
# 404
# Unknown object exception -- maxking/mailman
# 404
# Unknown object exception -- vvanghelle/jenkins-x-versions
# 404
# Unknown object exception -- yufeifly/docker17.03.x
# 404
# Unknown object exception -- asadagaha/ddd
# 404
# Unknown object exception -- lichengze520/vue-admin-demo
# 403
# Rate limit exceeded -- emiled/gatsby-starter-netlify-cms , using access token # 32
# Current time: 2021-07-12 22:35:46.189310
# ***Exit current access token, proceed with next aceess token # 33 rescrape -- emiled/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- mimifilles/one-click-hugo-cms
# 404
# Unknown object exception -- flicstar/hugo-cms
# 404
# Unknown object exception -- theapplegates/gatsby-starter-defaultnay
# 404
# Unknown object exception -- israeldahan/blog
# 404
# Unknown object exception -- jonahkalkman/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- jacobedwin79/medicability_cms
# 404
# Unknown object exception -- mariaregan/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- mariaregan/one-click-hugo-cms
# 404
# Unknown object exception -- chaoka/one-click-hugo-cms
# 404
# Unknown object exception -- basith374/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- giampierod/p2a-website
# 404
# Unknown object exception -- ymmah/timelock
# 403
# Rate limit exceeded -- SegaSSE/Bot-Music-2 , using access token # 33
# Current time: 2021-07-12 22:36:46.834321
# ***Exit current access token, proceed with next aceess token # 34 rescrape -- SegaSSE/Bot-Music-2
# ***Pat access token exceed limit, restart access token loop with # 0
# 404
# Unknown object exception -- ajmalafif/gatsby-interUI
# 404
# Unknown object exception -- MishaBykov/Json
# 404
# Unknown object exception -- laukaichung/chung-rn
# 404
# Unknown object exception -- nextgis/quickmapservices_server
# 404
# Unknown object exception -- ferisystem/TeleGold
# 403
# Rate limit exceeded -- saeidkhodaeigol/Saeid , using access token # 0
# Current time: 2021-07-12 22:37:34.092620
# ***Exit current access token, proceed with next aceess token # 1 rescrape -- saeidkhodaeigol/Saeid
# 403
# Rate limit exceeded -- brianfu/TeamCSSS , using access token # 1
# Current time: 2021-07-12 22:37:34.175907
# ***Exit current access token, proceed with next aceess token # 2 rescrape -- brianfu/TeamCSSS
# 401
# Bad credentials exception -- OpenInkpot-archive/gm , using access token # 2
# Current time: 2021-07-12 22:37:34.220813
# ***Exit current access token, proceed with next aceess token # 3 rescrape -- OpenInkpot-archive/gm
# 403
# Rate limit exceeded -- kstange/simbot , using access token # 3
# Current time: 2021-07-12 22:37:34.293821
# ***Exit current access token, proceed with next aceess token # 4 rescrape -- kstange/simbot
# 404
# Unknown object exception -- hacker44-h44/teleguard-v2
# 404
# Unknown object exception -- lciotti/xtideuniversalbios
# 404
# Unknown object exception -- sivakumar-kailasam/dotfiles
# 404
# Unknown object exception -- thesgc/cbh_chembl_ws_extension
# 404
# Unknown object exception -- tyrell152/womack
# 404
# Unknown object exception -- sanjeevraolade/Sanjeev.Xamarin.Plugins
# 404
# Unknown object exception -- petedegraw/react-redux-starter
# 404
# Unknown object exception -- stephenfin/patchwork
# 404
# Unknown object exception -- cujomalainey/dev
# 404
# Unknown object exception -- geraskalnas/scratch-www
# 404
# Unknown object exception -- dragonworks/prose.io
# 404
# Unknown object exception -- sarahn/ganeti
# 403
# Rate limit exceeded -- parnmatt/dwm , using access token # 4
# Current time: 2021-07-12 22:38:46.390120
# ***Exit current access token, proceed with next aceess token # 5 rescrape -- parnmatt/dwm
# 403
# Rate limit exceeded -- zydronium/muddesigner , using access token # 5
# Current time: 2021-07-12 22:38:46.445040
# ***Exit current access token, proceed with next aceess token # 6 rescrape -- zydronium/muddesigner
# 404
# Unknown object exception -- parnmatt/dmenu
# 404
# Unknown object exception -- parnmatt/surf
# 404
# Unknown object exception -- Oke-Anyanwu/vorats
# 404
# Unknown object exception -- viswanath666/greenhouse
# 404
# Unknown object exception -- Hlmn-Rmr/kodio-co
# 403
# Rate limit exceeded -- blackshadev/littledivelog , using access token # 6
# Current time: 2021-07-12 22:39:46.598310
# ***Exit current access token, proceed with next aceess token # 7 rescrape -- blackshadev/littledivelog
# 404
# Unknown object exception -- wldlsmttn/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- brsata/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- Franckeddy/ApiReact
# 404
# Unknown object exception -- okezieuc/one-click-hugo-cms
# 404
# Unknown object exception -- bkobl/openwrt-rtl838x
# 404
# Unknown object exception -- firemax13/android_kernel_sm6150_unified
# 404
# Unknown object exception -- Project-Leicht/libcore
# 404
# Unknown object exception -- kldickenson/umnpha
# 404
# Unknown object exception -- pqrth/gtg-services
# 404
# Unknown object exception -- EagleUnion/Eugen
# 404
# Unknown object exception -- cute-rui/Qv2ray-personal-fork
# 404
# Unknown object exception -- Superboyfan/BulmaRobot-1
# 403
# Rate limit exceeded -- JustusGammelgaard/darkflow , using access token # 7
# Current time: 2021-07-12 22:40:34.776860
# ***Exit current access token, proceed with next aceess token # 8 rescrape -- JustusGammelgaard/darkflow
# 404
# Unknown object exception -- trst/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- johanwallenborg/st
# 404
# Unknown object exception -- KhoaVanNguyen/one-click-hugo-cms
# 404
# Unknown object exception -- YES-12/WORK
# 404
# Unknown object exception -- murthy-softscripts/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- KryskZ09/dmenu
# 404
# Unknown object exception -- thangisme/notes
# 404
# Unknown object exception -- netlifykman/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- meineke/one-click-hugo-cms
# 404
# Unknown object exception -- Rhysdyson/one-click-hugo-cms
# 404
# Unknown object exception -- Rhysdyson/rspb
# 404
# Unknown object exception -- a-very-old-sock/sample_app
# 403
# Rate limit exceeded -- pierregillet/Factorywars , using access token # 8
# Current time: 2021-07-12 22:41:32.142940
# ***Exit current access token, proceed with next aceess token # 9 rescrape -- pierregillet/Factorywars
# 404
# Unknown object exception -- kasylozy/laravel-debugbar
# 404
# Unknown object exception -- ManelBoucenna/policy_library
# 404
# Unknown object exception -- SomeshJoshi19/test-repo
# 404
# Unknown object exception -- duebelbytes/medium
# 403
# Rate limit exceeded -- srozen/webdev_project , using access token # 9
# Current time: 2021-07-12 22:42:21.759029
# ***Exit current access token, proceed with next aceess token # 10 rescrape -- srozen/webdev_project
# 401
# Bad credentials exception -- calebrosario/boxen , using access token # 10
# Current time: 2021-07-12 22:42:21.822438
# ***Exit current access token, proceed with next aceess token # 11 rescrape -- calebrosario/boxen
# 403
# Rate limit exceeded -- lienha/Divvy_Up , using access token # 11
# Current time: 2021-07-12 22:42:21.888935
# ***Exit current access token, proceed with next aceess token # 12 rescrape -- lienha/Divvy_Up
# 403
# Rate limit exceeded -- baek-jinoo/my-boxen , using access token # 12
# Current time: 2021-07-12 22:42:21.959458
# ***Exit current access token, proceed with next aceess token # 13 rescrape -- baek-jinoo/my-boxen
# 403
# Rate limit exceeded -- vanHeemstraSystems/core , using access token # 13
# Current time: 2021-07-12 22:42:22.030983
# ***Exit current access token, proceed with next aceess token # 14 rescrape -- vanHeemstraSystems/core
# 403
# Rate limit exceeded -- this-is-mike/gvi-accounts , using access token # 14
# Current time: 2021-07-12 22:42:22.081789
# ***Exit current access token, proceed with next aceess token # 15 rescrape -- this-is-mike/gvi-accounts
# 403
# Rate limit exceeded -- jdyeakel/jdyeakel.github.io , using access token # 15
# Current time: 2021-07-12 22:42:22.131585
# ***Exit current access token, proceed with next aceess token # 16 rescrape -- jdyeakel/jdyeakel.github.io
# 403
# Rate limit exceeded -- lianilychee/lianilychee.github.io , using access token # 16
# Current time: 2021-07-12 22:42:23.554052
# ***Exit current access token, proceed with next aceess token # 17 rescrape -- lianilychee/lianilychee.github.io
# 403
# Rate limit exceeded -- DimaVovchuk/LvivPortal , using access token # 17
# Current time: 2021-07-12 22:42:23.631484
# ***Exit current access token, proceed with next aceess token # 18 rescrape -- DimaVovchuk/LvivPortal
# 404
# Unknown object exception -- danez/babel-babylon
# 404
# Unknown object exception -- balteravishay/DTL
# 404
# Unknown object exception -- balteravishay/DTL_More
# 404
# Unknown object exception -- jonohewitt/gatsby-starter-netlify-cms-2
# 404
# Unknown object exception -- jamesbmorris4444/globe
# 404
# Unknown object exception -- chromicant/gatsby-starter-tinacms
# 404
# Unknown object exception -- smallt93/redux-persist-config
# 404
# Unknown object exception -- turneyandhall/the-hills
# 404
# Unknown object exception -- yepdung/yepd-gatsby-netlify-cms
# 404
# Unknown object exception -- sivolko/Shubhendu-Shubham-blog
# 404
# Unknown object exception -- hanabi95/Shane
# 404
# Unknown object exception -- jonohewitt/gatsby-starter-netlify-cms
# 403
# Rate limit exceeded -- sustainme/gatsby-starter-netlify-cms , using access token # 18
# Current time: 2021-07-12 22:42:57.625818
# ***Exit current access token, proceed with next aceess token # 19 rescrape -- sustainme/gatsby-starter-netlify-cms
# 403
# Rate limit exceeded -- Vivek-Gajjar-psd/gatsby-starter-netlify-cms , using access token # 19
# Current time: 2021-07-12 22:43:01.481438
# ***Exit current access token, proceed with next aceess token # 20 rescrape -- Vivek-Gajjar-psd/gatsby-starter-netlify-cms
# 403
# Rate limit exceeded -- Prabhat123456/one-click-hugo-cms , using access token # 20
# Current time: 2021-07-12 22:43:03.593486
# ***Exit current access token, proceed with next aceess token # 21 rescrape -- Prabhat123456/one-click-hugo-cms
# 404
# Unknown object exception -- wp-wp/test
# 404
# Unknown object exception -- rana0731/html5-boilerplate
# 404
# Unknown object exception -- rpruizc/one-click-hugo-cms
# 404
# Unknown object exception -- garrettgibo/one-click-hugo-cms
# 404
# Unknown object exception -- mlstack-in/website
# 404
# Unknown object exception -- assaabloybr/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- assaabloybr/test_manual
# 404
# Unknown object exception -- toligmueller/gatsby-netlify-cms
# 404
# Unknown object exception -- quicky7/Red-Magician-Heroku
# 404
# Unknown object exception -- Turtle-Arena/turtle-arena-engine
# 404
# Unknown object exception -- designfwd/priorclave-intl-theme
# 404
# Unknown object exception -- giangitman/project1
# 403
# Rate limit exceeded -- shuaaa/twitter-API , using access token # 21
# Current time: 2021-07-12 22:44:01.838643
# ***Exit current access token, proceed with next aceess token # 22 rescrape -- shuaaa/twitter-API
# 404
# Unknown object exception -- sebass-surfer/one-click-hugo-cms
# 404
# Unknown object exception -- scottste/personal-website-hugo-cms
# 404
# Unknown object exception -- mintproject/mint-ui-lit
# 404
# Unknown object exception -- cjbd/webgl
# 404
# Unknown object exception -- somtick/jasminemyco-netlifycms
# 403
# Rate limit exceeded -- pikepa/manzamembers , using access token # 22
# Current time: 2021-07-12 22:44:47.669423
# ***Exit current access token, proceed with next aceess token # 23 rescrape -- pikepa/manzamembers
# 404
# Unknown object exception -- johnny-choo/one-click-hugo-cms
# 404
# Unknown object exception -- krishnamani/tryghost
# 404
# Unknown object exception -- YannickArmspach/gatsby-starter-netlify-cms
# 404
# Unknown object exception -- Highjhacker/lieface_core
# 404
# Unknown object exception -- mdox/st
# 404
# Unknown object exception -- cyre1450/jmglz
# 404
# Unknown object exception -- fliteinteractive/static-cms-demo
# 403
# Rate limit exceeded -- JennandLee/Our-Road-Trip , using access token # 23
# Current time: 2021-07-12 22:45:34.643676
# ***Exit current access token, proceed with next aceess token # 24 rescrape -- JennandLee/Our-Road-Trip
# 404
# Unknown object exception -- Rean1030/Blog_old
# 404
# Unknown object exception -- warrenbailey/ons-boxen
# 404
# Unknown object exception -- EngMohamedhefny/PeterDing
# 404
# Unknown object exception -- obedm503/obedm503
# 404
# Unknown object exception -- EngMohamedhefny/PeterDing1
# 404
# Unknown object exception -- garima94sharma/Trial
# 404
# Unknown object exception -- im2good/burnbit
# 404
# Unknown object exception -- curefit/react-slick-updated
# 404
# Unknown object exception -- MarianoLuduena/Asclepio
# 404
# Unknown object exception -- graysonecooper/google-api-php-client
# Finished scraping 19220 of 19999 records at 2021-07-12 22:46:42.556341
# It took 1:13:50.469266 to run.

# %%
# read in the file and check
df_repo_stats.head()
#print(df_repo_stats)
#print(df_repo_stats.isna().sum())
#print(df_repo_stats.shape)
# Out:
#    forks                              slug  stars  \
# 0    1.0                petejohanson/hyena    1.0
# 1    0.0     stuartwan/imlazyone.github.io    0.0
# 2  311.0  keycloak/keycloak-nodejs-connect  402.0
# 3  155.0                TommyLemon/APIAuto  910.0
# 4  245.0               seg/2016-ml-contest  144.0
#
#                                               topics  watchers
# 0                                                 []       1.0
# 1                                                 []       1.0
# 2                                                 []      26.0
# 3  [apijson, vuejs2, document-database, autotesti...      26.0
# 4  [machine-learning, data-science, geoscience, c...      30.0

# %%
df_repo_stats.to_csv(r'/home/zz3hs/git/dspg21oss/data/dspg21oss/new_repo_stats_0712_3.csv', index = False)

# %% [markdown]
# # Function to scrape one slug using specified pat index

# %%
#global github_pat_index
def pull_repo_stats(slug, github_pat_index):
    #github_pat_index = 1
   # if github_pat_index >= len(access_tokens):
   #     github_pat_index -= len(access_tokens)
   #     print("***Pat access token exceed limit, restart access token loop with #", github_pat_index)
    while True:
        try:
            if github_pat_index >= len(access_tokens):
                github_pat_index -= len(access_tokens)
                print(f"***Pat access token exceed limit, restart access token loop with #", github_pat_index)  
                
            access_token = get_access_token(github_pat_index)
            #print("Scrapping --", slug,". Extracting access token #", github_pat_index+1,", total", num_token, "tokens are available.")
            #if false, retry until true, max number of retry is set to 3 times
            g = Github(access_token, retry = 3, timeout = 15)
            repo = g.get_repo(slug)
            stars = repo.stargazers_count
            watchers = repo.subscribers_count
            forks = repo.forks_count
            topics = repo.get_topics()
        except RateLimitExceededException as e:
          #  print(e.status)
          #  print('WARNING: Rate limit exceeded --', slug, ", using access token #", github_pat_index)
            #time.sleep(300)
            github_pat_index+=1
          #  print("***Exit current access token, proceed with next aceess token #", github_pat_index, "rescrape --",slug)
            break
        except BadCredentialsException as e:
           # print(e.status)
           # print('WARNING: Bad credentials exception --', slug, ", using access token #", github_pat_index)
            github_pat_index+=1
           # print("***Exit current access token, proceed with next aceess token #", github_pat_index, "rescrape --",slug)
            break
        except UnknownObjectException as e:
           # print(e.status)
           # print('WARNING: Unknown object exception --', slug)
            stars = None
            watchers = None
            forks =  None
            topics = None
            return slug, stars, watchers, forks, topics
            break
        except GithubException as e:
           # print(e.status)
           # print('General exception --', slug)
            break
        except r.exceptions.ConnectionError as e:
           # print('Retries limit exceeded --', slug)
           # print(str(e))
            time.sleep(10)
            continue
        except r.exceptions.Timeout as e:
           # print('Time out exception --', slug)
           # print(str(e))
            time.sleep(10)
            continue
            
        results = (slug, stars, watchers, forks, topics)
        #return slug, stars, watchers, forks, topics
        return results

# %%
# Example
i = 0
print(slugs_example[i])
result = pull_repo_stats(slugs_example[i], 0)
print(result[3])

#print(result[0])
#print(result[1] ==None)
# Out:
# moderndive/ModernDive_book
# 295

# %% [markdown]
# ## Multiprocessing approach: pool.apply_async for multiple parameters

# %%
def get_result(results):
    global slug_log
    global stars_log
    global watchers_log
    global forks_log
    global topics_log
    if result is None:
        slug_log.append(None)
        stars_log.append(None)
        watchers_log.append(None)
        forks_log.append(None)
        topics_log.append(None)  
    else:
        slug_log.append(results[0])
        stars_log.append(results[1])
        watchers_log.append(results[2])
        forks_log.append(results[3])
        topics_log.append(results[4])
        #print("appending results")

# %%
def get_stars(stars):
    global stars_log
    stars_log.append(stars)
    print("appending results")

# %%
stars_log = []
#practice on 2 slugs, one invalid slug 
#slugs_example = ["moderndive/ModernDive_book", "unknownrepo"]

#practice on 7 slugs, one invalid slug 
slugs_example = ["moderndive/ModernDive_book", "DSPG-Young-Scholars-Program/dspg21oss", 
                 "unknownrepo", "moderndive/ModernDive_book", "lsst/ip_diffim", "esrlabs/chipmunk", "paulmillr/chokidar"]


slugs_100 = slugs[0:100]

# %%
multiprocessing.cpu_count()
# Out:
# 40

# %%
# Approach 2. pool.apply_async for multiple parameters
if __name__ == '__main__':
    cores_available = multiprocessing.cpu_count() - 1
    print(f'There are {cores_available} CPUs available.')
    #pool = multiprocessing.Pool(cores_available)
    pool = multiprocessing.Pool(10)
    
    # now we will feed in all of the remaining slugs 
    slug_log = []
    stars_log = []
    watchers_log = []
    forks_log = []
    topics_log = []

    start_time = datetime.datetime.now()
    print("Start scraping. Start time:", start_time)
    
    for slug in slugs_try:        
        pat_i = 3
        pool.apply_async(pull_repo_stats, args=(slug,  pat_i),callback = get_result)        
        print("~~~~~~~~~~~~~~~slug: ",slug, "using access token #", pat_i, "~~~~~~~~~~~~~~~~")
    pool.close()
    pool.join()
    
    final_log = pd.DataFrame({'slug': slug_log, "stars": stars_log, 'watchers': watchers_log, 'forks': forks_log, 'topics': topics_log}, columns=["slug", "stars", "watchers", "forks", "topics"])

    end_time = datetime.datetime.now()
    print("Finished scraping", len(final_log), "of", len(slugs_try), "records at", end_time)
    print("It took", end_time-start_time, "to run.")
# Out:
# There are 39 CPUs available.
# Start scraping. Start time: 2021-06-28 11:02:33.855801
# ~~~~~~~~~~~~~~~slug:  voxsim/badook using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Denver-userbot/D-USERBOT using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  thoniraq/IQTHON using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Baqrted/telethoncat using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Denver-userbot/rushi using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  MrASquare/verge-wallet using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ItzSjDude/Plus using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Velocies/raptor-ads using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nikolai5slo/jamvm using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  bhaii126272/userbot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nobody-repo/nObOdY-lOvEsYOU using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sahilgamer07d/SahilGamer555 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ryanpetrello/draughtcraft using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  goodmeow/xtrauserbot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  XavierNextStep/Xavier using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Krishna666Shrivastav/UserBot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  YoungLeung/CodingMart_iOS using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  cobracommander-snakexenziagang/CatMod using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  deyar-bb/Lite using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  limingxinleo/kong-phalcon using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dvjsworld/tr using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Lazybotk/hsje using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Baqrted/bybaqr using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Asalem1/AptRater using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dhruvgodara1999/CatBot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sndwvs/images_build_kit using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kits-ab/LogLady using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  youinmyhumiliation/project using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ececilla/jsa using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  TrevorSundberg/LynxChan using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sunpho84/SUNphi using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  fauzanaditia7/telebot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  prashanthkokkula06/AWS_Practice using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  cattele/telethoncat using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jcwimer/wrestlingApp using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  manas1111/manasbot2 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Baqrted/nottele using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  gamerfuckerofficial/Gamerfucker using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  wltribble/frost using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  klanrali/tastEnd using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  devunt/hydrocarbon using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Cincinesh/tue using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  flaviut/poetry using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ceylon/ceylon-module-resolver using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  qiupfyp/archillian_API using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  cloudfoundry-incubator/eirini-release using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ckr215/ckr215.github.io using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  qt-jorge-tovar/mean-app using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dieterich-lab/circtools using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  donatid/faveo-helpdesk using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  blmousee/repo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  selective-inference/R-software using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  MmxBoy/newbot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  tangjinhui951023/axios using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sundowndev/underbase using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rhenium/aclog using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  eminemdordie/mailer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  agdsn/hades using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  HenryFBP/2019-team-07f-dockerized using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  NLeSC/spot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  pkp/ots using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  skyhisi/xfce4-mailwatch-plugin using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ChristopherChudzicki/math3d-react using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  filerjs/filer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ascclemens/paste using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dllhlx/libcgroup using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  csikfer/lanview2 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Pyrdacor/freeserf.net using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Doxito/Ri-Core using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  crandrade/PokemonGo-Map using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  vigilo/correlator using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  centre-for-educational-technology/RADA using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  begla/Intrinsic using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  allourideas/pairwise-api using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  springernature/halfpipe using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  CivicHaxx/ok_councillr using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  csstree/csstree using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ronthecookie/discordboats-ARCHIVE using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  svenhjol/lockers using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  markhepburn/dotemacs using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  pothitos/naxos using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Cryru/Emotion using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Paperspace/gradient-cli using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  shiguredo/momo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  reactjs/React.NET using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  RegalOwl/HyperConomy using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Mego/Seriously using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  CryptoSpaces/tronwallet-mobile using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  staltz/manyverse using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  pyconau2017/symposion using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  solutious/stella using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  maksmaisak/Saxion_Y2Q4_Project_Exposure using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rootulp/exercism using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  twilio/twilio-node using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  triton-inference-server/server using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Quinter/trebek using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  partylover/openwrt-node-packages using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  venkateshshukla/libdivecomputer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  vigna/ne using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  conwayste/conwayste using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  MartinYik/AppleALC using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  symfony/cache using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  JuliaPackageMirrors/Wallace.jl using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  opentechinstitute/luci-commotion using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  linnovate/mean-on-openshift using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nextcloud/windows-universal using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  maraf/Money using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  qcha0s/theSpot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  EmurgoHK/cardanoupdate using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  gwt-plugins/gwt-eclipse-plugin using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  marsbard/puppet-alfresco using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  JaneaSystems/nodejs-mobile-gyp using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  adamturnerphotography/photogrpahiccms using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  1522140840/xxl-job using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rvetere/electron-react-boiler using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  stanfordnlp/spinn using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  andy-schulz/thekla using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ablyler/daemonizing-php using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mbkumar/pycdt using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  lierdakil/ide-haskell-hie using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  niefermar/google-maps-services-java using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rivinduw/fairseq_ntf using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  OpenTreeOfLife/propinquity using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  gwsystems/wasmception-libcxxabi using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  FarragoFiction/DollLibCorrect using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ledgerconnect/hivesigner-api using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Luodina/web-starter using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  eonarmy/xuserbot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kangso1/ppy using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  openva/richmondsunlight.com using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  datianshi/weblogic-buildpack using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mtezych/libcxxabi using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  JJJJJJJack/crazyflie-firmware using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kervin521/xxl-job-v1.9.1 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ib-ruby/ib-ruby using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  adib1380/iranian_bot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  eonarmy/xhackunaluserbot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  srvmsr/symfony-demo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  webrtc-lizp/chromium-llvm-project-libcxxabi using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  x86-64/frozen using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  JEMRIS/jemris using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  heroicefforts/java-buildpack-pyclid using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mlhartme/lavender using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  elpassion/mainframer-intellij-plugin using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dreamcatcherit/wooey-django22 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  DXsmiley/mathbot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Babelz/SaNi using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  samlanh/aseansm using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dpblh/BPM.js using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  CMSCollection/piranha.core using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  bobotang992/123 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  markllama/jenkins-jobs using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  DiegoValdivia/mean_practice using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  cool-robot-pals/pancakes-or-waffles using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  zion64/spring-ldap using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  hafslundnett/hdd-style using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  RubyIT/Android using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  IIIF-Commons/manifesto using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  xiyoujiyjy/free-programming-books-zh_CN using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  openstack/networking-bgpvpn using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ManageIQ/azure-armrest using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Ineedajob/RSBot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  tecknicaltom/cgdb-working using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  netgroup/srv6-pm-dp-ipset using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  phase2/grunt-drupal-tasks using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  cha0s/shrub using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  swoft-cloud/swoft-http-message using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  netnivaran/test using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  B3ST/B3 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  SitecoreUnicorn/Unicorn using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rudymatela/leancheck using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  devinbalkind/nyc-prepared using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ska80/parenscript using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  zipmark/rspec_api_documentation using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  bh-consulting/snack using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  justjavac/free-programming-books-zh_CN using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  zycet/iTRLib using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  blackops97/TEAM using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  frogbywyplay/git-repo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kinnarisanghvi/cloud-computing-AWS-Springboot-App using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  gonghao9527/-9527 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  fluidtrends/chunky using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mpracek/Diploma using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ChronosTeam/ChronosGL using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ops4j/org.ops4j.pax.wicket using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  artdiev/akommo-dashboard using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  evansde77/cirrus using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ExtraCells/ExtraCells2 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  r73inc/AR.ja using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  LeonWanjau/ecoms-dashboard using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  2martens/2martens.de using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  aronezhang/operator-sdk using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  eve-seat/seat using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  guildai/_guild-legacy using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  libyui/libyui-qt using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  shahabsaf1/merbot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  audy/dotflies using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  treewei/balancer-core using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dappnet-one/hivemind using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  itdddjulius/ConceptH using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nFnK/Workerman using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  coderIML/NAudio using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  TeaBough/st using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rahulyhg/generatte using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  bravelab/pilgrimage-dashboard using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  vmware/differential-datalog using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  TransparencyToolkit/LookingGlass using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  zetaops/pyoko using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  hpcloud-mon/monasca-events-api using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sjtu-rr-homework/PokemonAR-running using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  SoleeChoi/iamport-electron-example using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  NDLANO/image-api using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  monsterlabs/HumanRightsTracker using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  joaqoliva/TABLERODECONTROL using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mihirjh/cwtdashboard using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  strengejacke/sjmisc using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  iron-io/iron_worker_ruby_ng using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  persaianbot/XY using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mirumee/saleor-dashboard using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Sygmei/ObEngine using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mdgriffith/style-elements using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  reworkhow/JWAS.jl using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rmobis/unistream using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  OpenSDE/mnemosyne using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  pulai/ZXing.Net using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Zippen-Huang/auto-vehicle-PythonRobotics using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  boxcrittersmods/bc-mod-api using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  instructure/canvas-ios using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mrlitong/fpsgame using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Coolcord/Level-Headed using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  pv/gwaei-stuff using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  saiichihashimoto/eslint-config-saiichihashimoto using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  orange-cloudfoundry/cf-ops-automation using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  strukturag/VLCKit using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  miss-invincible/oauth2-bshaffer-implementation-in-slim using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  lmaurits/BEASTling using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Team-FreeDom/PB_Management using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jmigueldelgado/buhayra using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kaazing/http2.js using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  toruscomputer/tcodc using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  INAETICS/Drones-Simulator using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mb44/food-supply-pi using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  redhat-developer/codeready-workspaces using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  geoffroy-aubry/Indefero using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  yhfudev/php-indefero using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  readysetstem/readysetstem-api using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nheist/CaLiGraph using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  geodynamics/Rayleigh using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  gwolf0719/fjuexam using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  SBuild-org/sbuild using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  zk25796/niklasvh-html2canvas using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  itajenglish/apollo_frontend using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  PrestaShop/ps_facetedsearch using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  play-co/native-android using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  2420048520/https-github.com-analysys-EasyScheduler using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  prasannata/StackX using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  NLPatVCU/medaCy using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  UCSB-CMPTGCS-1A-F16/UCSB-CMPTGCS-1A-F16.github.io using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  phptal/PHPTAL using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  SciCompKL/CoDiPack using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  noahbenson/neuropythy using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  abh/ezmlm-idx using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  AnhellO/DAS_Sistemas using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ArmanIr/UltraJonzi using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  DaveBackus/Data_Bootcamp using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  bagelswitch/java-8-buildpack using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  reactojango/javascript_testing using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Kromey/roglick using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  paulshorey/ps using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  pmorou/quantasma using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  HTBox/crisischeckin using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  heroku/heroku-buildpack-nodejs using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  gmcabrita/dotfiles using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  lathonez/clicker using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Bnei-Baruch/mdb using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  vaishnaviallampallewar/nodejsCopied using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  shitwolfymakes/Endless-Sky-Mission-Builder using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  paluh/icecast using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  TheWorst1/1 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  klartext/any-dl using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jmcameron/attachments_translations using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mhardcastle/ddf-pipeline using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  RobertTheMagnificent/scrib using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mrrigealijan/mer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ljsun88/data_bootcamp_nyu using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  AmitKumarDas/Decisions using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Bogswagen/genieacs_herman using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  hochoy18/json4s using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  openservicebrokerapi/servicebroker using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  genieacs/genieacs using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  NUmeroAndDev/SojoDia-android using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Lyndir/Pearl using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  bitcoincashorg/bitcoincash.org using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Chris7/Mudlet2 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Sainan/Universal-Bypass using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nicoespeon/abracadabra using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jantoniomartin/condottieri-old using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  usagecontrolsystem/usagecontrolsystem using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  aparcar/asu using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  alscorsi/Streamming using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  esdoc-next/esdoc-next using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kiwix/kiwix-js-windows using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ahtss/213 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  barbelity/jfrog-cli-core-test using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ENCODE-DCC/chip-seq-pipeline using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  LeesinDong/ribbon using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Douglas-County-CO/NearMeDC using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  JenSte/libsigrokdecode using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  vincenthz/hs-gauge using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  PandaCrushSaga/PandaCrushSaga using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Ethck/PathOfBuilding using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mrsarutobi/https-github.com-Azure-Samples-media-services-dotnet-functions-integration using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mickey0524/leetcode using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  thinklikes/guapp-front-end using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  gabrielyuyang/test2 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  AxGord/Pony using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dheerajhanda/G using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kstoreyf/foo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  cassandra-project/platform using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  johnwbyrd/brakefile using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dongikpark/contrail using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  viren85/moviemirchi using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mrrigealijan/spm1 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  SpilledMilkCOM/MooveePicker using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  openeuler-mirror/infrastructure using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Zippen-Huang/donkeycar using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  EDRN/labcas-backend using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Qiyy1/Mytest using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  afderrick/Mudlet using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jfrog/jfrog-cli-core using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  pbrooks/dotfiles using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  apache/axis-axis2-java-sandesha using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ufu-games/freshmans-quest using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  gabrielyuyang/test3 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  anilreyhan/forktest using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  johndevedu/react-electron-rest-client using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sonnenhaft/pandax_angular-1.5 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  micos7/blog_laravel using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  gofed/gofed using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  5AMsan/Neorizons using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mercenem/devopsfolks using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Evildavo/SGD103-Homeless using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  osorubeki-fujita/odpt_tokyo_metro using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  SwatiJadhav46/html2canvas using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  art-locale/art-haus using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nathanchere/stx using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  OpenSocialCSN/incontact-desktop using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rahulram93/wysihtml-tables-demo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jbrowneuk/jblog using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jfrog/jfrog-cli using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  AthensFramework/Core using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  tantalum420/Docker using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  oomba/oomba-wiki using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  AYCHErp/Invoicing using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  QoboLtd/cakephp-utils using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  E-ARK-Software/earkweb using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Blockost/google-seq2seq using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rdewilde-ion/ion-electrum-server using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  wzthu/esATAC using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dkushner/ArborJs-Playground using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  leeper/leeper.github.io using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  andrecronje/gource using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Ohkiam/jQuery-contextMenu using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  oliverychen/oliverychen.github.io using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  krjivesh/star using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  KittyHawkIrc/modules using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  weixiaolv/micro-go-plugins using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ssilverm/pcsx-piplay using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sachinkanodia/rtools using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sonata-project/SonataNewsBundle using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ycz3792/Meka using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ivanoats/parade using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mkg20001/pkg-bundle using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  hbxq2018/xxl-job using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  leondraceus/PMDVN-Nexus-Bot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dcposch/go using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  OPI-PIB/navoica-platform using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  qingqiu8/zheng using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  swapnil-pathak/mbed-cli using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  khalahan/old_namecoin using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  JoinMarket-Org/joinmarket-clientserver using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  blomm/meanio_template using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  fjelltopp/meerkat_abacus using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kaltura/playkit-android using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  KIZI/EasyMiner-EasyMinerCenter using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  cloudflare/quiche using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dobruy2517/robot_tests_kap using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  apinf/openapi-designer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  breddy31/bandit1 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  carlsonp/kort using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kurthill4/d8 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  DarthMike/indielib-crossplatform using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  hieunguyenformos/lumX using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  tonyxiao/segment-debugger using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ishmilan2/ishmilan.github.io using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  guokai27/VUE-AD using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ShiZhan/fs-crawler using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  AakashOfficial/Calculator using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Teino1978-Corp/Teino1978-Corp-gulp using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Ultr4-Froz3n/spamer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  StanfordLegion/psana-legion using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ChinHuatAng/meta-virtualization using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dcdanko/BioBitBot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  johnnycook/gatsby-starter-netlify-cms using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  treeder/functions using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  manuelcortez/socializer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  LIVVkit/LIVVkit using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ebellity/geocoder using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  malramsay64/statdyn-simulation using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Softman65/abooks using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  haojianxun/mirror-quay.io using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rodrigosilvaluz/FaveoHelpDesk using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  naturenet/naturenet-viz using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  bin-nuance-bat/project using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  davkal/WP-contributions using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  doitroot/flannel using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  BUTSpeechFIT/beer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kungfumas/jsoneditor using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  evpobr/oggz using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  provegard/ncdbg using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  fyndiq/fyndiq-woocommerce-module using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  distribute-protocol/distribute-app using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  brightwind-dev/brightwind using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  frictionlessdata/specs using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Brightspace/D2L.Security.OAuth2 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  MagicForrest/DGVMTools using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nicferrier/elnode using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  openwebnet/openwebnet-android using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  raatiniemi/sonar-objective-c using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  CruceGameDevel/CruceGame using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  KenSuenobu/rust-pushrod using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  wp-plugins/subscribe2 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Azure/azure-event-hubs using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  haohlin/yolov3customtraining using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kwery/kwery using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Bandwidth/bandwidth.github.io using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  cisocrgroup/ocrd-postcorrection using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kenfehling/react-router-nested-history using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kimurakenshi/caravanas using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Ghostkeeper/SettingsGuide using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  esheldon/fitsio using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Promises/Warcraft-Maul-Buildtools using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  shawt/Arduino-Create-for-iForge using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Voog/wysihtml using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Waikato/meka using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  wtbarnes/synthesizAR using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  AppLozic/ApplozicSwift using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mentor81/spamer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  larrydiamond/typescriptcollectionsframework using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  bootc/ulogd2 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jeblad/Pickle using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  uken/fluent-plugin-elasticsearch using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mobinlord/xybot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  GoogleCloudPlatform/esp-v2 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  GNOME/gnome-klotski using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ronin-rb/ronin-db using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Maxsteam/EE using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kenavolic/statismo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  beer-asr/beer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  swisnl/jQuery-contextMenu using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  scoverage/scalac-scoverage-plugin using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  irvined1982/lavaflow using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  wikimedia/mediawiki-skins-Refreshed using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  prettier/plugin-php using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  BunkersAndBadasses/MetaDND using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nesbarse/mountain-blog using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mozilla/contain-facebook using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mkb2091/blockconvert using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  turnpike/libcxxabi using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Gubaer/josm-scripting-plugin using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Symphony-DAS/symphony-matlab using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  DoctorMcKay/node-steam-user using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  seclib/cerberus using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  TehNut/VoidCraft using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  codica2/vue-timebot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  symmetryinvestments/autowrap using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ITBE-Lab/MA using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  davidhu2000/youtube_desktop using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jagi/meteor-astronomy using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  shartge/netcomics using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  naazgull/zapata using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  opencredit/badgeos using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ferreusveritas/DynamicTrees using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  zauner/vvvv.js using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  curtbinder/AndroidStatus using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  vidaaudrey/avanta using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  TypeStrong/typedoc using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kemtol/solusikonveksi using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  lizardsystem/lizard-auth-server using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ShibeTemple/iChangerApp using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  python-provy/provy using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  bevacqua/node-emoji-random using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  emberjs/ember-qunit using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  achesak/weatherlog using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  pibemillo/unveil-gatsby-netlify-cms using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Disslove77777/AAAA using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  cooperhewitt/Planetary using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  apmckinlay/gsuneido using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  zet-evacuation/zet using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ymmah/carbon-c-relay using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  orlenko/bccf using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  filipemarruda/meanTest using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  pedronasser/functions using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  soruly/anilist-chinese using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  linuxmuster/linuxmuster-schulkonsole using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  halfline/polari using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  arackaf/cr-build-dashboard using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  MrLetsplay2003/MrCore using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  goldwasserexchange/public using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kinvolk/coreos-cloudinit using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  CaptainFact/captain-fact-api using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  smtcrms/Android-Iconics using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  RhenaudTheLukark/Botfire using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  xcwill/my_seq2seq using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  communcom/cyber-swift using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  infor-cloud/cloud-store using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  TinkerEdgeR-Android/build_blueprint using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Miner1305/ccdev using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  singhiam/ElectronTest using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  hkg36/SBJson_amenmod using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  almonteb/scoot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  arlac77/chunk-tokenizer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  wesh9999/cloud-store-import-test using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  alephdata/followthemoney using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Offensive101/MLproject using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  APDevTeam/Movecraft using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  glennmatthews/cot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dquinteros/quad using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  MaSven/simavr-solus-packaging using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  wkw/react-draft-editor-shell using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  veyrats/cf-java-buildpack-production using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  underdogg-forks/faveocleandecember using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  agrover/kmod using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  quangthuyhoang/dashboard using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  joomlatools/joomlatools-framework-activities using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  IHA114/mattata using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  epfl-vlsc/bwa using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  purilarp/openhab-openhab-core using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  reserva-facil/minimalist using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  paypal/paypal-smart-payment-buttons using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  larrybotha/dotfiles using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  maxsite/cms using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Gwion/gwion-sporth using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  csonchen/electron-react using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  arlac77/registry-mixin using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sravel/scripts using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dotnetcore/AspectCore-Framework using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  TelescopeSt/Telescope using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  chavdar/gobblin using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  identicurse/statusnet.py using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  reubano/tophubbers using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kbbgl/ecOptimizer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  AaronNGray/typedoc-next using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  codejamninja/charts using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  cc-daveloper/mist.io_vaadin-grid using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  PMKielstra/catfish using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  AYCH-Inc/aych.electrum using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  alisterk/chromiumfx-orign using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  vkefallinos/typedoc using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  SevenSinS02/selfie using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ging/fiware-idm using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  maxdrift/safari-client using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  liangtg/git-repo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Qarj/WebImblaze using access token # 3 ~~~~~~~~~~~~~~~~
# ...
# ~~~~~~~~~~~~~~~slug:  philroche/simplestreams-clone using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  camunda/blog.camunda.org using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  5monkeys/bpython using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  alanjia163/first1 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ganibc/btcpool using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  llccrr/tarot-master-electron using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nandiso/rest-client using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  snitheesh/rest-client using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ilariapiva/rest-client using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  videni/rest-client using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  vegeth1985/rest-client using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  npsyche/rest-client using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ZacksTsang/rest-client using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jmsosa/rest-client using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dark88888/rest-client using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  hiro117/rest-client using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  treatys/rest-client using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  acidgenomics/r-deseqanalysis using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  joe-lz/TodoKit2019 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  zhouchunyu/wechat using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mittagessen/kraken using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  omid1212/spam using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  tallerify/shared-server using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  codex-corp/flashls using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Trendyol/quarkify using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  bhermansyah/ANDMA-datacenter using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  leo-project/leo_redundant_manager using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kranz/vai using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Kane07008/findom using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  z0x010/lynis using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sl17/cyclone.github.io using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  noxor0/c-fastq-barcode using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  gSilas/space-assault using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  thanhcao/rd3next using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dmitriy-korotayev/macros using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  aofei/air using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  allomov/jenkins-buildpack-v2 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  WikiEducationFoundation/Wiki-Playlist using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  zioc/git-repo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ydh7611/VIP using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Adrianrp/electron using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  horde/hermes using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  generalbao/phpmailer6 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  aalice072/XFMaps using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  elbstack/elbstack-hackreact-web-3 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  bgkrupesh/BlockMarbleTest1 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  aymanamer/Dank-Memer using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  HuntWS/Jenkins-Plugin using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  vaniila/graphql using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  papillonads/papillonads.draft using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  giteshsawar/ledger using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  socialsudo/socialsudo.github.io using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  myzainn/free-video using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  k1988/git-repo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  hzypage/TestPy using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dyukusi/shout_for_ff14 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kiazhu/repo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sambhavdutt/fabric-ca using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sysadmws/sysadmws-formula using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jancelin/geo-poppy using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  vaartjesd/test using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  phanindra032/projectpractice1 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  YatsukBogdan1/SelectWood using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rwaschewski/vue-storefront-tracomodo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  JMensch/openwiki-nyt using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Toppington/insert_android2 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sailfishos-mirror/telepathy-haze using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Turing-Circle/sens-main using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  moodlebox/moodlebox.net using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  modelfarm/AR.js using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  cloudbase/cinder-ci using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  at0mzk1/facturacion using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  prashantkashyap09/BasicReact using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nirmal0001/master using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kukudan/Use-for-learn-vnpys using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  noah-smith-dev/upstack-test using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  cguerrerCS/pokenest-finder using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  lncm/pi-factory using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  shadowbeam/allan-watson using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  NOBITABRO/prosecbot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  bidah/storytime-feria using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  aleidaolvera/gusa-library using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  CharlesDDNoble/broncode using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  spacekitteh/git-repo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  egor5q/loshadbot using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  qrtc/uWebSockets using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  eth-sri/eth-sri.github.io using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  waartaa/waartaa using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  alabs/petateca using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ironandsilk/ar using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  msuliborski/the-nightmare using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  openflexo-team/connie using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nanoporetech/medaka using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  freedesktop/telepathy-haze using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  telefonicaid/fiware-sth-comet using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  influxdata/influxdb-comparisons using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  xfce-mirror/xfce4-notes-plugin using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  digabi/rich-text-editor using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ethantw/Han using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ypzhuang/web-console-starter-bk using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  asgardphp/asgard using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  kevoj/nodetomic-api-swagger using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Splawik/pytigon using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ansjory/mids-w205-crook using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  citizenlabsgr/openbudgetwy using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  spring-cloud/spring-cloud-dataflow-ui using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nirantarnoy/prasit using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  arwystli/getlocations_dr using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  moment/luxon using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  jjzhang166/libcss using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  tkgamegroup/flame using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Ashkanovich/Bring using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dymajo/waka using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  sazboom/pophealth-mihin using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  MateusVMachado/etm using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  churchthemes/church-theme-content using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  TelepathyIM/telepathy-haze using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Rareson/LammpsRelated using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  linuxpanpan/repo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  aicirt2012/icm-server using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Film-Solutions-LLC/fsregistry using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rejeep/apes using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  radjkarl/pyqtgraph_karl using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  pwafire/pwafire using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Zematus/Worlds using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Azure/AzureStack-Tools using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  synapsestudios/oidc-platform using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  goldenrivertek/git-repo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  furlongm/patchman using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  GHPReporter/Ghpr.Core using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  xuperchain/go-libp2p-kad-dht using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  MassEffectModder/MassEffectModder using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  tiarebalbi/fortaleza-ui-theme using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Saintway-Technology/repo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  canonical-web-and-design/cn.ubuntu.com using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  voteamerica/backend using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  UMM-CSci-3601-S18/iteration-4-readme-md using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  joomlatools/joomlatools-vagrant using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  MarcGrol/golangAnnotations using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  louissong7912/SMP_libaacs using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  serverboards/serverboards-plugins-oss using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  platformio/platformio-atom-ide using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  borzz/sysbench using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  pprotasov/dbapi using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ZcashFoundation/zecwallet using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  hhvm/hhast using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rescatux/rescatux using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  zdavatz/oddb2xml using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dalek-cryptography/bulletproofs using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mdickinson/bigfloat using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  angrykoala/wendigo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  open-eid/MOPP-iOS using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  apache/flex-flexunit using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  diachron/quality using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  OGGM/oggm using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  rspeele/Rezoom.SQL using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  nlsynth/iroha using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  criswell/uca-gpl using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  WhisperChi/owt-client-native-windows using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  freedesktop-unofficial-mirror/telepathy__telepathy-haze using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  unfaiyted/cactbot-settings-app using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  slfyusufu/git-repo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Lambda-School-Labs/labs10-shopping-list using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  twada/power-assert-runtime using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  dreaminghell/repo using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ruby-amqp/march_hare using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  zpy807/https-github.com-binux-pyspider using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  mperreir/HyblabDDJ2018 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  1busyguy/ARfaceSwap using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Miner1305/loki using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  JuananRodriguez/Dashboard-Electron using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Achain-Dev/act.cdt using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Max7641/linux_knowledge using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  swarm00/nanodbc using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  ericgsmith/d7patternlab using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Arpple/projectend using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  roycastro/AppsX11 using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  deiscc/builder using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  Edgarpz/boss_charts using access token # 3 ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~slug:  chzhong/git-repo using access token # 3 ~~~~~~~~~~~~~~~~
# Exception in thread Thread-15:
# Traceback (most recent call last):
#   File "/home/zz3hs/.conda/envs/crystal/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/home/zz3hs/.conda/envs/crystal/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zz3hs/.conda/envs/crystal/lib/python3.7/multiprocessing/pool.py", line 486, in _handle_results
#     cache[job]._set(i, obj)
#   File "/home/zz3hs/.conda/envs/crystal/lib/python3.7/multiprocessing/pool.py", line 662, in _set
#     self._callback(self._value)
#   File "<ipython-input-37-ca40cdba5350>", line 14, in get_result
#     slug_log.append(results[0])
# TypeError: 'NoneType' object is not subscriptable

# %%
#print(final_log)
final_log
# Out:
#                                     slug   stars  watchers  forks  \
# 0                            unknownrepo     NaN       NaN    NaN
# 1             moderndive/ModernDive_book   548.0      28.0  295.0
# 2             moderndive/ModernDive_book   548.0      28.0  295.0
# 3  DSPG-Young-Scholars-Program/dspg21oss     0.0       3.0    0.0
# 4                         lsst/ip_diffim     5.0      45.0    7.0
# 5                       esrlabs/chipmunk   285.0      11.0   23.0
# 6                     paulmillr/chokidar  7990.0      85.0  511.0
#
#                                               topics
# 0                                               None
# 1  [moderndive, data-science, tidyverse, statisti...
# 2  [moderndive, data-science, tidyverse, statisti...
# 3                                                 []
# 4                                                 []
# 5  [logs-analysis, logviewer, search, logstash, l...
# 6       [watch-files, fsevents, watcher, filesystem]

# %% [markdown]
# ## Multiprocessing approach: pool.imap_unordered

# %%
cores_available = multiprocessing.cpu_count() - 1
print(f'There are {cores_available} cores available.')
pool = Pool(cores_available)

# now we will feed in all of the remaining slugs 
slug_log = []
stars_log = []
watchers_log = []
forks_log = []
topics_log = []

start_time = datetime.datetime.now()
print("Start scraping. Start time:", start_time)
for result in pool.imap_unordered(pull_repo_stats, slugs_example):
    print("~~~~~~~~~~~~~~~result: ",result, "~~~~~~~~~~~~~~~~")
    if result is None:
        slug_log.append(None)
        stars_log.append(None)
        watchers_log.append(None)
        forks_log.append(None)
        topics_log.append(None)  
    else:
        slug_log.append(result[0])
        stars_log.append(result[1])
        watchers_log.append(result[2])
        forks_log.append(result[3])
        topics_log.append(result[4])


final_log = pd.DataFrame({'slug': slug_log, "stars": stars_log, 'watchers': watchers_log, 'forks': forks_log, 'topics': topics_log}, columns=["slug", "stars", "watchers", "forks", "topics"])

end_time = datetime.datetime.now()
print("Finished scraping", len(final_log), "of", len(slugs), "records at", end_time)
print("It took", end_time-start_time, "to run.")
# Out:
# There are 39 cores available.
# 404
# WARNING: Unknown object exception -- rrrrrrrrr
# Start scraping. Start time: 2021-06-23 11:22:11.104201
# ~~~~~~~~~~~~~~~result:  ('rrrrrrrrr', None, None, None, None) ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~result:  ('DSPG-Young-Scholars-Program/dspg21oss', 0, 3, 0, []) ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~result:  ('moderndive/ModernDive_book', 548, 28, 295, ['moderndive', 'data-science', 'tidyverse', 'statistical-inference', 'r', 'ggplot2', 'infer', 'hypothesis-testing', 'confidence-intervals', 'regression', 'regression-models', 'data-visualization', 'data-wrangling', 'tidy', 'rstudio', 'rstats', 'dplyr', 'bootstrap-method', 'permutation-test']) ~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~result:  ('moderndive/ModernDive_book', 548, 28, 295, ['moderndive', 'data-science', 'tidyverse', 'statistical-inference', 'r', 'ggplot2', 'infer', 'hypothesis-testing', 'confidence-intervals', 'regression', 'regression-models', 'data-visualization', 'data-wrangling', 'tidy', 'rstudio', 'rstats', 'dplyr', 'bootstrap-method', 'permutation-test']) ~~~~~~~~~~~~~~~~
# Finished scraping 4 of 4 records at 2021-06-23 11:22:11.378817
# It took 0:00:00.274616 to run.

# %%
final_log
# Out:
#                                     slug  stars  watchers  forks  \
# 0                              rrrrrrrrr    NaN       NaN    NaN
# 1  DSPG-Young-Scholars-Program/dspg21oss    0.0       3.0    0.0
# 2             moderndive/ModernDive_book  548.0      28.0  295.0
# 3             moderndive/ModernDive_book  548.0      28.0  295.0
#
#                                               topics
# 0                                               None
# 1                                                 []
# 2  [moderndive, data-science, tidyverse, statisti...
# 3  [moderndive, data-science, tidyverse, statisti...

# %%
#final_log.to_csv(r'/home/zz3hs/git/dspg21oss/data/dspg21oss/final_log_try.csv', index = False)

# %%
# read in the file and check
print(final_log.head())
print(final_log)
print(final_log.isna().sum())
print(final_log.shape)
# Out:
#                                     slug  stars  watchers  forks  \
# 0                              rrrrrrrrr    NaN       NaN    NaN
# 1  DSPG-Young-Scholars-Program/dspg21oss    0.0       3.0    0.0
# 2             moderndive/ModernDive_book  548.0      28.0  295.0
# 3             moderndive/ModernDive_book  548.0      28.0  295.0
#
#                                               topics
# 0                                               None
# 1                                                 []
# 2  [moderndive, data-science, tidyverse, statisti...
# 3  [moderndive, data-science, tidyverse, statisti...
#                                     slug  stars  watchers  forks  \
# 0                              rrrrrrrrr    NaN       NaN    NaN
# 1  DSPG-Young-Scholars-Program/dspg21oss    0.0       3.0    0.0
# 2             moderndive/ModernDive_book  548.0      28.0  295.0
# 3             moderndive/ModernDive_book  548.0      28.0  295.0
#
#                                               topics
# 0                                               None
# 1                                                 []
# 2  [moderndive, data-science, tidyverse, statisti...
# 3  [moderndive, data-science, tidyverse, statisti...
# slug        0
# stars       1
# watchers    1
# forks       1
# topics      1
# dtype: int64
# (4, 5)

# %% [raw]
# # concactinate scrapped dataframes together
# df1 = pd.read_csv('/home/zz3hs/git/dspg21oss/data/dspg21oss/repo_stats_bt_1000_1500.csv') #import csv
# print(df1.shape)
# df2 = pd.read_csv('/home/zz3hs/git/dspg21oss/data/dspg21oss/repo_stats_bt_1500_2000.csv') #import csv
# print(df2.shape)
# df3 = pd.read_csv('/home/zz3hs/git/dspg21oss/data/dspg21oss/repo_stats_bt_2000_4500.csv') #import csv
# print(df3.shape)
# df4 = pd.read_csv('/home/zz3hs/git/dspg21oss/data/dspg21oss/repo_stats_gt_3000.csv') #import csv
# print(df4.shape)
#
#
# frames = [df1, df2, df3, df4]
#
# repo_stats_gt_1000 = pd.concat(frames)
#
# repo_stats_gt_1000 = repo_stats_gt_1000.drop_duplicates(subset = 'slug', keep = 'first')
# print("We scrapped",repo_stats_gt_1000.shape[0], "repos, that have greater than 1000 commits.")
#
# #repo_stats_gt_3000.to_csv(r'/home/zz3hs/git/dspg21oss/data/dspg21oss/repo_stats_gt_3000.csv', index = False)
